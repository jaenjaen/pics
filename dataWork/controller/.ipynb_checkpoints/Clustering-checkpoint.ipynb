# %% [markdown]
# # Clustering

# %% [markdown]
# ## 1. keyword 정제
#     1) 주요 태그 추출
#     - description 내용 포함 태그
#     - description과 일치하는 단어가 없는 태그는 태그 그대로 사용
#     - 태그 없는 187개 스튜디오는 description에서 추출한 단어 사용
#
#      2) 유사 단어 묶어주기
#     - WordCloudVec으로 단어간 유사도 판별
#
#     >> 타겟 스튜디오와 동일한 태그 개수 세기
#
# ## 2. 범주형 데이터 Gower로 수치형 데이터로 변환
#     1) 범주형 데이터는 category와

# %%
import numpy as np #판다스 친구 넘파이
import pandas as pd # 판다스
from pandas import DataFrame as df
import re # 정규식 사용을 위함
import nltk
import csv
from konlpy.tag import Okt
from konlpy.utils import pprint
from collections import Counter

# %%
import os
dataset = pd.read_csv("total_dataset_trim.csv",encoding='utf-8')
dataset.head()
# Out:
#      NO  img_fold_no                 studio_name  \
# 0  1099           27                     홍대_체스#4
# 1   939          254     파티와 촬영용 이태원 뷰 좋은 루프탑 빌라
# 2   952          267     파티와 촬영용 이태원 뷰 좋은 루프탑 빌라
# 3   252          251           깔끔하고 아늑한 신축 투룸아파트
# 4   478          477  TV없이 아늑하게 꾸민 거실, 21평 부부 공간
#
#                                       studio_picture  \
# 0  ['https://s3.hourplace.co.kr/temp/images/2019/...
# 1  ['https://s3.hourplace.co.kr/temp/images/2019/...
# 2  ['https://s3.hourplace.co.kr/temp/images/2019/...
# 3  ['https://s3.hourplace.co.kr/temp/images/2019/...
# 4  ['https://s3.hourplace.co.kr/temp/images/2019/...
#
#                                           imafe_file category region  \
# 0  ['27_0_홍대_체스#4.jpg', '27_1_홍대_체스#4.jpg', '27_2...       원룸     서울
# 1  ['254_0_파티와_촬영용_이태원_뷰_좋은_루프탑_빌라.jpg', '254_1_파...       주택     서울
# 2  ['267_0_파티와_촬영용_이태원_뷰_좋은_루프탑_빌라.jpg', '267_1_파...       주택     서울
# 3  ['251_0_깔끔하고_아늑한_신축_투룸아파트.jpg', '251_1_깔끔하고_아늑...      아파트     서울
# 4  ['477_0_TV없이_아늑하게_꾸민_거실,_21평_부부_공간.jpg', '477_...      아파트     경기
#
#                                                  tag   price  area floor  \
# 0          #1.5룸#나혼자산다#모던#분리형원룸#빌라#서교동#서울시#원룸#클래식#홍대  50,000    30     2
# 1             #10명수용#남산타워#루프탑#벽난로#복고풍인테리어#자연광스튜디오#전망  38,000   145     2
# 2             #10명수용#남산타워#루프탑#벽난로#복고풍인테리어#자연광스튜디오#전망  38,000   145     2
# 3  #10평투룸오피스텔#따뜻한가정집#선유도신축아파트#선유도신축오피스텔#신혼부부아파트#아...  50,000    33    11
# 4  #12층#TV없는#분위기좋은#색다른#아늑한거실#예쁜거실#깨끗한#쇼파2개#북향의#해가안드는  62,000    69    12
#
#    default_person  parking                                        description
# 0               6        0  홍대 메인 거리에 등록한 오래된 집을 리모델링 했습니다. (90년대 빌라)\r\n체...
# 1               8        1  44평 내부에 큰 거실과 키친, 음악작업용 스튜디오 룸, 생활하는 큰 방, 렌트용 ...
# 2               8        1  44평 내부에 큰 거실과 키친, 음악작업용 스튜디오 룸, 생활하는 큰 방, 렌트용 ...
# 3               4        1  선유도역 1분거리에 위치한 신축 투룸오피스텔입니다.\r\n11층 남향으로 낮에는 해...
# 4              10        3  - 2인가구 부부가 사는 공간입니다.\r\n- 신축이라 쾌적하고 깔끔합니다.\r\n...

# %%
## Tag 다듬기
## 복합명사로 이루어진 태그는 잘라서 길이 2~7 사이의 단어만 추출
def getTagList(value):
    okt=Okt()
    parseTagList=[]
    tempTagList=[]
    tags=(value).str.split('#') # 태그별로 자르기
    for tag in tags:
        if len(tag)>1:
            okt.nouns(tag)  # 1개 태그 내 복합 명사 자르기
            for j in okt.nouns(tag):
                if(len(j)>=2|len(j)<9):
                    tempTagList.append(j)
    tempTagList=list(set(tempTagList))
    parseTagList.append(tempTagList)
    return parseTagList

# %%
## description 다듬기
def getDescList(value):
    okt=Okt()
    descList=[]
    value=value.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
    descList=[i for i in okt.nouns(value) if len(i)>1]
    descList=list(set(descList))
    return descList

# %%
## 코어 태그 추출
def getCoreTags(n):
    coreTagList=[]
    okt=Okt()    
    for i in range(n):
        coreTag=""
        descript=getDescList(dataset.description[i]) # 한글자 이상만 뽑음
        tags=getTagList(dataset.tag[i])  # tag를 한번 더 파싱
        for t in tags: 
            if t in descript: # 태그가 description 단어에도 있는지 확인
                coreTag+=t
        if len(tags[0])<=1: # 태그 수가 적으면(=1개 이하) desc의 단어로 대체
            for desc in descript:
                coreTagList.append(desc)
        elif len(coreTag)>=3:  # description과 일치하는 tag가 충분하면(3개 이상) 일치하는 태그 그대로 사용
            for core in coretag:
                coreTagList.append(core)
        else:  # description과 일치하는 태그는 없지만 태그 수는 충분할 때 추출한 tag를 그대로 사용
            for tag in tags:
                coreTagList.append(tag)
    return coreTagList

# %%
# %time CoreTagDate=getCoreTags(1800)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-329-e2ab2ba6d5b7> in getCoreTags(n)
#       6         coreTag=""
#       7         descript=getDescList(dataset.description[i]) # 한글자 이상만 뽑음
# ----> 8         tags=getTagList(dataset.tag[i])  # tag를 한번 더 파싱
#       9         for t in tags:
#      10             if t in descript: # 태그가 description 단어에도 있는지 확인
#
# <ipython-input-327-6ff199b1725b> in getTagList(value)
#       5     parseTagList=[]
#       6     tempTagList=[]
# ----> 7     tags=(value).split('#') # 태그별로 자르기
#       8     for tag in tags:
#       9         if len(tag)>1:
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Out:
# [['홍대', '원룸', '서울시', '클래식', '서교동', '빌라', '분리', '모던'],
#  ['자연', '전망', '고풍', '벽난로', '루프', '명수'],
#  ['자연', '전망', '고풍', '벽난로', '루프', '명수'],
#  ['신축', '선유도', '가정', '아파트', '평투룸'],
#  ['북향', '쇼파', '분위기'],
#  ['카페', '신혼집', '빌라'],
#  ['반포', '아파트', '잠원역', '소형', '강남', '잠원동'],
#  ['자취', '원룸', '가구', '광고', '여자'],
#  ['원룸', '싱글', '라이프', '주거', '고시원', '천호역'],
#  ['골드', '블루', '서울', '화이트', '모던'],
#  ['아이방', '테라스', '복층', '대형', '평수'],
#  ['아파트', '서현역'],
#  '칸막이',
#  '공간',
#  '평의',
#  '화실',
#  ['평지', '화장실', '주차', '편리', '빈티', '가능', '차량', '공간', '강화도', '공사'],
#  ['아파트', '정원', '모던', '아이방'],
#  ['오디오', '가구', '층집', '가정', '레디', '접시', '루왁', '소품', '화이트', '모던'],
#  ['차편', '동물', '층집', '여의도', '촬영', '당산', '아이', '근처', '베란다'],
#  ['돌담', '자연', '층집', '사계절', '종로구', '주의', '아이', '소개', '유리'],
#  ['두운', '심플', '카페', '효창동', '공간', '모던', '근처'],
#  ['자취', '남자', '공원', '고인돌', '심풀', '서초구', '숲역', '시민', '양재천'],
#  ['심플', '모던', '우드', '추럴', '아파트', '하우스', '화이트', '신혼집'],
#  ['모던', '심플', '빌라'],
#  ['화장실', '반지하', '가정', '빌라'],
#  ['아파트', '신혼집', '금호동', '옥수동'],
#  ['심플', '가정', '테리어', '아파트', '그레이', '평인', '화이트', '모던'],
#  ['심플', '주방', '애견', '거실', '쇼파', '모던'],
#  ['화이트하우스', '원목', '가정', '테리어', '테이블', '촬영', '화이트', '플랜'],
#  ['평일', '고급', '주말', '로쏘', '가능', '촬영', '명소'],
#  ['카페', '부산', '스터디'],
#  ['파트', '일산', '마을', '아파트', '후곡'],
#  ['반지하', '주택'],
#  ['장기', '영화', '작업실', '셀프', '복층', '촬영', '월세'],
#  ['원형', '네추럴', '심플', '거울', '주방', '조명', '계단', '사진빨', '화이트'],
#  ['자연', '바다', '밤하늘', '맑은', '시골', '단독'],
#  '뒷마당',
#  '앞마당',
#  '주변',
#  '시간',
#  '대여',
#  '사용',
#  '공터',
#  '운정신도시',
#  '검색',
#  '위로',
#  '차고',
#  '가능',
#  '장소',
#  '오전',
#  '단독주택',
#  '잡지',
#  '모든',
#  '주차',
#  '오후',
#  '사진',
#  '파주',
#  ['분위기', '카페', '주얼리', '정원', '야간', '소품', '고가'],
#  '주택',
#  ['프렌치', '미니', '플라워', '한남동', '복합', '정원', '주상', '모던'],
#  ['홍대', '주택', '연남동', '꽃길', '테라스'],
#  ['파티', '주택', '층집', '바베큐', '소나무', '애견', '벽난로', '정원', '데크', '목조', '설경', '가든'],
#  ['파티', '주택', '층집', '바베큐', '소나무', '애견', '벽난로', '정원', '데크', '목조', '설경', '가든'],
#  ['기숙사', '하숙집', '층집', '옥상', '마당', '학생'],
#  ['나무', '층집', '사계절', '네츄럴', '햇살', '마당', '창문'],
#  ['힐링', '웨딩', '스몰', '바닷가', '제주', '별장', '평정', '야외', '촬영', '주독'],
#  ['야경', '부부', '빌라'],
#  ['미니', '원목', '아파트', '갤러리', '화이트', '신혼집'],
#  ['신축', '남향', '가정', '섭외', '아파트', '촬영', '강원도'],
#  ['주방', '아기', '우드', '아파트', '소품', '거실', '화이트', '모던'],
#  ['주방', '아기', '우드', '아파트', '소품', '거실', '화이트', '모던'],
#  ['자연', '북카페', '아파트', '수채화', '천일홍', '축제', '휴량', '학생'],
#  ['비디오', '키덜트', '브이', '아파트', '촬영', '식물', '소품', '로그'],
#  ['차편', '영상', '브이', '아파트', '스타일', '촬영', '소품', '로그', '모던', '일몰'],
#  ['심플', '분위기', '미니', '국적', '아파트', '화이트', '압구정', '모던'],
#  ['심플', '분위기', '미니', '국적', '아파트', '화이트', '압구정', '모던'],
#  ['잠실', '모던', '고양이', '서울', '아파트', '화이트', '아이'],
#  ['가정', '아파트', '용산', '화이트', '비디오', '한강', '아이'],
#  ['주방', '강뷰', '신혼집', '대면'],
#  ['주차', '심플', '아파트', '가능', '그레이', '모던'],
#  ['아파트', '베란다'],
#  ['모델링', '아파트'],
#  ['평집', '잠실', '미니', '우드', '가정', '사진빨', '화이트'],
#  ['거실', '아파트', '서재', '전망'],
#  '대우',
#  '소재',
#  '서울',
#  '부터',
#  '아파트',
#  '전망',
#  '한강',
#  '금호동',
#  '사용',
#  ['고층', '아파트', '남자', '아이방'],
#  ['심플', '고층', '아파트', '하우스', '아이'],
#  ['건물', '주택', '해먹', '옥상', '계단', '복층', '다가', '상가', '루프', '가족사'],
#  ['쉐어', '케렌', '쓰리룸', '시아', '셰어', '빌라', '하우스', '통기타', '여자'],
#  '홍대입구역',
#  '주택',
#  ['생활', '가정', '구가'],
#  '독채',
#  '예약',
#  '옥상',
#  '제공',
#  '느낌',
#  '촬영',
#  '하우스',
#  '진행',
#  '다락방',
#  '테라스',
#  '장소',
#  '공간',
#  '컨셉',
#  '서로',
#  '분위기',
#  '주말',
#  '저희',
#  '추천',
#  '또한',
#  '다른',
#  '평일',
#  '프라이',
#  '인조잔디',
#  '포함',
#  '게스트',
#  '거실',
#  ['건물', '카페', '테라스', '분위기'],
#  ['깨끗', '양천구', '염창역', '강서구', '심플', '가정', '등촌역', '목동'],
#  ['대형', '휴양지', '모임', '세미', '느낌', '촬영', '평수'],
#  ['마루', '헤링', '원목', '우드', '추럴', '화이트', '강남구'],
#  ['심플', '조명', '여학생', '아파트', '현대', '용산', '감각', '모던'],
#  ['최근', '주차장'],
#  ['가족', '목재', '가정', '그릇', '아파트', '촬영'],
#  ['가족', '황토', '흙집'],
#  ['소형', '가족', '아파트', '전망'],
#  ['가족', '아파트'],
#  ['가족', '아파트'],
#  ['드라마', '미니', '아파트', '촬영', '화이트', '대여'],
#  ['경기도',
#   '일산',
#   '카페',
#   '브이',
#   '아파트',
#   '컬러',
#   '느낌',
#   '하우스',
#   '촬영',
#   '소품',
#   '로그',
#   '모던',
#   '통창'],
#  ['마루', '숲뷰', '원목', '아파트', '잡지', '내추럴', '모던', '북유럽'],
#  ['영상', '상도', '아파트', '바이럴', '최상급', '장소', '촬영', '모던'],
#  ['판교',
#   '분당',
#   '가구',
#   '클래식',
#   '갤러리',
#   '셀프',
#   '수내동',
#   '대형',
#   '소품',
#   '하우스',
#   '평수',
#   '그림',
#   '유화'],
#  ['판교',
#   '분당',
#   '가구',
#   '클래식',
#   '갤러리',
#   '셀프',
#   '수내동',
#   '대형',
#   '소품',
#   '하우스',
#   '평수',
#   '그림',
#   '유화'],
#  '리본',
#  '아파트',
#  '마루',
#  ['씨티', '분위기', '다락방', '산장', '초대형', '한남동', '옥수동', '벽난로', '복층', '빌라', '한강'],
#  ['씨티', '분위기', '다락방', '산장', '초대형', '한남동', '옥수동', '벽난로', '복층', '빌라', '한강'],
#  ['피안', '양재동', '모던', '주택', '복층', '빌라', '유러'],
#  ['피안', '양재동', '모던', '주택', '복층', '빌라', '유러'],
#  ['사무실', '오피스'],
#  ['홈바', '고급'],
#  ['무대', '스몰', '분위기'],
#  ['노출', '갤러리', '테라스', '현대', '촬영', '루프', '유니크'],
#  ['드라마', '광고', '서울', '뉴트', '아파트', '컬러', '촬영'],
#  ['드라마', '광고', '서울', '뉴트', '아파트', '컬러', '촬영'],
#  ['영화', '대관', '가정', '장소', '촬영'],
#  ['셔터', '화보', '드라마', '광고', '루버', '부부', '개인', '사진', '장소', '촬영', '감성', '마크'],
#  ['셔터', '화보', '드라마', '광고', '루버', '부부', '개인', '사진', '장소', '촬영', '감성', '마크'],
#  ['카페', '테마', '갤러리', '자동차', '장소', '촬영'],
#  ['렌탈', '작업실', '영화', '대관', '빈티', '잡지', '장소', '촬영', '공간'],
#  ['잔듸', '드라마', '화보', '농사', '배경', '장소', '시골', '촬영', '풍경'],
#  ['홍대', '영화', '드라마', '야구', '데이트', '연습장', '장소', '촬영'],
#  ['촬영', '호프', '장소'],
#  ['모던', '아지트'],
#  ['공원', '방송국', '미니', '놀이', '한세상', '래미안', '근처', '북유럽'],
#  ['가족', '홍대', '미니', '촬영', '거실', '전망', '서재', '근처'],
#  ['영화', '분위기', '광고', '카페', '라운지', '촬영', '컨셉'],
#  '인테리어',
#  '별채',
#  '주변',
#  '언덕',
#  '특징',
#  '귤밭',
#  '전원',
#  '주택',
#  '실내',
#  '구분',
#  '조성',
#  '복층',
#  '저희',
#  '잔디',
#  ['노을', '올림픽공원역', '공원', '미니', '야경', '올림픽', '사옥', '전망'],
#  ['강화도', '주택', '시골', '대형'],
#  ['영업', '씨방', '상업', '일반', '공간', '피시방'],
#  '인테리어',
#  '규모',
#  '흡연실',
#  '카페',
#  '환경',
#  ['녹음실', '녹음', '광고', '코딩', '강남'],
#  ['감성', '공간', '성북구', '대관'],
#  ['대안', '대관', '한남동', '복합', '문화', '갤러리', '장소', '공간', '이태원', '전시'],
#  ['동산', '산속', '보은', '오두막', '매실', '농장', '마당', '시크릿', '잔디'],
#  ['무인', '분위기', '터치', '카페', '커피숍', '자판기'],
#  ['미니', '신혼집'],
#  ['럭셔리', '카페', '반포', '마리나', '요트', '동작', '회장', '보트'],
#  ['일산', '관리', '두피', '미용실', '헤어', '살롱'],
#  ['맥주', '양궁', '사격장', '카페', '실내', '술집', '다트'],
#  ['가게', '카페', '분당'],
#  ['주택', '빈방'],
#  ['카페', '가든', '정원'],
#  '이면',
#  '강남',
#  '지하철',
#  ['파티', '작업실', '터링', '와인', '카페', '프라이', '직장인', '모임', '케이', '예술가'],
#  ['파티', '작업실', '터링', '와인', '카페', '프라이', '직장인', '모임', '케이', '예술가'],
#  ['소규모', '지하', '행사', '신사역', '독특', '강연', '라운지', '팬미팅', '전시'],
#  ['소규모', '지하', '행사', '신사역', '독특', '강연', '라운지', '팬미팅', '전시'],
#  ['가마솥', '숯불', '고기', '벽난로', '펜션', '토방'],
#  ['가마솥', '자연', '주방', '전통', '한남동', '쿠킹'],
#  ['가야산', '정원', '성주', '해인사', '잔디'],
#  '연령',
#  '거실',
#  '시간',
#  '아파트',
#  '교실',
#  '아이',
#  '사용',
#  '현재',
#  '산책',
#  '원중',
#  '광장',
#  '가능',
#  '중앙',
#  '주로',
#  '유희',
#  '건축',
#  '형태',
#  '월요일',
#  '가정',
#  '어린이집',
#  '방이',
#  '실로',
#  '단지',
#  '보육',
#  '위치',
#  '정도',
#  '일요일',
#  '대상',
#  '가정',
#  '순천만',
#  '정원',
#  '순천',
#  '전남',
#  '입자',
#  '선호',
#  '오시',
#  '주말',
#  '촬영',
#  '기타',
#  '유투브',
#  '사용',
#  '가족',
#  '거주',
#  '대학생',
#  '중년',
#  '강아지',
#  '직장인',
#  '부부',
#  '화장실',
#  '모두',
#  '중인',
#  '거주',
#  '방도',
#  '주중',
#  '가정',
#  '주말',
#  '일반',
#  '놀이',
#  '촬영',
#  '거실',
#  '아이',
#  '베란다',
#  ['신축', '주택', '빌라', '강동구', '가정', '성내동', '서울시', '강동역'],
#  ['부엌', '가구', '가정', '아파트', '식물', '디자인', '거실', '안방', '모던', '베란다'],
#  ['쇼핑몰', '대관', '광고', '가정', '대리석', '아파트', '촬영', '신혼집'],
#  ['심플', '가정', '대리석', '아파트', '까페', '모던'],
#  ['심플', '가정', '대리석', '아파트', '까페', '모던'],
#  ['아파트', '서재', '가정', '인천'],
#  ['아파트', '서재', '가정', '인천'],
#  ['소음', '주말', '가정', '아파트', '가능', '모던', '근처'],
#  ['파티', '럭셔리', '펜션', '가정', '서울', '도시', '하우스', '공간', '게스트하우스'],
#  ['쓰리룸', '채광', '원목', '가정', '대형', '레트로', '큰집'],
#  ['가정', '복합', '주상', '아파트', '대형', '평수', '모던'],
#  ['일산', '투룸', '주택', '가정', '개인', '빌라', '방송'],
#  ['아파트', '가정', '베란다'],
#  ['혼사', '복도', '대관', '레트로', '빈티', '가정', '아파트', '촬영', '이태원'],
#  ['혼사', '복도', '대관', '레트로', '빈티', '가정', '아파트', '촬영', '이태원'],
#  ['가족', '람사', '아파트', '가정'],
#  ['근교', '우드', '가정', '클래식', '서울', '아파트'],
#  ['근교', '우드', '가정', '클래식', '서울', '아파트'],
#  ['홍대', '가정', '서교동', '테라스', '내츄럴'],
#  ['홍대', '입구', '가정', '테라스', '내츄럴'],
#  ['아파트', '가정', '엔틱'],
#  ['아파트', '가정', '엔틱'],
#  ['아파트', '가정', '엔틱'],
#  ['센터', '컨벤션', '주변', '평화', '김대중', '광장', '가정', '아파트', '영산강', '목포'],
#  ['센터', '컨벤션', '주변', '평화', '김대중', '광장', '가정', '아파트', '영산강', '목포'],
#  ['아파트', '가정', '일산'],
#  ['홈인', '대관', '홈스', '가정', '그램', '테리어', '아파트', '스타', '장소', '촬영', '하우스', '대여'],
#  ['화초', '어항', '작고', '가정', '해수어'],
#  ['가족', '경기', '자연', '가정', '광주'],
#  ['건물', '층집', '가정', '촬영장', '아파트', '대여'],
#  ['자취', '대관', '가정', '바이럴', '제품', '촬영', '대여', '여자'],
#  ['섭외', '가정'],
#  ['촬영', '차편', '가정', '전망'],
#  ['남향', '가정', '고층', '아파트', '촬영', '거실', '공간', '대여'],
#  ['정원', '테라스', '용산', '가제', '모델링'],
#  ['가족', '식탁', '세대', '장비', '주인', '다가'],
#  ['가족', '드라마', '광고', '아파트', '잡지', '촬영', '신혼집'],
#  ['가족', '아파트', '촬영', '내츄럴', '번화가', '북유럽'],
#  ['필드', '가족', '노을', '탑층', '스타', '이케아', '촬영', '편안함', '화이트'],
#  ['가족', '홍대', '영상', '가정', '바이럴', '장소', '촬영', '번화가', '대여'],
#  ['가족', '오이', '가평', '코스', '정원', '레저', '야외', '펜션', '단체'],
#  ['가족', '스파', '펜션'],
#  ['독채', '강변', '경기', '웨딩', '북한', '스몰', '가평', '야외', '까페'],
#  ['노출', '가평', '주택', '아침', '고요', '정원', '수목원', '시골', '마당', '잔디'],
#  ['설악', '힐링', '잣나무', '황토', '가평', '별장', '구들'],
#  ['청평', '가평', '카폐'],
#  ['파티', '대관', '스터디', '서울', '모임', '강남', '촬영', '생일', '각종'],
#  ['영상', '강연', '원데이', '간담', '촬영', '세미나'],
#  ['소규모',
#   '파티',
#   '작업실',
#   '마케팅',
#   '공원',
#   '사무실',
#   '로데오',
#   '신사동',
#   '스포츠',
#   '도산',
#   '모임',
#   '감각',
#   '루프',
#   '브랜드',
#   '강남'],
#  ['사무실', '감각', '법률', '사무소'],
#  ['투룸', '자취', '빈티', '레트로', '감각', '하우스'],
#  ['파티', '샤워', '카페', '원목', '브라', '공간', '이벤트', '감성', '대여'],
#  ['렌탈', '인터뷰', '자연', '광고', '바이럴', '셀프', '욕조', '촬영', '감성', '그네'],
#  ['불광천', '분위기', '카페', '테라스', '감성', '주차장'],
#  ['가득', '감성'],
#  ['감성', '맛집'],
#  ['화보', '경리', '동남아', '광고', '빈티', '개인', '마켓', '블로그', '사진', '촬영', '감성'],
#  ['홈인', '정원', '테리어', '수영장', '펜션', '촬영', '감성'],
#  ['구조', '자연', '오두막', '바베큐', '테라스', '복층', '촬영', '감성'],
#  ['강가', '심플', '미니', '화이트', '마당', '비담', '내추럴', '모던', '전망', '북유럽'],
#  ['강가', '심플', '미니', '화이트', '마당', '비담', '내추럴', '모던', '전망', '북유럽'],
#  ['렌탈', '작업실', '도곡동', '양재', '강남'],
#  ['연습실', '선릉역', '강남', '거울'],
#  ['사무실', '삼성동', '로펌', '강남', '모던', '오피스'],
#  ['대관', '카페', '인생', '촬영', '강남', '양재'],
#  ['대관', '카페', '인생', '촬영', '강남', '양재'],
#  ['영상', '룩북', '광고', '사진', '제품', '촬영', '역삼역', '대행', '강남', '호리'],
#  ['유튜버', '논현', '유튜브', '촬영', '신사', '역삼', '강남', '호리'],
#  ['무인', '렌탈', '청담동', '셀프', '유튜브', '강남'],
#  ['파티', '주방', '공간', '강남', '대여'],
#  ['타워', '서밋', '반포', '옥상', '촬영', '야경', '도심', '교보', '루프', '강남'],
#  ['미술', '공원', '동양화', '신사동', '강남구', '도산', '학원', '민화', '수묵화', '압구정', '그림'],
#  ['논현동', '회의실', '사무실', '학동역', '강남구', '임원', '오피스'],
#  ['원룸', '렌탈', '강남'],
#  ['원룸', '렌탈', '강남'],
#  ['렌탈', '셀프', '강남'],
#  ['원룸', '렌탈', '강남'],
#  ['렌탈', '쓰리룸', '주택', '반지하', '강남역', '논현역', '강남'],
#  ['녹음실', '동호', '대치동', '리즌', '대치', '삼성역', '강남'],
#  ['광고', '모던', '인터뷰', '강남'],
#  ['스튜', '영상', '다오', '대형', '촬영', '방음', '화이트', '강남', '호리'],
#  ['렌탈', '논현동', '존렌탈', '주역', '강남', '호리'],
#  ['영상', '실내', '존트', '배경', '사진', '촬영', '흰색', '강남', '호리'],
#  ['강남역', '구장', '까페'],
#  ['역삼동', '강남역', '존트', '대형', '호리'],
#  ['로프', '강남'],
#  ['렌탈', '자연', '광렌탈', '촬영', '연광', '강남', '호리'],
#  ['파티', '작업실', '카페', '플라워', '아지트', '강남'],
#  ['홈바', '공원', '리조트', '극장', '수영장', '갤러리', '대형', '화이트', '평수', '강남', '베란다'],
#  ['강릉', '주택', '한국', '구옥', '마당'],
#  ['정동진', '강릉', '유리창', '카페', '바다'],
#  ['강변', '프렌치', '주방', '조명', '웨인', '스콧', '컨드', '야경', '모던'],
#  ['강변', '산책로', '바지선', '노래방', '소나무', '정원', '계단', '낚시', '소품', '모닥불', '게스트하우스'],
#  ['강변', '산책로', '바지선', '노래방', '소나무', '정원', '계단', '낚시', '소품', '모닥불', '게스트하우스'],
#  ['강북', '심플', '강북구', '성북구', '독신남', '모던', '노원구'],
#  ['강북', '심플', '강북구', '성북구', '독신남', '모던', '노원구'],
#  ['강뷰', '강가', '다락방', '양평', '정원', '배경', '펜션', '한강', '엔틱'],
#  ['강서', '신혼'],
#  ['코지', '강서구', '심플', '블랙', '서울', '네츄럴', '공간', '화이트'],
#  ['영상', '찍기', '신촌역', '걱정', '강연', '소음', '신촌', '모임', '장소', '촬영', '세미나'],
#  ['가게', '거진항', '건어물', '강원도'],
#  ['바다', '강원도', '펜션'],
#  ['소규모', '개인', '강의', '모임', '쇼룸', '클래스', '촬영', '공간', '이벤트', '세미나', '전시'],
#  ['영상', '회의실', '바이럴', '강남', '촬영', '강의실', '작은방'],
#  ['강연', '주택', '강의', '클래스', '강남', '촬영', '강의실', '세미나'],
#  ['강화', '최고', '이사', '반딧불', '자연', '천국', '가재', '최고급', '촬영', '강화도', '연속', '진돗개'],
#  ['교회', '양관', '강화도', '기독교'],
#  ['렌탈', '방송', '부스', '개인', '방음', '대여', '버스'],
#  ['분위기', '카페', '개인', '고척동', '구로'],
#  ['카페', '개인', '복층', '분위기'],
#  ['카페', '애견', '개인', '철길', '송정', '폐역'],
#  ['심플', '카페', '개인', '동네', '모던', '작고'],
#  '영화',
#  '스몰',
#  '인근',
#  '중고서점',
#  '국제',
#  '웨딩',
#  '전주',
#  '문화',
#  '영화제',
#  '환갑',
#  '공간',
#  '돌잔치',
#  '유니클로',
#  '원룸',
#  '교육방송',
#  '건물',
#  '마을',
#  '알라딘',
#  '대전',
#  '오피스텔',
#  '미술',
#  '파티',
#  '거리',
#  '사무실',
#  '기린',
#  '위치',
#  '상가',
#  '전시',
#  '작업실',
#  '화가',
#  '인테리어',
#  '창가',
#  '조명',
#  '건물',
#  '포토',
#  '수준',
#  '작품',
#  '갤러리',
#  '명의',
#  '중앙',
#  '위치',
#  '그래퍼',
#  '스튜디오',
#  '각각',
#  '안양천',
#  ['셔터', '조명', '루버', '대리석', '갤러리', '아파트', '거실', '전망', '유럽'],
#  ['경의선', '독립', '작업실', '홍대', '책방', '서교동', '갤러리', '서점', '책거리'],
#  ['분위기', '병원', '카페', '에스테', '갤러리', '미용실', '공간'],
#  ['갤러리', '골드', '럭셔리', '카페'],
#  ['농가', '화가', '주택', '정원', '갤러리', '시골', '마당'],
#  ['작업실', '기원', '전통', '송년', '카페', '바둑', '갤러리', '찻집', '모임', '피로연', '대여', '돌잔치'],
#  ['책방', '카페', '북카페', '어린이', '정원', '벽난로', '갤러리', '서점'],
#  ['갤러리', '작업실', '연습실'],
#  ['회의', '강연', '갤러리', '원데이', '모임', '클래스', '세미나', '전시회'],
#  ['회의', '워크샵', '강연', '갤러리', '촬영', '세미나', '전시회'],
#  ['마루', '홍대', '나무', '합정동', '바닥', '빌라', '거실'],
#  ['마루', '홍대', '나무', '합정동', '바닥', '빌라', '거실'],
#  ['해방촌', '주택', '남산', '옥상', '다가', '거실', '루프'],
#  ['거실', '아파트', '북카페'],
#  ['거실', '일산', '주택'],
#  ['거실', '일산', '주택'],
#  ['거실', '중정'],
#  ['거실', '파티'],
#  ['거실', '햇살'],
#  ['분위기', '주방', '빌라', '거실', '모던'],
#  ['주방', '미니', '블랙', '남향', '아이방', '거실', '화이트', '서재', '여자'],
#  ['조명', '가구', '원목', '맛집', '아이방', '기린', '아파트', '햇살', '거실', '석양', '서재'],
#  ['경기도', '화초', '공원', '우드', '가정', '아파트', '그림', '느낌', '거실', '호수', '구조'],
#  ['경기도', '화초', '공원', '우드', '가정', '아파트', '그림', '느낌', '거실', '호수', '구조'],
#  ['가정', '정원', '잡지', '거실', '화이트', '모던', '베란다'],
#  ['심플', '키즈', '우드', '맛집', '테리어', '살림', '햇살', '하우스', '거실', '화이트', '감성', '플랜'],
#  ['영화',
#   '운동',
#   '자연',
#   '기구',
#   '주택',
#   '빌라',
#   '커튼',
#   '실내',
#   '일반',
#   '느낌',
#   '촬영',
#   '거실',
#   '공간',
#   '장소'],
#  ['앞펜션', '거제도', '제일', '바다'],
#  ['라마', '럭셔리', '거제도', '특급', '호텔', '오션', '수영장', '거제', '장소', '촬영', '공간', '경남'],
#  ['라마', '럭셔리', '특급', '호텔', '오션', '수영장', '거제', '장소', '촬영', '공간', '경남'],
#  ['라마', '럭셔리', '휴가', '특급', '호텔', '오션', '수영장', '거제', '장소', '촬영', '공간', '경남'],
#  ['라마', '럭셔리', '휴가', '특급', '호텔', '오션', '수영장', '거제', '장소', '촬영', '공간', '경남'],
#  ['화장실', '투룸빌', '자취', '투룸', '미니', '테라스', '빌라', '화이트'],
#  ['화장실', '투룸빌', '자취', '투룸', '미니', '테라스', '빌라', '화이트'],
#  ['건축',
#   '경산',
#   '건축가',
#   '강판',
#   '사무실',
#   '블럭',
#   '시멘트',
#   '북카페',
#   '건축사',
#   '마당',
#   '대구',
#   '구로',
#   '내부'],
#  ['고양이', '주택', '게러', '창고', '차고', '오피스'],
#  ['세미나',
#   '회신',
#   '영화',
#   '거리',
#   '해운대',
#   '워크숍',
#   '바다',
#   '회송',
#   '부산',
#   '동백섬',
#   '년회',
#   '게스트하우스',
#   '망년'],
#  ['코지', '공원', '다락방', '마당', '하우스', '낙산', '게스트하우스', '작고'],
#  ['홍대', '파티', '입구', '민박', '주택', '서울', '호스텔', '펜션', '게스트하우스'],
#  ['로비', '칵테일', '카페', '호텔', '라운지', '호스텔', '종로', '게스트하우스'],
#  ['경기도', '일산동', '경기', '고양시', '복층', '빌라'],
#  ['경기', '성남', '분당', '영화', '화보', '장소', '촬영'],
#  ['경기', '심플', '미니', '빈티', '원목', '가정', '뉴트', '레트로', '화이트'],
#  ['경기도', '우드', '테리어', '수영장', '테라스', '느낌', '마당', '잔디', '아이', '플랜'],
#  ['경기도', '성남', '기지역', '수도권', '성남동'],
#  ['경기도', '모던', '장소', '촬영', '신혼집', '대여'],
#  ['경기도', '일산', '화보', '자연', '대관', '키친', '오픈', '쿠킹', '잡지', '촬영'],
#  ['경기도', '드라마', '하남', '아파트', '촬영', '내츄럴'],
#  ['경기도', '용인', '드라마', '광교', '재연', '홈쇼핑', '뷰티', '새집', '촬영', '호수', '방송'],
#  ['경기도', '주차', '자연', '채광', '은방', '가능', '햇빛', '빌라', '광주'],
#  ['경기도', '광고', '광주시', '로봇', '가성', '촬영', '엑스', '제품', '호리'],
#  ['경기도', '심플', '주방', '가정', '남양주', '하우스', '모던'],
#  ['경기', '원룸', '심플', '신축', '네츄럴', '야당', '파주', '모던'],
#  ['웅상', '사무실', '양산', '소품', '경남'],
#  ['동반', '맥주', '경리', '수제', '칵테일', '카페', '애견', '스낵바', '디저트', '이태원'],
#  ['파티', '자연', '대관', '쿠킹', '경복궁', '서울', '클래스'],
#  ['미술', '생활', '작업실', '작품', '공간', '전시'],
#  ['산길', '등산로', '텃밭', '계곡', '산장', '정원', '별장', '시골'],
#  ['해방촌', '주택', '남산', '옥상', '계단', '다가', '루프'],
#  ['해방촌', '주택', '남산', '옥상', '계단', '다가', '루프'],
#  ['럭셔리', '메그', '레트로', '벽난로', '계단', '책장', '피아노', '모던'],
#  ['럭셔리', '메그', '레트로', '벽난로', '계단', '책장', '피아노', '모던'],
#  ['계단', '옥탑', '주택', '옥상'],
#  ['식탁', '조명', '시계', '계단', '복층', '샹들리', '쇼파', '스탠드'],
#  ['가구', '계단', '복층', '테라스', '유니크', '구조'],
#  ['잠실', '나무', '다락방', '주택', '원목', '계단', '복층', '느낌', '빌라', '하우스', '구조'],
#  ['중후', '분위기', '가구', '빈티', '어르신', '담소', '클래식', '장소', '서재'],
#  ['중후', '분위기', '가구', '빈티', '어르신', '담소', '클래식', '장소', '서재'],
#  ['백지장', '신도림', '갤러리', '가옥', '모임', '촬영', '루프', '전시'],
#  ['탁트인', '해운대', '고급', '부산', '유리', '전망'],
#  ['고급', '빌라'],
#  ['미니', '원목', '고급', '주택', '갤러리', '테이블', '테라스', '빌라', '풍경', '그림'],
#  ['코팅', '주택', '웨인', '마당', '목조', '제주도'],
#  ['와인', '복층'],
#  ['호수', '아파트', '고급', '화이트'],
#  ['광고', '주택', '고급', '정원', '대형', '촬영', '루프'],
#  ['고기', '소고기', '한식당', '삼겹살'],
#  '고양이',
#  '나름',
#  '가정',
#  '일반',
#  ['분위기', '고양이', '애견', '카페', '러블리'],
#  ['고양이', '아기', '모델', '갈고'],
#  ['독채', '주택', '군산', '리플', '시골', '풍경'],
#  ['독채', '주택', '군산', '리플', '시골', '풍경'],
#  ['고층', '아파트', '해변', '바다'],
#  ['노을', '웰시', '청주', '고층', '아파트', '야경', '석양', '불빛'],
#  ['강조', '고층', '전경', '아파트', '도시', '용산'],
#  ['산조', '북한', '신축', '고층', '아파트'],
#  ['고층', '아파트'],
#  ['고층', '아파트'],
#  ['고층', '아파트'],
#  ['고층', '아파트'],
#  ['시흥', '바다', '고층', '아파트', '소형', '석양', '전망'],
#  ['남향', '대교', '바다', '고층', '아파트', '아주', '송도국제도시', '인천'],
#  ['심플', '블랙', '고층', '아파트', '화이트', '모던'],
#  ['고층', '아파트', '채광', '인천'],
#  ['고층', '아파트', '자연', '정원'],
#  ['나주', '고택'],
#  ['레트로', '옛날', '게스트하우스', '고택'],
#  ['레트로', '옛날', '게스트하우스', '고택'],
#  ['나무', '빈티', '주택', '고택', '옛날', '레트로'],
#  ['나무', '빈티', '주택', '고택', '옛날', '레트로'],
#  ['일산', '심플', '골드', '블루', '모던'],
#  ['카페', '골목길', '분위기'],
#  ['영상', '아트', '공소', '백지장', '공유', '클래스', '촬영', '공간', '문래'],
#  ['회의실', '테디', '워크샵', '촬영장', '한남동', '장소', '공간', '루프', '대여', '오피스'],
#  ['마포', '공덕', '염리동'],
#  '선호',
#  '평일',
#  '문의',
#  '가능',
#  '공덕역',
#  '오피스텔',
#  '날짜',
#  ['소규모', '렌탈', '독서', '쇼핑몰', '대관', '공릉', '모임', '장소', '촬영', '공간', '대여'],
#  ['꽃차', '공유', '오픈', '주방'],
#  ['학원', '보습', '공부', '학생'],
#  ['파티', '부방', '모임', '스타', '디룸', '아파텔', '공간', '생일'],
#  ['공부', '여유', '거실', '서재', '아이'],
#  ['공터', '사장'],
#  ['파티', '콘서트', '촬영', '공연', '연주회', '연극', '세미나'],
#  ['조명', '중계', '라이브', '스트림', '올인원', '공연', '카메라', '음향'],
#  ['무대', '리허설', '공연', '촬영', '공간'],
#  ['무대', '리허설', '공연', '촬영', '공간'],
#  ['파티', '공연장', '무대', '연습실'],
#  ['소규모', '작업실', '사무실', '공연장', '디자인'],
#  ['홍대', '드라마', '공원', '광고', '벚꽃', '장소', '단풍', '대여'],
#  '중문',
#  '공원',
#  '자동',
#  '아파트',
#  '거실',
#  '바로',
#  ['고깔', '아파트', '공원', '복층'],
#  '촬영',
#  '스튜디오',
#  '가정',
#  ['렌탈', '주방', '키친', '쿠킹', '역삼동', '공유', '클래스', '역삼', '강남'],
#  ['사무실', '촬영', '가능', '야외', '동시', '공장'],
#  ['공장', '렌탈', '파주', '대형'],
#  ['책책', '공주', '아이'],
#  ['과천', '목조', '주택', '마당'],
#  ['영화', '화보', '광고', '장소', '촬영'],
#  ['홍대', '드라마', '광고', '숙소', '정원', '호스텔', '테라스', '장소', '마당', '대여', '게스트하우스'],
#  ['촬영', '광고', '가능', '드라마'],
#  ['광고', '세차장', '자동차', '촬영', '디테', '일링', '광택'],
#  ['화보', '광고', '클래식', '갤러리', '촬영', '화이트', '신혼집', '북유럽'],
#  ['화보', '광고', '클래식', '갤러리', '촬영', '화이트', '신혼집', '북유럽'],
#  ['식탁', '소파', '광고', '복층', '촬영'],
#  ['식탁', '소파', '전신', '거울', '광고', '복층', '촬영', '식물'],
#  ['식탁', '소파', '전신', '거울', '광고', '복층', '촬영', '식물'],
#  ['드라마', '분위기', '광고', '채광', '촬영'],
#  ['가득', '오븐', '주방', '광고', '키친', '우드', '요리', '햇살', '다이닝', '촬영', '명품'],
#  ['신축', '광교', '광고', '모던', '아파트', '촬영', '신혼집'],
#  ['수원', '컨벤션', '공원', '광교', '호수'],
#  ['주택', '광명', '대여', '옥상'],
#  ['주택', '광명', '대여', '옥상'],
#  ['광안', '해변', '부산', '바다'],
#  ['광안', '소품', '부산', '화보'],
#  ['심플', '미니', '광역시', '라이프', '화이트', '광주', '모던'],
#  ['광화문', '모던', '전망', '클래식'],
#  ['광흥창', '마포'],
#  ['수동', '서강대'],
#  ['소규모', '부방', '모임', '교습', '장소'],
#  ['분위기', '테리어', '식물', '교통', '플랜'],
#  ['이벤트', '파티', '디지털', '대관', '카페', '모임', '장소', '촬영', '단체', '구로'],
#  ['디지털', '심플', '신축', '단지', '커튼', '대림역', '하우스', '모던', '구로'],
#  ['합정동', '구옥'],
#  ['빈티', '주택', '원목', '구옥', '브이', '레트로', '식물', '로그'],
#  ['기숙사', '글로벌', '스터디', '서울', '라운지', '국제'],
#  ['뮤직', '까페', '군산', '라이브'],
#  ['뮤직', '까페', '군산', '라이브'],
#  ['귀촌', '고양이', '귀농', '시골', '논밭'],
#  ['귤밭', '주택', '제주도'],
#  ['음악학', '대치동', '뮤직', '레슨', '아파트', '학원', '피아노', '첼로', '은마', '그랜드피아노'],
#  ['럭셔리', '주방', '고급', '대리석', '놀이', '거실', '안방', '모던', '그랜드피아노'],
#  ['조적', '산조', '어린이', '욕실', '그레이', '놀이터', '모던'],
#  ['심플', '전면', '그레이', '화이트', '모던', '전망'],
#  ['소파', '그레이', '하우스', '천안', '모던'],
#  ['아치', '심플', '모던', '영등포', '그레이', '신혼집'],
#  ['아치', '심플', '모던', '영등포', '그레이', '신혼집'],
#  '너리',
#  '화이트',
#  '공존',
#  '공간',
#  ['화초', '저녁놀', '손때', '정원', '그린', '식물', '베란다'],
#  ['도자기', '조명', '빈티', '액자', '늑한', '공간', '그림'],
#  '주차공간',
#  '도자기',
#  '청주',
#  '구성',
#  '단지',
#  '작품',
#  '정원',
#  '조성',
#  '아파트',
#  '활용',
#  '공간',
#  '지역',
#  '그림',
#  '경기도',
#  '골프장',
#  '풍경',
#  '한성',
#  '탁트인',
#  '수욜',
#  '이용',
#  '시야',
#  '아침',
#  '실내',
#  '미술품',
#  '시간',
#  '아파트',
#  '저녁',
#  '위치',
#  '최고급',
#  '월욜',
#  '그림',
#  ['글램핑', '파티', '웨딩', '미팅', '스몰', '대관', '스터디', '촬영', '루프'],
#  ['글램핑', '파티', '웨딩', '미팅', '스몰', '대관', '스터디', '촬영', '루프'],
#  ['캠핑', '글램핑', '바다'],
#  ['캠핑', '글램핑', '바다'],
#  ['기와집', '수원', '운동장', '대학생', '엠티', '수련', '수영장', '시골', '단체'],
#  ['찻길', '아기', '우드', '복합', '클래식', '주상', '공간', '모던'],
#  ['햇살', '공원', '복도'],
#  ['김포', '아파트', '구래동'],
#  ['김포', '아파트', '구래동'],
#  ['김포', '한강', '신도시'],
#  ['마당', '김포', '화이트'],
#  ['씨티', '조명', '빈티', '남산', '아파트', '복층', '느낌', '까페'],
#  ['마포', '참견', '신촌', '서울', '아파트', '확장', '연애', '베란다'],
#  ['와인', '파티', '바닥', '대리석'],
#  '기흥구',
#  '한성',
#  '전체',
#  '개중',
#  '샤워',
#  '아이방',
#  '공간활용',
#  '시간',
#  '아파트',
#  '욕조',
#  '촬영',
#  '전망',
#  '바로',
#  '경기도',
#  '에어컨',
#  '화장실',
#  '용인시',
#  '부스',
#  '지하',
#  '벚꽃',
#  '나머지',
#  '안방',
#  '화이트',
#  '공간',
#  '골프장',
#  '선호',
#  '미니멀리즘',
#  '구조',
#  '분위기',
#  '추구',
#  '놀이터',
#  '물건',
#  '주차',
#  '거리',
#  '오후',
#  '평일',
#  '전부',
#  '마북동',
#  '아침',
#  '위치',
#  '동네',
#  '침대',
#  '거실',
#  '쇼파',
#  '모던',
#  '근처',
#  ['심플', '신축', '미니', '아파트', '안방', '침실', '모던'],
#  ['아파트', '모던', '송도'],
#  ['탄천', '아파트', '분당', '인근'],
#  ['싱글', '라이프', '아파트'],
#  ['수동', '마포구'],
#  ['주방', '원목', '스코프', '책장', '느낌', '테이블', '쇼파', '아이'],
#  ['화이트하우스', '화이트', '마크'],
#  ['하우스', '모던', '심플'],
#  ['심플', '신혼'],
#  ['심플', '신혼'],
#  ['카페', '파주', '맛집', '케이크', '디저트', '운정'],
#  ['음악', '인공', '폭포', '바베큐', '패치', '정원', '구장', '야외', '테라스', '촬영'],
#  ['마당', '정원'],
#  ['텃밭', '천지', '정원', '별장', '수국', '잔디'],
#  ['나무', '반려견', '가구', '테라스', '공간', '유니크'],
#  ['뒷산', '나무', '전원', '연못', '정원', '밤나무', '마당', '논밭', '그네'],
#  ['촬영', '해방촌', '주택', '나무'],
#  ['나무', '빈티', '주택', '고택', '옛날', '레트로', '하우스'],
#  ['나무', '빈티', '주택', '고택', '옛날', '레트로', '하우스'],
#  '모두',
#  '분위기',
#  '평일',
#  '주말',
#  '오피스텔',
#  '사람',
#  '사전예약',
#  '시간',
#  '연결',
#  '느낌',
#  '표현',
#  '대중교통',
#  '서울',
#  '말씀',
#  '구애',
#  '이용도',
#  '주차장',
#  '크게',
#  '생활',
#  '감각',
#  '소품',
#  '사전',
#  '마포',
#  '주시',
#  '컬러풀',
#  '개인',
#  '이용권',
#  '화면',
#  '위치',
#  '공덕역',
#  '해주시',
#  '날짜',
#  '미리',
#  '예약',
#  '언제',
#  '풍부',
#  '실감',
#  '한직',
#  '촬영',
#  '오피스텔',
#  ['빌라', '가정', '룸빌'],
#  ['시티', '해방촌', '루프'],
#  ['마을', '필동', '남산', '원룸'],
#  ['자취', '원룸', '저취방', '유리창', '복층', '구조'],
#  ['홍대', '동교동', '원룸', '서울시'],
#  ['자취', '원룸', '드라마', '직장인', '바이럴', '동대문', '여자'],
#  ['일산', '원룸', '킨텍스', '아파트', '복층', '백석역', '모던', '북유럽'],
#  ['일산', '원룸', '킨텍스', '아파트', '복층', '모던'],
#  ['파티', '심플', '복합', '주상', '모던', '베란다'],
#  '인테리어',
#  '거울',
#  '고층',
#  '복층',
#  '위치',
#  '이태리',
#  '가죽',
#  '오피스텔',
#  '종각역',
#  ['평택', '원룸', '분위기', '카페', '햇빛', '식물'],
#  ['빈티', '원룸'],
#  ['연세대', '신촌', '서강대', '이대'],
#  ['일산', '자취', '원룸'],
#  ['촬영', '원룸', '장소', '대관'],
#  ['운동',
#   '광고',
#   '정원',
#   '색공간',
#   '요가',
#   '데크',
#   '홀로',
#   '휴양림',
#   '공간',
#   '작가',
#   '단체',
#   '휴식',
#   '의방'],
#  ['자취', '원룸', '미니', '남산', '서울', '셀프', '테라스', '데이', '분리', '베드'],
#  ['작업실', '확보', '사무실', '시야', '의정부', '전경', '촬영', '공간'],
#  ['마루', '서울역', '남산', '후암동'],
#  ['영화', '광고', '남산', '후암동', '인더스트리얼', '촬영', '식물', '서울역', '전망'],
#  ['타워', '채광', '후암동', '야경', '빌라', '루프'],
#  ['산조', '북한', '공사', '상암', '정체', '여의도', '차량', '안양천'],
#  ['노을', '심플', '남서', '맛집', '사진', '석양', '오늘'],
#  ['남양주', '수산', '수동면'],
#  ['테리어', '햇살', '동네', '남양주', '식물', '공간', '신혼집', '플랜'],
#  ['운집', '진접', '낭만', '벽난로', '마당', '남양주', '그네'],
#  ['강변', '북한', '청평댐', '리버', '뷰강', '낚시', '체험', '보트', '자라섬', '남이섬'],
#  ['바지선', '포리', '양평', '어업', '추읍산', '산수유', '축제', '상자', '한강', '용배'],
#  '남면',
#  '주방',
#  '장판',
#  '항구',
#  '촬영장',
#  '싱크대',
#  '창고',
#  '화장실',
#  '텃밭',
#  '주거',
#  '바다',
#  '소로',
#  '남해',
#  '임대',
#  '교체',
#  '별채',
#  '언덕',
#  '마을',
#  '도배',
#  '시골',
#  '작은방',
#  '게스트',
#  '구조',
#  ['더블', '자연', '채광', '남향', '도보', '신답역', '아이방', '거실', '아이'],
#  ['영상', '홍대', '자연', '채광', '가정', '연남동', '느낌', '촬영', '화이트', '내추럴'],
#  ['빈티', '내추럴', '코지'],
#  ['작업실', '자연', '노출', '빈티', '시골', '내츄럴', '풍경', '감성'],
#  ['마루', '빈티', '채광', '원목', '내츄럴', '화이트'],
#  ['마루', '빈티', '채광', '원목', '내츄럴', '화이트'],
#  ['냇물', '물놀이', '산속', '바베큐', '주택', '테라스', '시골', '마당', '풍경'],
#  '선호',
#  '조정',
#  '오후',
#  '조명',
#  '가정',
#  '시간',
#  '가능',
#  '운치',
#  '햇살',
#  '요일',
#  '오전',
#  '거실',
#  '인테리어',
#  '유럽',
#  ['럭셔리', '주방', '촬영장', '가정', '소대', '사진', '촬영', '거실', '쇼파', '침실'],
#  ['마당', '공간', '구조', '복층'],
#  ['청도', '연못', '정원', '기와', '데크', '마당', '나무숲'],
#  ['사찰', '노을', '동산', '분위기', '카페', '저녁', '장소', '도심', '주차장'],
#  ['풍경', '파티', '지역', '공기', '청정', '정원', '맑은', '가든'],
#  ['심플', '주방', '미니', '원목', '우드', '아이방', '거실', '화이트', '침실', '감성'],
#  ['청주', '물씬', '전통', '한국', '느낌', '주차장'],
#  ['주변', '미니', '리스트', '화이트', '한강'],
#  ['주변', '미니', '리스트', '화이트', '한강'],
#  ['유러', '코지', '네추럴', '심플'],
#  ['시공간', '주방', '미니', '채광', '츄럴', '아이방', '거실', '하우스', '전망'],
#  ['대나무', '작업실', '건축', '노출', '사무소', '카페', '원목', '디자인', '테이블'],
#  ['녹번', '가정'],
#  ['전주', '아파트', '놀이터', '소형', '쇼파', '베란다'],
#  ['농가', '나무', '주택', '촬영', '시골', '모델링', '강아지'],
#  ['동산', '산속', '보은', '오두막', '정원', '매실', '농장', '마당', '시크릿', '잔디'],
#  ['미니', '천장', '쿠킹', '욕실', '화이트', '모던'],
#  ['미니', '천장', '쿠킹', '욕실', '화이트', '모던'],
#  ['디제이', '타워', '주차', '지하', '클럽'],
#  ['코지', '노출', '모던', '주택', '가정', '계단', '테라스', '유리'],
#  ['빈집', '주택', '아파트', '도시', '다가', '상가', '구조'],
#  ['소규모', '대관', '카페', '아늑', '골목', '다다', '모임', '촬영', '독서'],
#  ['다락방', '아파트', '테라스', '복층', '전망'],
#  ['용인', '단국대', '보정동', '아파트', '소형', '죽전역', '추천', '근처'],
#  ['홍대', '신촌', '옥상', '연남동', '연희동', '야경', '야외', '단독', '유리', '전망'],
#  ['단독', '주택', '판교', '유럽'],
#  ['파티', '쇼핑몰', '비용', '터링', '촬영', '장소', '케이', '단독', '공간', '사용'],
#  ['화보', '자연', '광렌탈', '광고', '옥상', '도시', '강남'],
#  ['화보', '자연', '광렌탈', '광고', '정원', '도시', '강남'],
#  ['파티', '반려견', '애견', '정원', '수영장', '다이닝', '마당', '루프', '잔디'],
#  ['파티', '반려견', '애견', '정원', '수영장', '다이닝', '마당', '루프', '잔디'],
#  ['마당', '파주', '모던'],
#  ['마당', '파주', '모던'],
#  ['마당', '빈티', '화곡동'],
#  ['마당', '빈티', '화곡동'],
#  ['안개', '산속', '무주군', '주택', '장수군', '마당', '공간'],
#  ['마당', '텃밭', '마을', '시골'],
#  ['마당', '텃밭', '마을', '시골'],
#  ['파주', '모던'],
#  ['심플', '드라마', '조명', '빈티', '우드', '사진', '디자인', '망원동', '화이트', '환영'],
#  '언제',
#  '촬영',
#  '위치',
#  '외관',
#  '마당',
#  '대구',
#  '단독주택',
#  ['주택', '정원', '인천'],
#  ['주택', '정원', '인천'],
#  ['화보', '광렌탈', '자연', '광고', '빈티', '정원', '도시', '강남'],
#  ['가득',
#   '기와집',
#   '고삼',
#   '저수지',
#   '감나무',
#   '맛집',
#   '대들보',
#   '정성',
#   '야외',
#   '시골',
#   '촬영',
#   '조경',
#   '잔디'],
#  ['가득',
#   '기와집',
#   '고삼',
#   '저수지',
#   '감나무',
#   '맛집',
#   '대들보',
#   '정성',
#   '야외',
#   '시골',
#   '촬영',
#   '조경',
#   '잔디'],
#  ['분위기', '주방', '국적', '채광', '아동복', '우드', '마당', '촬영', '화이트'],
#  ['나무', '네추럴', '조명', '주말', '촬영', '욕실', '욕조', '느낌', '마당', '거실', '감성'],
#  ['산정', '북한', '광고', '뉴타운', '마을', '은평', '진관동'],
#  ['렌탈', '화보', '자연', '대관', '광고', '촬영장', '장소', '촬영', '공간', '대여', '레이스'],
#  ['의정원', '강변', '숲속', '단양'],
#  ['의정원', '강변', '숲속', '단양'],
#  ['독채', '근교', '정원', '서울', '수영장', '별장', '수도권', '펜션', '단체', '잔디'],
#  ['한식당', '모임', '식당', '대형', '단체'],
#  ['홍대', '안주', '분위기', '보라', '필수', '코스', '술집', '맛집', '데이트', '단체', '회식'],
#  '중대',
#  '상호',
#  '경희대',
#  '협의',
#  '사용',
#  '흡연실',
#  '애니',
#  '삼거리',
#  '구장',
#  '대대',
#  '가능',
#  '장소',
#  '음료',
#  '공간',
#  '휴식',
#  '완비',
#  ['주차', '화장실', '보관', '사무실', '단기', '채광', '가능', '임대', '당산', '숙박'],
#  ['파티', '쇼핑몰', '대관', '카페', '촬영', '파주', '연말', '감성'],
#  ['파티', '요리', '침대', '촬영', '공간', '대구', '대여', '동성로'],
#  ['파티', '요리', '침대', '촬영', '공간', '대구', '대여', '동성로'],
#  ['파티', '분위기', '주택', '브라', '원데이', '모임', '클래스', '화이트', '대구'],
#  ['주택', '대구', '두산동'],
#  ['주방', '아이방', '대전', '아파트', '거실', '안방'],
#  ['유성구', '아파트', '노은동', '전시'],
#  ['대청', '마루', '도독', '제주', '정원', '채팬션', '시골', '잔디', '돌담', '제주도'],
#  ['원룸', '위치', '대학로'],
#  ['서비스', '영상', '렌탈', '발렛', '촬영', '사거리', '대형', '학동', '호리'],
#  ['대화역', '작업실', '사운드', '음향'],
#  ['댄스', '운동'],
#  ['댄스', '영상', '홍대', '대관', '연습', '합정', '연습실', '촬영', '안무'],
#  ['댄스', '영상', '홍대', '대관', '연습', '합정', '연습실', '촬영', '안무'],
#  ['맥주', '분위기', '카페', '술집', '데이트', '아지트'],
#  ['소나무', '바베큐', '정원', '벽난로', '데크', '마당'],
#  ['고급', '아기', '데크', '빌라', '유니크', '아이'],
#  ['주차', '용이', '전통', '가구', '도보', '한국', '정원', '가능', '테라스', '이태원'],
#  ['심플', '신축', '우드', '아파트', '도심', '화이트', '한강'],
#  ['빈집', '마포', '공덕', '복합', '주상', '독신남'],
#  ['미니', '블랙', '건축가', '빈티', '가구', '독일', '화이트'],
#  ['주택', '구조'],
#  ['카페', '주택', '연남동', '연희동', '구조', '유럽'],
#  ['철거', '사무실', '분위기'],
#  ['가득', '드라마', '광고', '채광', '원목', '컬러', '잡지', '촬영', '거실', '공간'],
#  ['동산', '카페', '제주', '인근', '감귤', '마을', '돌집', '과수원', '시골', '마당', '돌담'],
#  ['원룸', '대관', '아파트', '촬영', '공간', '동대문', '대여'],
#  ['화공', '빈티', '침대', '테이블', '벽돌', '하우스'],
#  ['옵션', '원룸'],
#  ['해변',
#   '평일',
#   '카페',
#   '이용',
#   '건물',
#   '개인',
#   '전경',
#   '가능',
#   '카폐',
#   '장소',
#   '보유',
#   '촬영',
#   '자랑',
#   '전망'],
#  ['미국', '경리', '빈티', '고동', '동빙', '차고', '마당', '이태원'],
#  ['아치', '중문', '나무', '프렌치', '조명', '욕실', '스타일', '햇살', '판교', '소품', '올리브'],
#  ['아치', '중문', '나무', '프렌치', '조명', '욕실', '스타일', '햇살', '판교', '소품', '올리브'],
#  ['드림', '영통', '모두', '남자', '쭈꾸미', '행복', '맛집', '한식당'],
#  ['홍대', '드라마', '분위기', '사격장', '대관', '술집', '모임', '장소', '촬영', '회식'],
#  ['홍대', '드라마', '분위기', '사격장', '대관', '술집', '모임', '장소', '촬영', '회식'],
#  ['영화', '럭셔리', '드라마', '대관', '광고', '주택', '고급', '정원', '회장', '촬영', '임대', '하우스'],
#  ['영화', '쇼핑몰', '드라마', '대관', '빈티', '잡지', '촬영', '하우스', '옷가게', '감성', '유럽'],
#  ['유튜버', '홍대', '입구', '드라마', '신촌', '전문', '촬영', '튜버'],
#  '주변',
#  '제외',
#  '이용',
#  '시야',
#  '왕숙천',
#  '광릉',
#  '마음',
#  '수목원',
#  '주중',
#  '햇볕',
#  ['작업실', '기계', '가구', '빈티', '목공', '공구', '디자인', '소품'],
#  ['사무실', '모던', '디자인'],
#  ['사무실', '소호', '모던', '디자인'],
#  ['사무실', '서재', '북카페', '디자인'],
#  ['시공간', '문구', '갤러리', '모임', '디자인', '소품', '공간'],
#  ['소규모', '코지', '키덜트', '규어', '사무실', '매니아', '디자인', '아지트', '오피스'],
#  ['촬영', '하우스', '디자인'],
#  '뱅뱅',
#  '부근',
#  '디제잉',
#  '강남역',
#  '사거리',
#  '위치',
#  '연습실',
#  '양재',
#  '뱅뱅',
#  '부근',
#  '디제잉',
#  '강남역',
#  '사거리',
#  '위치',
#  '연습실',
#  '양재',
#  ...]

# %% [markdown]
# ## wordcloud
#     단어간 유사도

# %%
from gensim.models import word2vec

num_features = 300    # Word vector dimensionality                      
min_word_count = 10   # Minimum word count                        
num_workers = 2     # Number of threads to run in parallel
context = 4          # Context window size                                                                                    
downsampling = 1e-3  # Downsample setting for frequent words

model = gensim.models.Word2Vec(CoreTagDate, workers=num_workers, 
                          size=num_features, min_count = min_word_count,
                          window = context, sample = downsampling)

model_name = "TagSimilarity"
model.save(model_name)

# %%
# model.wv.vocab
model.wv.most_similar("원목",topn=5)
# Out:
# [('자연', 0.26361364126205444),
#  ('느낌', 0.2331203818321228),
#  ('대관', 0.2019938975572586),
#  ('신축', 0.20067569613456726),
#  ('우드', 0.1839878112077713)]

# %%
{'홍대': <gensim.models.keyedvectors.Vocab at 0x26c82b1e788>,
 '원룸': <gensim.models.keyedvectors.Vocab at 0x26c82b1e588>,
 '클래식': <gensim.models.keyedvectors.Vocab at 0x26c82b1ec48>,
 '빌라': <gensim.models.keyedvectors.Vocab at 0x26c82b1e888>,
 '모던': <gensim.models.keyedvectors.Vocab at 0x26c82b1ed48>,
 '자연': <gensim.models.keyedvectors.Vocab at 0x26c82b1ea88>,
 '전망': <gensim.models.keyedvectors.Vocab at 0x26c82b1e108>,
 '벽난로': <gensim.models.keyedvectors.Vocab at 0x26c82b1e508>,
 '루프': <gensim.models.keyedvectors.Vocab at 0x26c82b1e048>,
 '신축': <gensim.models.keyedvectors.Vocab at 0x26c82b1ed88>,
 '가정': <gensim.models.keyedvectors.Vocab at 0x26c82b1ed08>,
 '아파트': <gensim.models.keyedvectors.Vocab at 0x26c82b1e4c8>,
 '분위기': <gensim.models.keyedvectors.Vocab at 0x26c82b552c8>,
 '카페': <gensim.models.keyedvectors.Vocab at 0x26c82b55908>,
 '신혼집': <gensim.models.keyedvectors.Vocab at 0x26c82b55148>,
 '강남': <gensim.models.keyedvectors.Vocab at 0x26c82b55208>,
 '자취': <gensim.models.keyedvectors.Vocab at 0x26c82b55888>,
 '가구': <gensim.models.keyedvectors.Vocab at 0x26c82b55408>,
 '광고': <gensim.models.keyedvectors.Vocab at 0x26c82b55188>,
 '서울': <gensim.models.keyedvectors.Vocab at 0x26c82b55cc8>,
 '화이트': <gensim.models.keyedvectors.Vocab at 0x26c82b55248>,
 '아이방': <gensim.models.keyedvectors.Vocab at 0x26c82b55948>,
 '테라스': <gensim.models.keyedvectors.Vocab at 0x26c82b55d88>,
 '복층': <gensim.models.keyedvectors.Vocab at 0x26c82b55448>,
 '대형': <gensim.models.keyedvectors.Vocab at 0x26c82b554c8>,
 '이': <gensim.models.keyedvectors.Vocab at 0x26c82b550c8>,
 '공': <gensim.models.keyedvectors.Vocab at 0x26c82b55348>,
 '간': <gensim.models.keyedvectors.Vocab at 0x26c82b556c8>,
 '화': <gensim.models.keyedvectors.Vocab at 0x26c82b557c8>,
 '실': <gensim.models.keyedvectors.Vocab at 0x26ce02041c8>,
 '빈티': <gensim.models.keyedvectors.Vocab at 0x26ce02042c8>,
 '가능': <gensim.models.keyedvectors.Vocab at 0x26ce0204548>,
 '공간': <gensim.models.keyedvectors.Vocab at 0x26c827970c8>,
 '정원': <gensim.models.keyedvectors.Vocab at 0x26c82797148>,
 '층집': <gensim.models.keyedvectors.Vocab at 0x26c82797688>,
 '소품': <gensim.models.keyedvectors.Vocab at 0x26c82797608>,
 '촬영': <gensim.models.keyedvectors.Vocab at 0x26c82797d48>,
 '아이': <gensim.models.keyedvectors.Vocab at 0x26c82797808>,
 '베란다': <gensim.models.keyedvectors.Vocab at 0x26c82797188>,
 '심플': <gensim.models.keyedvectors.Vocab at 0x26c82797fc8>,
 '공원': <gensim.models.keyedvectors.Vocab at 0x26c82797c88>,
 '우드': <gensim.models.keyedvectors.Vocab at 0x26c82797408>,
 '하우스': <gensim.models.keyedvectors.Vocab at 0x26c82797ec8>,
 '테리어': <gensim.models.keyedvectors.Vocab at 0x26c82797508>,
 '그레이': <gensim.models.keyedvectors.Vocab at 0x26c82797c08>,
 '주방': <gensim.models.keyedvectors.Vocab at 0x26c82797288>,
 '거실': <gensim.models.keyedvectors.Vocab at 0x26c82797888>,
 '원목': <gensim.models.keyedvectors.Vocab at 0x26c82797708>,
 '고급': <gensim.models.keyedvectors.Vocab at 0x26c82797088>,
 '일산': <gensim.models.keyedvectors.Vocab at 0x26c82797788>,
 '주택': <gensim.models.keyedvectors.Vocab at 0x26c827972c8>,
 '영화': <gensim.models.keyedvectors.Vocab at 0x26c82797948>,
 '작업실': <gensim.models.keyedvectors.Vocab at 0x26c827974c8>,
 '셀프': <gensim.models.keyedvectors.Vocab at 0x26c82797a08>,
 '조명': <gensim.models.keyedvectors.Vocab at 0x26c82797dc8>,
 '계단': <gensim.models.keyedvectors.Vocab at 0x26c82797a88>,
 '바다': <gensim.models.keyedvectors.Vocab at 0x26c82797b48>,
 '시골': <gensim.models.keyedvectors.Vocab at 0x26c82797308>,
 '마': <gensim.models.keyedvectors.Vocab at 0x26c82797448>,
 '주': <gensim.models.keyedvectors.Vocab at 0x26c82797048>,
 '시': <gensim.models.keyedvectors.Vocab at 0x26c82797988>,
 '대': <gensim.models.keyedvectors.Vocab at 0x26c82797908>,
 '사': <gensim.models.keyedvectors.Vocab at 0x26c82797f48>,
 '용': <gensim.models.keyedvectors.Vocab at 0x26c82797d88>,
 '정': <gensim.models.keyedvectors.Vocab at 0x26c82797e88>,
 '도': <gensim.models.keyedvectors.Vocab at 0x26c807ff888>,
 '위': <gensim.models.keyedvectors.Vocab at 0x26c807ff788>,
 '가': <gensim.models.keyedvectors.Vocab at 0x26cffe2e888>,
 '장': <gensim.models.keyedvectors.Vocab at 0x26cffe2e0c8>,
 '소': <gensim.models.keyedvectors.Vocab at 0x26cffe2e648>,
 '오': <gensim.models.keyedvectors.Vocab at 0x26cffe2e9c8>,
 '전': <gensim.models.keyedvectors.Vocab at 0x26cffe2e1c8>,
 '지': <gensim.models.keyedvectors.Vocab at 0x26cffeba7c8>,
 '파': <gensim.models.keyedvectors.Vocab at 0x26cffebac48>,
 '미니': <gensim.models.keyedvectors.Vocab at 0x26cffebae48>,
 '파티': <gensim.models.keyedvectors.Vocab at 0x26cffeba248>,
 '바베큐': <gensim.models.keyedvectors.Vocab at 0x26cffeba848>,
 '옥상': <gensim.models.keyedvectors.Vocab at 0x26cffeba908>,
 '마당': <gensim.models.keyedvectors.Vocab at 0x26cffebab08>,
 '나무': <gensim.models.keyedvectors.Vocab at 0x26cff69b7c8>,
 '야외': <gensim.models.keyedvectors.Vocab at 0x26c828115c8>,
 '야경': <gensim.models.keyedvectors.Vocab at 0x26c82811388>,
 '갤러리': <gensim.models.keyedvectors.Vocab at 0x26c82811748>,
 '식물': <gensim.models.keyedvectors.Vocab at 0x26c82811588>,
 '영상': <gensim.models.keyedvectors.Vocab at 0x26cffafd308>,
 '한강': <gensim.models.keyedvectors.Vocab at 0x26c8288cdc8>,
 '서재': <gensim.models.keyedvectors.Vocab at 0x26c8288c148>,
 '부': <gensim.models.keyedvectors.Vocab at 0x26c8288ce88>,
 '아': <gensim.models.keyedvectors.Vocab at 0x26c8288c648>,
 '트': <gensim.models.keyedvectors.Vocab at 0x26cffe76408>,
 '고층': <gensim.models.keyedvectors.Vocab at 0x26cffe76fc8>,
 '구': <gensim.models.keyedvectors.Vocab at 0x26c82c26ec8>,
 '역': <gensim.models.keyedvectors.Vocab at 0x26c82c26bc8>,
 '제': <gensim.models.keyedvectors.Vocab at 0x26c82c26e88>,
 '촬': <gensim.models.keyedvectors.Vocab at 0x26c82c26048>,
 '영': <gensim.models.keyedvectors.Vocab at 0x26c82c26748>,
 '스': <gensim.models.keyedvectors.Vocab at 0x26c82c26988>,
 '방': <gensim.models.keyedvectors.Vocab at 0x26c82c26fc8>,
 '테': <gensim.models.keyedvectors.Vocab at 0x26c82c26d48>,
 '기': <gensim.models.keyedvectors.Vocab at 0x26c82c268c8>,
 '일': <gensim.models.keyedvectors.Vocab at 0x26c82c26948>,
 '인': <gensim.models.keyedvectors.Vocab at 0x26c82c26a48>,
 '조': <gensim.models.keyedvectors.Vocab at 0x26c82c26908>,
 '거': <gensim.models.keyedvectors.Vocab at 0x26cffc60d88>,
 '모임': <gensim.models.keyedvectors.Vocab at 0x26c827b1308>,
 '느낌': <gensim.models.keyedvectors.Vocab at 0x26c827b1448>,
 '가족': <gensim.models.keyedvectors.Vocab at 0x26c827b1a88>,
 '드라마': <gensim.models.keyedvectors.Vocab at 0x26c827b1688>,
 '대여': <gensim.models.keyedvectors.Vocab at 0x26c827b10c8>,
 '경기도': <gensim.models.keyedvectors.Vocab at 0x26c827b1b48>,
 '북유럽': <gensim.models.keyedvectors.Vocab at 0x26c827b1fc8>,
 '장소': <gensim.models.keyedvectors.Vocab at 0x26c827b1c48>,
 '리': <gensim.models.keyedvectors.Vocab at 0x26c827b19c8>,
 '사무실': <gensim.models.keyedvectors.Vocab at 0x26c827b1348>,
 '대관': <gensim.models.keyedvectors.Vocab at 0x26c827b1188>,
 '화보': <gensim.models.keyedvectors.Vocab at 0x26c827b1e08>,
 '개인': <gensim.models.keyedvectors.Vocab at 0x26c827b1048>,
 '사진': <gensim.models.keyedvectors.Vocab at 0x26c827b1608>,
 '감성': <gensim.models.keyedvectors.Vocab at 0x26c827b1888>,
 '렌탈': <gensim.models.keyedvectors.Vocab at 0x26cffe553c8>,
 '어': <gensim.models.keyedvectors.Vocab at 0x26cffe55488>,
 '원': <gensim.models.keyedvectors.Vocab at 0x26cffe55f08>,
 '연': <gensim.models.keyedvectors.Vocab at 0x26cffe55a08>,
 '잔디': <gensim.models.keyedvectors.Vocab at 0x26cffe55388>,
 '럭셔리': <gensim.models.keyedvectors.Vocab at 0x26cffe55d88>,
 '소규모': <gensim.models.keyedvectors.Vocab at 0x26cffe55f88>,
 '펜션': <gensim.models.keyedvectors.Vocab at 0x26c82b60e08>,
 '중': <gensim.models.keyedvectors.Vocab at 0x26c82b60948>,
 '유': <gensim.models.keyedvectors.Vocab at 0x26c82b60e88>,
 '치': <gensim.models.keyedvectors.Vocab at 0x26c82b603c8>,
 '디자인': <gensim.models.keyedvectors.Vocab at 0x26c82b60ac8>,
 '쇼핑몰': <gensim.models.keyedvectors.Vocab at 0x26c82b608c8>,
 '게스트하우스': <gensim.models.keyedvectors.Vocab at 0x26c82b60b08>,
 '채광': <gensim.models.keyedvectors.Vocab at 0x26c82b60f08>,
 '레트로': <gensim.models.keyedvectors.Vocab at 0x26c82b60c08>,
 '맛집': <gensim.models.keyedvectors.Vocab at 0x26c82b60848>,
 '수영장': <gensim.models.keyedvectors.Vocab at 0x26c82b60048>,
 '구조': <gensim.models.keyedvectors.Vocab at 0x26c82b60d08>,
 '연습실': <gensim.models.keyedvectors.Vocab at 0x26c82b60d88>,
 '호리': <gensim.models.keyedvectors.Vocab at 0x26c82b60a88>,
 '광렌탈': <gensim.models.keyedvectors.Vocab at 0x26c82b607c8>,
 '남산': <gensim.models.keyedvectors.Vocab at 0x26c82b60f48>}

# %% [markdown]
# # Clustering

# %% [markdown]
# ## 1. keyword 정제
#     1) 주요 태그 추출
#     - description 내용 포함 태그
#     - description과 일치하는 단어가 없는 태그는 태그 그대로 사용
#     - 태그 없는 187개 스튜디오는 description에서 추출한 단어 사용
#
#      2) 유사 단어 묶어주기
#     - WordCloudVec으로 단어간 유사도 판별
#
#     >> 타겟 스튜디오와 동일한 태그 개수 세기
#
# ## 2. 범주형 데이터 Gower로 수치형 데이터로 변환
#     1) 범주형 데이터는 category와

# %%
import numpy as np 
import pandas as pd 
from pandas import DataFrame as df
import csv
from konlpy.tag import Okt
from collections import Counter

# %%
import os
dataset = pd.read_csv("total_dataset_trim_newTag.csv",encoding='utf-8')
dataset.tail()
# Out:
#       index    NO  img_fold_no  \
# 1847   1847  1804           89
# 1848   1848  1831            1
# 1849   1849  1832            2
# 1850   1850  1840           10
# 1851   1851  1847           17
#
#                                             studio_name  \
# 1847                                              홍대 2룸
# 1848                   경리단길 윤싸롱 3호점 - 채광 굿 깔끔하고 모던한 자취방
# 1849  상수역 6분거리 , 합정역 6분거리 30평급 넓은 공간 자연광 스튜디오 VILLA ...
# 1850                                                 시매
# 1851                                (용산) 채광맛집 예술가의 로프트!
#
#                                          studio_picture  \
# 1847  ['https://s3.hourplace.co.kr/image/user/841/20...
# 1848  ['https://s3.hourplace.co.kr/image/user/6876/2...
# 1849  ['https://s3.hourplace.co.kr/image/user/6691/2...
# 1850  ['https://s3.hourplace.co.kr/image/user/6818/2...
# 1851  ['https://s3.hourplace.co.kr/temp/images/2020/...
#
#                                              imafe_file category region  tag  \
# 1847  ['89_0_홍대_2룸.jpg', '89_1_홍대_2룸.jpg', '89_2_홍대_...       빌라     서울  NaN
# 1848  ['1_0_경리단길_윤싸롱_3호점_-_채광_굿_깔끔하고_모던한_자취방.jpg', '...       원룸     서울  NaN
# 1849  ['2_0_상수역_6분거리_,_합정역_6분거리_30평급_넓은_공간_자연광_스튜디오_...     스튜디오     서울  NaN
# 1850  ['10_0_시매.jpg', '10_1_시매.jpg', '10_2_시매.jpg', ...       주택     서울  NaN
# 1851  ['17_0_(용산)_채광맛집_예술가의_로프트!.jpg', '17_1_(용산)_채광...       원룸     서울  NaN
#
#        price  area floor  default_person  parking  \
# 1847  50,000    50     2               7        0
# 1848  40,000    33     1               3        1
# 1849  45,000    96     3               6        1
# 1850  41,000    46     4               3        2
# 1851  87,000    26    12               3        2
#
#                                             description  \
# 1847                                 홍대에 있는 방 2개 주택입니다.
# 1848  낮에 채광 잘드는 1층 집이고 공간은 약 10평정도 됩니다. 드라마 이태원클라쓰 촬...
# 1849  30평의 넓은 공간에 동남서 방향 3면에 창이 배치되어 자연광이 풍부하고 섹션별로 ...
# 1850  해방촌 언저리에 있는 작은 옥탑방이예요.\r\n\r\n방문이 없는 투룸 과 주방 공...
# 1851  안녕하세요!\r\n\r\n용산에 위치한 복층 오피스텔입니다\r\n공간이 넓지는 않지...
#
#                                                new_tag1  \
# 1847                                       ['홍대', '주택']
# 1848  ['채광', '공간', '평정', '드라마', '이태원', '촬영', '바로', '...
# 1849  ['평의', '공간', '방향', '배치', '자연', '디자인', '공간', '촬...
# 1850  ['해방촌', '옥탑방', '방문', '투룸', '주방', '공간', '가지', '...
# 1851  ['용산', '위치', '복층', '오피스텔', '공간', '고가', '미터', '...
#
#                                                new_tag2
# 1847                                       ['홍대', '주택']
# 1848  ['채광', '공간', '평정', '드라마', '이태원', '촬영', '바로', '...
# 1849  ['평의', '공간', '방향', '배치', '자연', '디자인', '공간', '촬...
# 1850  ['해방촌', '옥탑방', '방문', '투룸', '주방', '공간', '가지', '...
# 1851  ['용산', '위치', '복층', '오피스텔', '공간', '고가', '미터', '...

# %%
## description 다듬기
def getDescList(n):
    okt=Okt()
    descList=[]
    for i in range(n):
        tempList=[]
        descript=(dataset.description[i]) # 한글자 이상만 뽑음
        descript=descript.replace("\n","")
        descript=descript.replace("\r","")
        descript=descript.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣09]","")
        tempList=[j[0] for j in okt.pos(descript) if ((len(j[0])>1)& (len(j[0])<7)& (j[1]=="Noun"))]
        tempList=list(set(tempList))
        if len(tempList)>0:
            descList.append(tempList)
        else:
            descList.append(tempList)
#             print(tempList,"|",i)
                                    # [] | 92
                                    # [] | 988
                                    # [] | 1486
                                    # [] | 1806
    return descList

# %%
# descList=getDescList(len(dataset))
# descList
# Out:
# [] | 92
# [] | 988
# [] | 1486
# [] | 1806

# %%
len(descList)
# Out:
# 1852

# %%
## Tag 다듬기
## 복합명사로 이루어진 태그는 잘라서 길이 2~7 사이의 단어만 추출
def getTagList(n):
    parseTagList=[]
    okt=Okt()
    for i in range(n):
        tempTagList=[]
        tags=str(dataset.tag[i]).split('#') # 태그별로 자르기
        for tag in tags:
            if len(tag)>1:
                okt.pos(tag)  # 1개 태그 내 복합 명사 자르기
                for j in okt.nouns(tag):
                    if(len(j)>=2|len(j)<7):
                        tempTagList.append(j)
        tempTagList=list(set(tempTagList))
        parseTagList.append(tempTagList)
    return parseTagList

# %%
# tagList=getTagList(10)
# tagList

# %% [markdown]
# ### CoreTag 2가지 방법

# %%
## Case 1) 코어 태그 추출 (태그, description 합집합)
def getCoreTags1(n):
    coreTagList1=[]
    okt=Okt()    
    coreTag=[]
    descript=getDescList(n) # 한글자 이상만 뽑음
    tags=getTagList(n)  # tag를 한번 더 파싱
    for i in range(len(descript)): 
        if (len(tags[i])>0): 
            coreTag.append(tags[i]+descript[i])
        else:
            coreTag.append(descript[i])
    coreTagList1.append(coreTag)
    return coreTagList1

# %%
# %time CoreTagDate1=getCoreTags1(len(dataset))
# CoreTagDate1=CoreTagDate1[0]
CoreTagDate1
# Out:
# Wall time: 1min 8s
# [['클래식',
#   '홍대',
#   '원룸',
#   '빌라',
#   '모던',
#   '서교동',
#   '서울시',
#   '분리',
#   '모델링',
#   '그림',
#   '클래식',
#   '홍대',
#   '거리',
#   '평일',
#   '메인',
#   '빌라',
#   '체스',
#   '모던',
#   '주말',
#   '예약',
#   '등록',
#   '바탕',
#   '분위기',
#   '조성'],
#  ['벽난로',
#   '전망',
#   '루프',
#   '고풍',
#   '자연',
#   '명수',
#   '내부',
#   '작업',
#   '생활',
#   '렌트',
#   '주방',
#   '쇼핑몰',
#   '게스트',
#   '키친',
#   '사용',
#   '거실',
#   '촬영',
#   '음악',
#   '스튜디오',
#   '구성',
#   '옥상',
#   '침실'],
#  ['벽난로',
#   '전망',
#   '루프',
#   '고풍',
#   '자연',
#   '명수',
#   '내부',
#   '작업',
#   '생활',
#   '렌트',
#   '주방',
#   '쇼핑몰',
#   '게스트',
#   '키친',
#   '사용',
#   '거실',
#   '촬영',
#   '음악',
#   '스튜디오',
#   '구성',
#   '옥상',
#   '침실'],
#  ['선유도',
#   '아파트',
#   '가정',
#   '평투룸',
#   '신축',
#   '선유도역',
#   '위치',
#   '시설',
#   '주방',
#   '크기',
#   '느낌',
#   '야경',
#   '거실',
#   '신축',
#   '남향',
#   '투룸',
#   '오피스텔',
#   '욕실',
#   '안양천'],
#  ['분위기',
#   '쇼파',
#   '북향',
#   '햇빛',
#   '주방',
#   '직장',
#   '북향',
#   '평일',
#   '전문의',
#   '직접',
#   '가구',
#   '거실',
#   '촬영',
#   '신축',
#   '서재',
#   '관계',
#   '공간',
#   '부부'],
#  ['카페',
#   '신혼집',
#   '빌라',
#   '위치',
#   '세탁실',
#   '찾기',
#   '주방',
#   '사용',
#   '남편',
#   '직접',
#   '빌라',
#   '서재',
#   '바로',
#   '건물',
#   '구조',
#   '주차장',
#   '수원',
#   '친구',
#   '인테리어',
#   '거실',
#   '공원',
#   '다이닝',
#   '화장실',
#   '경기도',
#   '겸용',
#   '여권',
#   '월드컵경기',
#   '드레스',
#   '맞은편',
#   '가까이',
#   '침실',
#   '공용',
#   '베란다',
#   '신혼',
#   '주차',
#   '벽돌',
#   '사이사이',
#   '민원'],
#  ['아파트',
#   '반포',
#   '잠원동',
#   '잠원역',
#   '소형',
#   '강남',
#   '불가',
#   '위치',
#   '내부',
#   '아파트',
#   '모델링',
#   '주간',
#   '평일',
#   '언제',
#   '준공',
#   '현재',
#   '잠원역',
#   '주말',
#   '근처',
#   '야간',
#   '협의'],
#  ['광고',
#   '자취',
#   '가구',
#   '원룸',
#   '여자',
#   '인테리어',
#   '테라스',
#   '가득',
#   '타워',
#   '직접',
#   '인용',
#   '원룸',
#   '시간대',
#   '셀프',
#   '공간',
#   '모든',
#   '롯데',
#   '월드',
#   '제외',
#   '정도',
#   '노란색'],
#  ['라이프',
#   '싱글',
#   '원룸',
#   '주거',
#   '고시원',
#   '천호역',
#   '위치',
#   '세탁실',
#   '제품',
#   '주방',
#   '참고',
#   '언제',
#   '지금',
#   '공간',
#   '최근',
#   '모델링',
#   '원룸텔',
#   '소개',
#   '블로그',
#   '일정',
#   '수입',
#   '천호역',
#   '욕실',
#   '화보',
#   '영파여고',
#   '촬영',
#   '포털사이트',
#   '전체',
#   '부부',
#   '복도',
#   '인터넷',
#   '가구',
#   '근처',
#   '고시원',
#   '운영',
#   '저희',
#   '취미'],
#  ['블루',
#   '골드',
#   '모던',
#   '서울',
#   '화이트',
#   '쓰레기',
#   '아파트',
#   '학생',
#   '주방',
#   '지상',
#   '사용',
#   '모두',
#   '최대한',
#   '소재',
#   '소품',
#   '분리수거',
#   '주차장',
#   '규어',
#   '식물',
#   '스텝',
#   '간식',
#   '거실',
#   '적극',
#   '숲뷰',
#   '화장실',
#   '사전',
#   '방도',
#   '건담',
#   '지하',
#   '도시락',
#   '촬영',
#   '동대문구',
#   '협조',
#   '장비',
#   '거주',
#   '답사',
#   '가구',
#   '밤샘촬영',
#   '평이'],
#  ['평수', '테라스', '아이방', '복층', '대형', '아파트', '테라스', '아이방', '복층', '평수'],
#  ['아파트',
#   '서현역',
#   '아파트',
#   '사항',
#   '사용',
#   '모두',
#   '주말',
#   '분장',
#   '소품',
#   '확장',
#   '실로',
#   '평일',
#   '화장실',
#   '관계',
#   '단지',
#   '개화',
#   '가능',
#   '시간',
#   '특이',
#   '남서',
#   '안쪽',
#   '서현역',
#   '장대',
#   '공사'],
#  ['화실', '칸막이', '공간', '화실', '평의'],
#  ['빈티',
#   '편리',
#   '평지',
#   '주차',
#   '차량',
#   '가능',
#   '강화도',
#   '공사',
#   '화장실',
#   '공간',
#   '위치',
#   '사용',
#   '언제',
#   '주말',
#   '인원',
#   '스튜디오',
#   '실제',
#   '공간',
#   '매우',
#   '전기',
#   '소품',
#   '필요',
#   '문자',
#   '건물',
#   '바로',
#   '주차장',
#   '인테리어',
#   '우측',
#   '내외',
#   '평일',
#   '싱크대',
#   '정말',
#   '서울',
#   '소가',
#   '여러',
#   '화장실',
#   '고속도로',
#   '강화대교',
#   '느낌',
#   '트럭',
#   '거리',
#   '일시',
#   '컨셉',
#   '인근',
#   '식당',
#   '촬영',
#   '차량',
#   '기재',
#   '장비',
#   '시간',
#   '구분',
#   '가능',
#   '내용',
#   '편의점',
#   '리얼',
#   '접근성',
#   '아주',
#   '소요',
#   '별도',
#   '출입문',
#   '가구',
#   '주차',
#   '대로',
#   '소속'],
#  ['모던',
#   '아이방',
#   '아파트',
#   '정원',
#   '어닝',
#   '요일',
#   '화이트',
#   '정원',
#   '소품',
#   '데크',
#   '구조',
#   '모델링',
#   '평일',
#   '기본',
#   '거실',
#   '아이',
#   '선호',
#   '키친',
#   '느낌',
#   '블루',
#   '설계',
#   '인더스트리얼',
#   '사이',
#   '촬영',
#   '모던',
#   '한지',
#   '분위기',
#   '시간',
#   '포인트',
#   '바흐',
#   '여름',
#   '테라스',
#   '체적',
#   '수영장',
#   '그네',
#   '부엌'],
#  ['가구',
#   '모던',
#   '가정',
#   '접시',
#   '루왁',
#   '오디오',
#   '층집',
#   '레디',
#   '화이트',
#   '소품',
#   '연출',
#   '위치',
#   '아파트',
#   '주방',
#   '주말',
#   '독립',
#   '조율',
#   '공간',
#   '소품',
#   '분리',
#   '차림',
#   '인테리어',
#   '평일',
#   '거실',
#   '미추홀',
#   '아이',
#   '사전',
#   '이용',
#   '오전',
#   '모던',
#   '슬라이딩',
#   '저녁',
#   '장난감',
#   '시간',
#   '인천',
#   '돌상',
#   '스크린',
#   '전통'],
#  ['동물',
#   '베란다',
#   '당산',
#   '차편',
#   '촬영',
#   '아이',
#   '층집',
#   '여의도',
#   '근처',
#   '연출',
#   '위치',
#   '생활',
#   '내부',
#   '아파트',
#   '대기',
#   '여의도',
#   '용품',
#   '공간',
#   '필요',
#   '방이',
#   '설치',
#   '또한',
#   '당산역',
#   '아이',
#   '커버',
#   '소등',
#   '에어컨',
#   '안방',
#   '사이',
#   '촬영',
#   '집안',
#   '장비',
#   '베란다',
#   '연기자',
#   '가구',
#   '배치',
#   '조명',
#   '활용'],
#  ['돌담',
#   '종로구',
#   '유리',
#   '소개',
#   '자연',
#   '아이',
#   '층집',
#   '주의',
#   '사계절',
#   '아파트',
#   '메인',
#   '층집',
#   '사직',
#   '소개',
#   '거실',
#   '복합',
#   '공원',
#   '겨울',
#   '한눈',
#   '맞은편',
#   '보통',
#   '자연',
#   '높이',
#   '여름',
#   '가을',
#   '통창',
#   '주상',
#   '네이버'],
#  ['카페',
#   '심플',
#   '모던',
#   '두운',
#   '근처',
#   '공간',
#   '효창동',
#   '위치',
#   '위해',
#   '하루',
#   '베리',
#   '조정',
#   '광고',
#   '구내식당',
#   '일요일',
#   '평일',
#   '현재',
#   '원래',
#   '돼지고기',
#   '종일',
#   '식당',
#   '식사',
#   '뷔페',
#   '촬영',
#   '영업',
#   '토요일',
#   '회사',
#   '저녁',
#   '가능',
#   '시간',
#   '내용',
#   '협의',
#   '오후',
#   '전문',
#   '점심',
#   '직장인',
#   '직원',
#   '아침',
#   '근처',
#   '운영',
#   '효창동'],
#  ['심풀',
#   '남자',
#   '시민',
#   '자취',
#   '양재천',
#   '공원',
#   '고인돌',
#   '숲역',
#   '서초구',
#   '빈티',
#   '주택가',
#   '목금',
#   '토일',
#   '월화',
#   '인근',
#   '창가',
#   '자취',
#   '요일',
#   '나무',
#   '모던',
#   '시간',
#   '선호',
#   '협의'],
#  ['하우스',
#   '아파트',
#   '우드',
#   '심플',
#   '모던',
#   '신혼집',
#   '추럴',
#   '화이트',
#   '위치',
#   '장점',
#   '아파트',
#   '이동',
#   '사용',
#   '지안',
#   '모두',
#   '심플',
#   '소리',
#   '수거',
#   '여의도',
#   '강남',
#   '공간',
#   '바로',
#   '소품',
#   '용마산',
#   '경우',
#   '정말',
#   '공원',
#   '사람',
#   '용산',
#   '미리',
#   '동의',
#   '거의',
#   '어디',
#   '촬영',
#   '부부',
#   '생각',
#   '거나',
#   '부분',
#   '발생',
#   '가구',
#   '노량진',
#   '쓰레기'],
#  ['모던',
#   '심플',
#   '빌라',
#   '연출',
#   '위치',
#   '호선',
#   '분당선',
#   '주방',
#   '빌라',
#   '특징',
#   '뚝섬역',
#   '화이트',
#   '말씀',
#   '남향',
#   '구조',
#   '평일',
#   '거실',
#   '서울',
#   '다이닝',
#   '미리',
#   '테이블',
#   '오전',
#   '그레이',
#   '프레',
#   '대의',
#   '느낌',
#   '블루',
#   '화초',
#   '모던',
#   '촬영',
#   '초반',
#   '자연',
#   '성수동',
#   '분위기',
#   '시한',
#   '저녁',
#   '하나',
#   '침실',
#   '컬러',
#   '협의',
#   '배색',
#   '주차',
#   '서울숲',
#   '저희'],
#  ['가정',
#   '화장실',
#   '반지하',
#   '빌라',
#   '호선',
#   '세탁실',
#   '주방',
#   '이동',
#   '탑차',
#   '언제',
#   '빌라',
#   '주말',
#   '등산',
#   '도보',
#   '주차장',
#   '원상',
#   '버스정류장',
#   '승용차',
#   '지하철',
#   '일요일',
#   '평일',
#   '거실',
#   '화장실',
#   '이용',
#   '교통',
#   '집기',
#   '교회',
#   '촬영',
#   '도봉산',
#   '가능',
#   '해주시',
#   '가구',
#   '날짜',
#   '도봉산역',
#   '공영',
#   '복구'],
#  ['옥수동',
#   '신혼집',
#   '아파트',
#   '금호동',
#   '연출',
#   '위치',
#   '아파트',
#   '우드',
#   '요일',
#   '주말',
#   '최대한',
#   '금호동',
#   '서재',
#   '화이트',
#   '공간',
#   '소품',
#   '식물',
#   '거실',
#   '신축',
#   '감성',
#   '이용',
#   '느낌',
#   '드레스',
#   '촬영',
#   '시간',
#   '침실',
#   '평소',
#   '옥수역',
#   '주차',
#   '가구',
#   '근처',
#   '트렌디',
#   '부엌'],
#  ['아파트',
#   '심플',
#   '모던',
#   '평인',
#   '테리어',
#   '가정',
#   '화이트',
#   '그레이',
#   '장판',
#   '아파트',
#   '직접',
#   '모노',
#   '수리',
#   '단란',
#   '조율',
#   '공간',
#   '소품',
#   '에어비앤비',
#   '사전',
#   '그레이',
#   '신혼부부',
#   '분위기',
#   '거주',
#   '생각',
#   '가구',
#   '날짜',
#   '운영',
#   '일상',
#   '벽지'],
#  ['주방',
#   '쇼파',
#   '심플',
#   '거실',
#   '모던',
#   '애견',
#   '연출',
#   '근처',
#   '아파트',
#   '주방',
#   '사용',
#   '인용',
#   '이미지',
#   '모태',
#   '아쿠아',
#   '공간',
#   '평수',
#   '소품',
#   '신소재',
#   '클랜',
#   '대리석',
#   '클래식',
#   '삼송역',
#   '쇼파',
#   '거실',
#   '화장실',
#   '안방',
#   '모던',
#   '촬영',
#   '식탁',
#   '생각',
#   '스탭',
#   '아주',
#   '신혼',
#   '동반',
#   '여러가지',
#   '애견',
#   '햇살'],
#  ['화이트하우스',
#   '플랜',
#   '촬영',
#   '가정',
#   '테리어',
#   '화이트',
#   '테이블',
#   '원목',
#   '연출',
#   '하우스',
#   '느낌',
#   '평일',
#   '자재',
#   '새벽',
#   '주말',
#   '가능',
#   '화이트',
#   '자유',
#   '제외',
#   '원목'],
#  ['명소',
#   '평일',
#   '로쏘',
#   '고급',
#   '주말',
#   '촬영',
#   '가능',
#   '촬영장',
#   '레스토랑',
#   '평일',
#   '소로',
#   '로쏘',
#   '주말',
#   '촬영',
#   '다수',
#   '시간',
#   '이탈리안'],
#  ['부산',
#   '스터디',
#   '카페',
#   '인테리어',
#   '카페',
#   '사용',
#   '거의',
#   '이용자',
#   '아침',
#   '촬영',
#   '운영',
#   '가능',
#   '감성',
#   '스터디'],
#  ['후곡',
#   '아파트',
#   '일산',
#   '마을',
#   '파트',
#   '연출',
#   '작업',
#   '플로리스트',
#   '베란다',
#   '주방',
#   '실로',
#   '사용',
#   '카페',
#   '느낌',
#   '거실',
#   '식탁',
#   '공간',
#   '테이블',
#   '접이식'],
#  ['반지하',
#   '주택',
#   '위치',
#   '때문',
#   '사용',
#   '요일',
#   '소품',
#   '원상',
#   '현재',
#   '반지하',
#   '선호',
#   '세팅',
#   '촬용',
#   '장비',
#   '가능',
#   '시간',
#   '공실이',
#   '복귀',
#   '주택',
#   '수진동',
#   '성남'],
#  ['장기',
#   '촬영',
#   '작업실',
#   '셀프',
#   '복층',
#   '영화',
#   '월세',
#   '위치',
#   '사용',
#   '최대한',
#   '세탁기',
#   '하남시',
#   '지원',
#   '블라인드',
#   '말씀',
#   '미사',
#   '물품',
#   '기본',
#   '설치',
#   '냉장고',
#   '오피스텔',
#   '이용',
#   '에어컨',
#   '강변',
#   '아일랜드',
#   '시간',
#   '식탁',
#   '일주',
#   '이주',
#   '신도시',
#   '아이보리',
#   '빌트',
#   '여러가지',
#   '의자',
#   '하루'],
#  ['네추럴',
#   '원형',
#   '주방',
#   '사진빨',
#   '심플',
#   '조명',
#   '거울',
#   '화이트',
#   '계단',
#   '단독주택',
#   '위치',
#   '호선',
#   '주방',
#   '파티',
#   '비지니스',
#   '프로포즈',
#   '샤워',
#   '공간',
#   '돌곶',
#   '거실',
#   '돌곶이역',
#   '다이닝룸',
#   '자유',
#   '테이블',
#   '브라',
#   '각종',
#   '하우스',
#   '일과',
#   '촬영',
#   '모임',
#   '휴식',
#   '시간',
#   '가세',
#   '침실',
#   '이벤트'],
#  ['밤하늘',
#   '바다',
#   '단독',
#   '자연',
#   '맑은',
#   '시골',
#   '위치',
#   '일품',
#   '과수원',
#   '강원도',
#   '맑은',
#   '원목',
#   '우리',
#   '야산',
#   '소개',
#   '집앞',
#   '가정',
#   '각각',
#   '마당',
#   '야외',
#   '외각',
#   '연결',
#   '자연환경',
#   '지은지',
#   '테라스',
#   '잔디',
#   '밤하늘',
#   '실내',
#   '속초시',
#   '아이보리',
#   '계열'],
#  ['단독주택',
#   '사용',
#   '위로',
#   '차고',
#   '운정신도시',
#   '주변',
#   '장소',
#   '오전',
#   '대여',
#   '검색',
#   '모든',
#   '가능',
#   '시간',
#   '잡지',
#   '오후',
#   '공터',
#   '주차',
#   '사진',
#   '파주',
#   '뒷마당',
#   '앞마당'],
#  ['카페',
#   '고가',
#   '주얼리',
#   '분위기',
#   '정원',
#   '소품',
#   '야간',
#   '연출',
#   '세련',
#   '미가',
#   '정원',
#   '로맨틱',
#   '공간',
#   '핸드',
#   '소품',
#   '감각',
#   '보유',
#   '인테리어',
#   '엔틱',
#   '전구',
#   '공존',
#   '전적',
#   '현대',
#   '느낌',
#   '계절',
#   '메이드',
#   '촬영',
#   '다른',
#   '스트링',
#   '가구',
#   '야간'],
#  ['주택'],
#  ['한남동',
#   '플라워',
#   '모던',
#   '복합',
#   '프렌치',
#   '주상',
#   '정원',
#   '미니',
#   '위치',
#   '한남동',
#   '드레스',
#   '페미닌',
#   '거실',
#   '모던',
#   '복합',
#   '주상',
#   '정원',
#   '창문',
#   '공간',
#   '침실'],
#  ['테라스', '주택', '홍대', '연남동', '꽃길', '위치', '연트럴꽃길', '자락', '하우스'],
#  ['바베큐',
#   '벽난로',
#   '가든',
#   '목조',
#   '파티',
#   '주택',
#   '소나무',
#   '설경',
#   '층집',
#   '정원',
#   '애견',
#   '데크',
#   '전원주택',
#   '사용',
#   '방해',
#   '지대',
#   '나무',
#   '자락',
#   '산속',
#   '바로',
#   '옥외',
#   '데크',
#   '건물',
#   '분당',
#   '설경',
#   '풍경',
#   '공원',
#   '겨울',
#   '요금',
#   '장산',
#   '정원수',
#   '계절',
#   '촬영',
#   '자연',
#   '조물',
#   '집뒤',
#   '벽난로',
#   '베란다',
#   '주택',
#   '아주',
#   '잔디',
#   '별도',
#   '율동',
#   '여러가지',
#   '도심',
#   '기도'],
#  ['바베큐',
#   '벽난로',
#   '가든',
#   '목조',
#   '파티',
#   '주택',
#   '소나무',
#   '설경',
#   '층집',
#   '정원',
#   '애견',
#   '데크',
#   '전원주택',
#   '사용',
#   '방해',
#   '지대',
#   '나무',
#   '자락',
#   '산속',
#   '바로',
#   '옥외',
#   '데크',
#   '건물',
#   '분당',
#   '설경',
#   '풍경',
#   '공원',
#   '겨울',
#   '요금',
#   '장산',
#   '정원수',
#   '계절',
#   '촬영',
#   '자연',
#   '조물',
#   '집뒤',
#   '벽난로',
#   '베란다',
#   '주택',
#   '아주',
#   '잔디',
#   '별도',
#   '율동',
#   '여러가지',
#   '도심',
#   '기도'],
#  ['하숙집',
#   '학생',
#   '마당',
#   '기숙사',
#   '층집',
#   '옥상',
#   '하숙집',
#   '마당',
#   '일산동구',
#   '고기',
#   '피고',
#   '먹기',
#   '소리',
#   '분위기',
#   '식사동',
#   '러닝',
#   '공간',
#   '건물'],
#  ['마당', '네츄럴', '햇살', '나무', '층집', '창문', '사계절', '햇살', '전원주택', '사계절'],
#  ['별장',
#   '웨딩',
#   '제주',
#   '스몰',
#   '평정',
#   '야외',
#   '바닷가',
#   '촬영',
#   '힐링',
#   '주독',
#   '위치',
#   '독채',
#   '제주',
#   '영화',
#   '정원',
#   '감귤',
#   '건축학개론',
#   '별장',
#   '낚시',
#   '서귀포시',
#   '미리',
#   '장소',
#   '하우스',
#   '제격',
#   '바다',
#   '푸른',
#   '지니',
#   '제공',
#   '여유',
#   '위미항',
#   '서연'],
#  ['부부',
#   '야경',
#   '빌라',
#   '위치',
#   '경치',
#   '때문',
#   '중이',
#   '빌라',
#   '주말',
#   '이태원',
#   '조율',
#   '현재',
#   '일정',
#   '선호',
#   '공휴일',
#   '신혼부부',
#   '촬영',
#   '주중',
#   '거주',
#   '바깥',
#   '경리',
#   '중턱'],
#  ['아파트',
#   '갤러리',
#   '신혼집',
#   '화이트',
#   '미니',
#   '원목',
#   '언제',
#   '주말',
#   '신혼집',
#   '화이트',
#   '벽면',
#   '최근',
#   '원목',
#   '액자',
#   '모델링',
#   '평일',
#   '작은방',
#   '거실',
#   '오전',
#   '스타일',
#   '그림',
#   '갤러리',
#   '공간활용',
#   '장만',
#   '촬영',
#   '분위기',
#   '저녁',
#   '시간',
#   '전체',
#   '하나',
#   '미니',
#   '협의',
#   '오후',
#   '가구'],
#  ['섭외',
#   '아파트',
#   '촬영',
#   '가정',
#   '강원도',
#   '신축',
#   '남향',
#   '위치',
#   '아파트',
#   '공립',
#   '시큐리티',
#   '일반',
#   '언제',
#   '샤워',
#   '주말',
#   '완공',
#   '강원대학교',
#   '매니',
#   '바로',
#   '소품',
#   '남향',
#   '대학',
#   '부스',
#   '조정',
#   '경우',
#   '살이',
#   '설치',
#   '이야기',
#   '살림',
#   '평형',
#   '가정',
#   '거실',
#   '트루',
#   '화장실',
#   '구성',
#   '감성',
#   '정리',
#   '미리',
#   '테이블',
#   '욕실',
#   '각종',
#   '마련',
#   '맞은편',
#   '춘천',
#   '촬영',
#   '주중',
#   '침대',
#   '회의',
#   '시간',
#   '해주시',
#   '이후',
#   '주차',
#   '가구',
#   '후평동'],
#  ['아파트',
#   '주방',
#   '우드',
#   '거실',
#   '모던',
#   '화이트',
#   '소품',
#   '아기',
#   '연출',
#   '위치',
#   '인테리어',
#   '안양',
#   '가구',
#   '평촌',
#   '가정',
#   '미니',
#   '화이트',
#   '소품',
#   '남향',
#   '트렌디'],
#  ['아파트',
#   '주방',
#   '우드',
#   '거실',
#   '모던',
#   '화이트',
#   '소품',
#   '아기',
#   '연출',
#   '위치',
#   '인테리어',
#   '안양',
#   '가구',
#   '평촌',
#   '가정',
#   '미니',
#   '화이트',
#   '소품',
#   '남향',
#   '트렌디'],
#  ['아파트',
#   '학생',
#   '휴량',
#   '북카페',
#   '자연',
#   '축제',
#   '천일홍',
#   '수채화',
#   '생활',
#   '영상',
#   '아파트',
#   '프로젝트',
#   '재미',
#   '바로',
#   '조정',
#   '뒷산',
#   '인테리어',
#   '평일',
#   '제약',
#   '거실',
#   '가정',
#   '가족',
#   '믹스',
#   '오전',
#   '대여',
#   '토요일',
#   '촬영',
#   '자연',
#   '시간',
#   '매치',
#   '오후',
#   '리폼',
#   '휴양림',
#   '가구',
#   '대신'],
#  ['아파트',
#   '식물',
#   '브이',
#   '키덜트',
#   '촬영',
#   '비디오',
#   '로그',
#   '소품',
#   '참고',
#   '언제',
#   '인용',
#   '공간',
#   '비치',
#   '액자',
#   '식물',
#   '초록',
#   '하우스',
#   '마련',
#   '촬영',
#   '가을',
#   '예정',
#   '사진',
#   '고풍',
#   '기도',
#   '근처',
#   '사항',
#   '구애',
#   '매우',
#   '말씀',
#   '원목',
#   '선인장',
#   '모니터링',
#   '문의',
#   '겨울',
#   '느낌',
#   '계절',
#   '시간',
#   '미니',
#   '협의',
#   '해주시',
#   '그릇',
#   '조명',
#   '햇살',
#   '푸릇',
#   '아파트',
#   '대기',
#   '나무',
#   '최대한',
#   '규어',
#   '단풍',
#   '삼각지',
#   '배동',
#   '덮힌',
#   '제공',
#   '창문',
#   '침실',
#   '베란다',
#   '몬스테라',
#   '방공',
#   '모두',
#   '배경',
#   '강남',
#   '마치',
#   '소품',
#   '강북',
#   '거실',
#   '서울',
#   '피크닉',
#   '공원',
#   '주변',
#   '화장실',
#   '미리',
#   '이용',
#   '테이블',
#   '장소',
#   '중심',
#   '신혼부부',
#   '안방',
#   '효창',
#   '예약',
#   '집안',
#   '재미나',
#   '편이',
#   '오후',
#   '옛날'],
#  ['스타일',
#   '영상',
#   '아파트',
#   '일몰',
#   '브이',
#   '차편',
#   '촬영',
#   '모던',
#   '로그',
#   '소품',
#   '아파트',
#   '인테리어',
#   '아주',
#   '가구',
#   '실내',
#   '모던',
#   '공간',
#   '플랜트',
#   '신축',
#   '구성',
#   '채광'],
#  ['아파트',
#   '국적',
#   '심플',
#   '압구정',
#   '모던',
#   '분위기',
#   '화이트',
#   '미니',
#   '강아지',
#   '위치',
#   '조절',
#   '아파트',
#   '직접',
#   '최대한',
#   '소품',
#   '구조',
#   '거실',
#   '평형',
#   '욕실',
#   '신혼부부',
#   '집의',
#   '동향',
#   '종일',
#   '압구정동',
#   '촬영',
#   '시간',
#   '하나',
#   '편이',
#   '협의',
#   '대부분',
#   '연락',
#   '아침',
#   '날짜',
#   '이구',
#   '조명',
#   '밝기',
#   '하루',
#   '활용'],
#  ['아파트',
#   '국적',
#   '심플',
#   '압구정',
#   '모던',
#   '분위기',
#   '화이트',
#   '미니',
#   '강아지',
#   '위치',
#   '조절',
#   '아파트',
#   '직접',
#   '최대한',
#   '소품',
#   '구조',
#   '거실',
#   '평형',
#   '욕실',
#   '신혼부부',
#   '집의',
#   '동향',
#   '종일',
#   '압구정동',
#   '촬영',
#   '시간',
#   '하나',
#   '편이',
#   '협의',
#   '대부분',
#   '연락',
#   '아침',
#   '날짜',
#   '이구',
#   '조명',
#   '밝기',
#   '하루',
#   '활용'],
#  ['아파트',
#   '잠실',
#   '모던',
#   '서울',
#   '아이',
#   '화이트',
#   '고양이',
#   '연출',
#   '아파트',
#   '주방',
#   '라벤더',
#   '파스텔',
#   '비롯',
#   '소재',
#   '화이트',
#   '금속',
#   '고양이',
#   '유지',
#   '장식',
#   '네이비',
#   '거실',
#   '평형',
#   '화장실',
#   '구성',
#   '핑크',
#   '민트',
#   '반려동물',
#   '중문',
#   '느낌',
#   '관련',
#   '도어',
#   '모던',
#   '촬영',
#   '포인트',
#   '컬러',
#   '전반',
#   '베란다',
#   '활용',
#   '아이방',
#   '소파',
#   '그린'],
#  ['아파트',
#   '한강',
#   '비디오',
#   '가정',
#   '아이',
#   '화이트',
#   '용산',
#   '위치',
#   '영상',
#   '여분',
#   '아파트',
#   '이동',
#   '한강',
#   '기차',
#   '주말',
#   '화이트',
#   '공간',
#   '평수',
#   '채광',
#   '확장',
#   '남향',
#   '구조',
#   '벽지',
#   '소품',
#   '위주',
#   '광고',
#   '공구',
#   '평일',
#   '용도',
#   '남아',
#   '더욱',
#   '거실',
#   '해질녘',
#   '가족',
#   '아이',
#   '완구',
#   '사전',
#   '동부',
#   '일자',
#   '테이블',
#   '그레이',
#   '선호',
#   '가전',
#   '브리',
#   '느낌',
#   '필요시',
#   '안방',
#   '보쉬',
#   '유의',
#   '촬영',
#   '엘레베이터',
#   '장비',
#   '시간',
#   '전체',
#   '비글',
#   '프리미엄',
#   '연한',
#   '협의',
#   '베란다',
#   '활용',
#   '가구',
#   '역시',
#   '이촌동',
#   '기타',
#   '노을',
#   '소파',
#   '야간',
#   '부엌'],
#  ['신혼집',
#   '강뷰',
#   '대면',
#   '주방',
#   '평일도',
#   '모델링',
#   '평일',
#   '중순',
#   '이후',
#   '촬영',
#   '주말',
#   '신혼집',
#   '저녁'],
#  ['아파트',
#   '심플',
#   '주차',
#   '모던',
#   '가능',
#   '그레이',
#   '아파트',
#   '은평구',
#   '널널해',
#   '구산동',
#   '결혼',
#   '주차',
#   '서울시',
#   '부부',
#   '구역'],
#  ['아파트',
#   '베란다',
#   '라면',
#   '아파트',
#   '베란다',
#   '인테리어',
#   '지하철',
#   '평일',
#   '혹시',
#   '나무',
#   '촬영',
#   '석수역',
#   '보기',
#   '시간',
#   '협의'],
#  ['아파트', '모델링', '모델링'],
#  ['우드',
#   '사진빨',
#   '잠실',
#   '평집',
#   '가정',
#   '화이트',
#   '미니',
#   '인테리어',
#   '제품',
#   '아파트',
#   '우드',
#   '전철역',
#   '잠실',
#   '근방',
#   '미니',
#   '공사',
#   '화이트',
#   '컨셉',
#   '최근'],
#  ['아파트', '전망', '서재', '거실', '아파트', '신도시', '한강', '장기동', '센트럴', '김포'],
#  ['아파트', '아파트', '전망', '사용', '대우', '한강', '서울', '금호동', '소재', '부터'],
#  ['남자', '아이방', '아파트', '고층', '위치', '오후', '평일', '부암동', '진구', '부산', '가정', '오전'],
#  ['하우스',
#   '아파트',
#   '심플',
#   '고층',
#   '아이',
#   '지은지',
#   '위치',
#   '오후',
#   '아파트',
#   '형구',
#   '전망',
#   '오전',
#   '신도시',
#   '아침',
#   '평형',
#   '다산',
#   '고층',
#   '얼마',
#   '시간',
#   '선호'],
#  ['가족사',
#   '상가',
#   '옥상',
#   '주택',
#   '루프',
#   '해먹',
#   '복층',
#   '다가',
#   '건물',
#   '계단',
#   '사용',
#   '공간',
#   '최근',
#   '축하',
#   '노출',
#   '집도',
#   '거실',
#   '옆집',
#   '주변',
#   '화장실',
#   '맞벌이',
#   '시간',
#   '항상',
#   '고해',
#   '앞집',
#   '테라스',
#   '지은',
#   '옛날',
#   '콘크리트',
#   '네모',
#   '부엌'],
#  ['통기타',
#   '하우스',
#   '여자',
#   '케렌',
#   '쉐어',
#   '시아',
#   '빌라',
#   '쓰리룸',
#   '셰어',
#   '삼거리',
#   '위치',
#   '하우스',
#   '페르시안',
#   '상도동',
#   '거리',
#   '지하철역',
#   '거주',
#   '요일',
#   '선녀',
#   '신대방',
#   '시간',
#   '안식처',
#   '공간',
#   '셰어',
#   '일상',
#   '고양이',
#   '협의'],
#  ['홍대입구역', '주택'],
#  ['구가', '생활', '가정', '위치', '거제도', '아파트'],
#  ['독채',
#   '게스트',
#   '인조잔디',
#   '주말',
#   '공간',
#   '다락방',
#   '평일',
#   '추천',
#   '또한',
#   '거실',
#   '장소',
#   '하우스',
#   '서로',
#   '느낌',
#   '촬영',
#   '예약',
#   '다른',
#   '제공',
#   '분위기',
#   '옥상',
#   '진행',
#   '테라스',
#   '프라이',
#   '포함',
#   '컨셉',
#   '저희'],
#  ['분위기', '테라스', '건물', '카페', '사용', '카페'],
#  ['목동',
#   '깨끗',
#   '양천구',
#   '강서구',
#   '등촌역',
#   '심플',
#   '가정',
#   '염창역',
#   '장점',
#   '이자',
#   '아파트',
#   '영상',
#   '사용',
#   '일반',
#   '최대한',
#   '모델링',
#   '가정',
#   '비교',
#   '촬영',
#   '한지',
#   '협조',
#   '시간',
#   '정도',
#   '단점',
#   '진행',
#   '정상',
#   '개월',
#   '저희'],
#  ['평수',
#   '느낌',
#   '촬영',
#   '모임',
#   '휴양지',
#   '세미',
#   '대형',
#   '문제',
#   '위치',
#   '기념일',
#   '파티',
#   '이수',
#   '모두',
#   '스타',
#   '찍기',
#   '인생',
#   '도보',
#   '공간',
#   '바로',
#   '소품',
#   '초등학교',
#   '인테리어',
#   '친구',
#   '세미나',
#   '순간',
#   '생일',
#   '정말',
#   '사실',
#   '최적화',
#   '감성',
#   '오션',
#   '엠티',
#   '이벤트',
#   '거리',
#   '바닷가',
#   '추억',
#   '모임',
#   '워크샵',
#   '소음',
#   '회의',
#   '가능',
#   '구비',
#   '포즈',
#   '사당역',
#   '가득',
#   '전혀',
#   '사진',
#   '소규모',
#   '휴양지',
#   '도심',
#   '조명',
#   '취미'],
#  ['강남구',
#   '마루',
#   '우드',
#   '추럴',
#   '화이트',
#   '헤링',
#   '원목',
#   '레이스',
#   '주방',
#   '모두',
#   '브랜드',
#   '지금',
#   '공간',
#   '바로',
#   '광고',
#   '이야기',
#   '스토리',
#   '현관',
#   '풍경',
#   '가족',
#   '기분',
#   '장면',
#   '신혼부부',
#   '창밖',
#   '촬영',
#   '위층',
#   '아이방',
#   '인스타그램',
#   '호스트',
#   '기도',
#   '요리'],
#  ['아파트',
#   '여학생',
#   '심플',
#   '모던',
#   '조명',
#   '용산',
#   '감각',
#   '현대',
#   '아파트',
#   '거실',
#   '촬영',
#   '조명',
#   '다른',
#   '용산',
#   '삼각지역'],
#  ['주차장', '최근', '가정', '오후'],
#  ['아파트',
#   '목재',
#   '그릇',
#   '촬영',
#   '가정',
#   '가족',
#   '참고',
#   '대수',
#   '사투리',
#   '초등학교',
#   '평일',
#   '페리',
#   '직장',
#   '오전',
#   '발레',
#   '배송',
#   '소파',
#   '촬영',
#   '바이올린',
#   '홈파티',
#   '골프',
#   '주차',
#   '사진',
#   '근처',
#   '위치',
#   '주방',
#   '유리',
#   '심플',
#   '화이트',
#   '블라인드',
#   '스케쥴',
#   '단장',
#   '느낌',
#   '어회',
#   '셀프',
#   '모든',
#   '식탁',
#   '아주',
#   '그릇',
#   '원어민',
#   '부산',
#   '아파트',
#   '지상',
#   '우드',
#   '나무',
#   '주말',
#   '구가',
#   '사광',
#   '다시',
#   '뉴웨이브',
#   '마트',
#   '제한',
#   '햇빛',
#   '수준',
#   '광안대교',
#   '목재',
#   '비디오',
#   '개인',
#   '임시',
#   '디자인',
#   '보흐',
#   '계획',
#   '이후',
#   '연출',
#   '회색',
#   '모두',
#   '주차공간',
#   '반대편',
#   '조율',
#   '여자아이',
#   '나이프',
#   '크리스마스',
#   '보유',
#   '덤블링',
#   '작고',
#   '최소',
#   '경비실',
#   '업로드',
#   '미국',
#   '거실',
#   '카트',
#   '화장실',
#   '데코',
#   '스타일',
#   '동향',
#   '블루',
#   '안방',
#   '지하',
#   '학년',
#   '예약',
#   '장비',
#   '제외',
#   '덴비',
#   '오후',
#   '도움',
#   '모델',
#   '가구',
#   '컨셉',
#   '취미'],
#  ['흙집',
#   '가족',
#   '황토',
#   '아들',
#   '흙집',
#   '구리',
#   '도로',
#   '자리',
#   '왕방',
#   '직접',
#   '사이',
#   '지은',
#   '자락',
#   '강남',
#   '시간',
#   '동두천',
#   '부부',
#   '개통',
#   '포천'],
#  ['전망',
#   '소형',
#   '가족',
#   '아파트',
#   '방도',
#   '아파트',
#   '전망',
#   '오후',
#   '선호',
#   '평일',
#   '남자',
#   '오전',
#   '아이',
#   '일대',
#   '여자',
#   '중학교',
#   '초등학교'],
#  ['가족', '아파트', '아파트', '인테리어', '평일', '올해', '모두', '문의', '주말'],
#  ['가족', '아파트', '아파트', '인테리어', '평일', '올해', '모두', '문의', '주말'],
#  ['대여',
#   '아파트',
#   '촬영',
#   '드라마',
#   '화이트',
#   '미니',
#   '뮤직비디오',
#   '생생정보통',
#   '검법',
#   '남녀',
#   '용인',
#   '오늘아침',
#   '알짜',
#   '다큐멘터리',
#   '촬영',
#   '뉴스',
#   '케이블',
#   '방송'],
#  ['하우스',
#   '아파트',
#   '카페',
#   '느낌',
#   '브이',
#   '일산',
#   '촬영',
#   '모던',
#   '통창',
#   '경기도',
#   '로그',
#   '소품',
#   '컬러',
#   '연출',
#   '아파트',
#   '위해',
#   '주말',
#   '화이트',
#   '공간',
#   '소품',
#   '빈티',
#   '작업',
#   '인테리어',
#   '엔틱',
#   '워낙',
#   '카페',
#   '평일',
#   '거실',
#   '각각',
#   '경기도',
#   '레드',
#   '오전',
#   '마지막',
#   '느낌',
#   '안방',
#   '모던',
#   '촬영',
#   '셀프',
#   '시간',
#   '침실',
#   '컬러',
#   '블랙',
#   '포인트',
#   '협의',
#   '오후',
#   '놀이',
#   '활용',
#   '저희',
#   '일산',
#   '색감',
#   '가지',
#   '아이방',
#   '계열',
#   '컨셉',
#   '컬러풀',
#   '그린'],
#  ['북유럽',
#   '아파트',
#   '내추럴',
#   '숲뷰',
#   '모던',
#   '마루',
#   '잡지',
#   '원목',
#   '위치',
#   '아파트',
#   '느낌',
#   '내추럴',
#   '평의',
#   '거실',
#   '파노라마',
#   '숲뷰',
#   '자랑',
#   '수지'],
#  ['영상',
#   '최상급',
#   '아파트',
#   '상도',
#   '바이럴',
#   '촬영',
#   '모던',
#   '장소',
#   '아파트',
#   '더샾',
#   '상도동',
#   '이메일',
#   '유공',
#   '문자',
#   '조정',
#   '인테리어',
#   '경우',
#   '동작구',
#   '스텝',
#   '살림',
#   '일정',
#   '미리',
#   '상세',
#   '최상급',
#   '모던',
#   '촬영',
#   '차량',
#   '주소',
#   '내용',
#   '연락',
#   '문자메시지',
#   '도움',
#   '포스코',
#   '사진',
#   '발송',
#   '동반',
#   '분만'],
#  ['하우스',
#   '평수',
#   '갤러리',
#   '그림',
#   '클래식',
#   '가구',
#   '유화',
#   '분당',
#   '셀프',
#   '대형',
#   '소품',
#   '수내동',
#   '판교',
#   '아파트',
#   '주차공간',
#   '직접',
#   '요일',
#   '소품',
#   '인테리어',
#   '클래식',
#   '고층',
#   '선호',
#   '오전',
#   '하우스',
#   '그림',
#   '갤러리',
#   '화초',
#   '목욜',
#   '셀프',
#   '시간',
#   '제외',
#   '전망',
#   '여유',
#   '가구',
#   '그린'],
#  ['하우스',
#   '평수',
#   '갤러리',
#   '그림',
#   '클래식',
#   '가구',
#   '유화',
#   '분당',
#   '셀프',
#   '대형',
#   '소품',
#   '수내동',
#   '판교',
#   '아파트',
#   '주차공간',
#   '직접',
#   '요일',
#   '소품',
#   '인테리어',
#   '클래식',
#   '고층',
#   '선호',
#   '오전',
#   '하우스',
#   '그림',
#   '갤러리',
#   '화초',
#   '목욜',
#   '셀프',
#   '시간',
#   '제외',
#   '전망',
#   '여유',
#   '가구',
#   '그린'],
#  ['해링', '리본', '아파트', '마루'],
#  ['다락방',
#   '초대형',
#   '한남동',
#   '벽난로',
#   '산장',
#   '씨티',
#   '빌라',
#   '옥수동',
#   '한강',
#   '분위기',
#   '복층',
#   '다락방',
#   '경험',
#   '촬영',
#   '옥수동',
#   '서울',
#   '소품'],
#  ['다락방',
#   '초대형',
#   '한남동',
#   '벽난로',
#   '산장',
#   '씨티',
#   '빌라',
#   '옥수동',
#   '한강',
#   '분위기',
#   '복층',
#   '다락방',
#   '경험',
#   '촬영',
#   '옥수동',
#   '서울',
#   '소품'],
#  ['유러',
#   '양재동',
#   '주택',
#   '피안',
#   '빌라',
#   '모던',
#   '복층',
#   '유러',
#   '스타일',
#   '양재동',
#   '세팅',
#   '게스트',
#   '일요일',
#   '피안',
#   '빌라',
#   '모던',
#   '가정',
#   '요일',
#   '복층',
#   '제외',
#   '소품'],
#  ['유러',
#   '양재동',
#   '주택',
#   '피안',
#   '빌라',
#   '모던',
#   '복층',
#   '유러',
#   '스타일',
#   '양재동',
#   '세팅',
#   '게스트',
#   '일요일',
#   '피안',
#   '빌라',
#   '모던',
#   '가정',
#   '요일',
#   '복층',
#   '제외',
#   '소품'],
#  ['아파트'],
#  ['사무실',
#   '오피스',
#   '마케팅',
#   '위치',
#   '패션',
#   '오피스',
#   '뮤직',
#   '공간',
#   '유니크',
#   '광고',
#   '무드',
#   '서브컬쳐',
#   '감성',
#   '중심',
#   '언노운',
#   '머셜',
#   '거리',
#   '컨셉',
#   '회사',
#   '사무실',
#   '출신',
#   '언더그라운드',
#   '프라이',
#   '대기업',
#   '명의',
#   '지인'],
#  ['고급', '홈바', '아파트', '설치', '광교신도시', '요일', '가능'],
#  ['분위기', '무대', '스몰', '위치', '사용', '분위기', '무대', '마포구', '성산동'],
#  ['테라스',
#   '갤러리',
#   '노출',
#   '루프',
#   '촬영',
#   '현대',
#   '유니크',
#   '위치',
#   '건축물',
#   '하이',
#   '레벨',
#   '파주',
#   '가드',
#   '마을',
#   '규모',
#   '공간',
#   '현대',
#   '유니크',
#   '높이'],
#  ['광고',
#   '아파트',
#   '뉴트',
#   '촬영',
#   '서울',
#   '드라마',
#   '컬러',
#   '아파트',
#   '햇빛',
#   '베란다',
#   '카메라',
#   '전농동',
#   '표현',
#   '평일',
#   '선호',
#   '색감',
#   '거실',
#   '주말',
#   '동대문구',
#   '구조',
#   '남향',
#   '욕실',
#   '협의'],
#  ['광고',
#   '아파트',
#   '뉴트',
#   '촬영',
#   '서울',
#   '드라마',
#   '컬러',
#   '아파트',
#   '햇빛',
#   '베란다',
#   '카메라',
#   '전농동',
#   '표현',
#   '평일',
#   '선호',
#   '색감',
#   '거실',
#   '주말',
#   '동대문구',
#   '구조',
#   '남향',
#   '욕실',
#   '협의'],
#  ['장소',
#   '촬영',
#   '가정',
#   '영화',
#   '대관',
#   '아파트',
#   '모델링',
#   '주택',
#   '심플',
#   '문의',
#   '유의',
#   '촬영',
#   '시간',
#   '이용',
#   '살림살이'],
#  ['광고',
#   '화보',
#   '셔터',
#   '마크',
#   '사진',
#   '촬영',
#   '개인',
#   '드라마',
#   '감성',
#   '부부',
#   '장소',
#   '루버',
#   '위치',
#   '주방',
#   '합정역',
#   '빌라',
#   '서재',
#   '화이트',
#   '추가',
#   '공간',
#   '평수',
#   '원목',
#   '인테리어',
#   '작고',
#   '싱크대',
#   '마크',
#   '구입',
#   '가변',
#   '신축',
#   '테이블',
#   '접이식',
#   '하우스',
#   '대여',
#   '셔터',
#   '도어',
#   '안방',
#   '전체',
#   '구분',
#   '정도',
#   '출구',
#   '작품',
#   '작년',
#   '디자인',
#   '러브',
#   '테라스',
#   '이케아',
#   '아이템',
#   '사진',
#   '조명',
#   '공사',
#   '운영',
#   '저희',
#   '루버'],
#  ['광고',
#   '화보',
#   '셔터',
#   '마크',
#   '사진',
#   '촬영',
#   '개인',
#   '드라마',
#   '감성',
#   '부부',
#   '장소',
#   '루버',
#   '위치',
#   '주방',
#   '합정역',
#   '빌라',
#   '서재',
#   '화이트',
#   '추가',
#   '공간',
#   '평수',
#   '원목',
#   '인테리어',
#   '작고',
#   '싱크대',
#   '마크',
#   '구입',
#   '가변',
#   '신축',
#   '테이블',
#   '접이식',
#   '하우스',
#   '대여',
#   '셔터',
#   '도어',
#   '안방',
#   '전체',
#   '구분',
#   '정도',
#   '출구',
#   '작품',
#   '작년',
#   '디자인',
#   '러브',
#   '테라스',
#   '이케아',
#   '아이템',
#   '사진',
#   '조명',
#   '공사',
#   '운영',
#   '저희',
#   '루버'],
#  ['자동차',
#   '테마',
#   '갤러리',
#   '카페',
#   '촬영',
#   '장소',
#   '테마',
#   '오후',
#   '카페',
#   '특색',
#   '장소',
#   '촬영',
#   '요일',
#   '펍입니',
#   '오전'],
#  ['빈티',
#   '렌탈',
#   '장소',
#   '촬영',
#   '작업실',
#   '영화',
#   '공간',
#   '잡지',
#   '대관',
#   '위치',
#   '사용',
#   '유리',
#   '아트',
#   '찍기',
#   '스튜디오',
#   '공간',
#   '소품',
#   '빈티',
#   '인테리어',
#   '클래스',
#   '용도',
#   '연남동',
#   '행사',
#   '복합',
#   '작업실',
#   '감성',
#   '각종',
#   '느낌',
#   '촬영',
#   '모임',
#   '자연',
#   '전체',
#   '잡지',
#   '독서',
#   '평소',
#   '진행',
#   '화공',
#   '천고',
#   '원데이',
#   '아틀리에',
#   '사진',
#   '소규모'],
#  ['화보',
#   '농사',
#   '잔듸',
#   '배경',
#   '촬영',
#   '풍경',
#   '드라마',
#   '시골',
#   '장소',
#   '염소',
#   '추가',
#   '태양광도',
#   '잔디밭',
#   '경우',
#   '공장',
#   '차후',
#   '신분',
#   '시골',
#   '토끼',
#   '잔듸',
#   '종일',
#   '촬영',
#   '숙박',
#   '협의',
#   '주택',
#   '마리',
#   '요청',
#   '사진',
#   '고구마',
#   '하루'],
#  ['홍대',
#   '야구',
#   '연습장',
#   '촬영',
#   '데이트',
#   '드라마',
#   '영화',
#   '장소',
#   '위치',
#   '홍대',
#   '야구',
#   '연습장',
#   '실외'],
#  ['촬영', '호프', '장소', '펍입니', '이상', '수용', '분위기'],
#  ['모던',
#   '아지트',
#   '일링',
#   '주방',
#   '타운하우스',
#   '광합성',
#   '자체',
#   '유리',
#   '스타',
#   '멍하니',
#   '이방',
#   '채광',
#   '평수',
#   '공간',
#   '원목',
#   '산옆',
#   '수다',
#   '방이',
#   '기본',
#   '거실',
#   '화분',
#   '신축',
#   '게임',
#   '박스',
#   '테이블',
#   '새소리',
#   '전용',
#   '스타일',
#   '밤새',
#   '취향',
#   '느낌',
#   '만화책',
#   '곳곳',
#   '모던',
#   '촬영',
#   '초반',
#   '집안',
#   '침대',
#   '창문',
#   '부부',
#   '침실',
#   '파라솔',
#   '바베큐',
#   '테라스',
#   '방석',
#   '듣기',
#   '가구',
#   '브릭',
#   '신혼',
#   '보이',
#   '역시',
#   '커피',
#   '노리',
#   '소파',
#   '대신'],
#  ['북유럽',
#   '래미안',
#   '놀이',
#   '한세상',
#   '공원',
#   '근처',
#   '미니',
#   '방송국',
#   '아파트',
#   '이동',
#   '서재',
#   '마루',
#   '추가',
#   '책장',
#   '소품',
#   '거실',
#   '평형',
#   '아이',
#   '느낌',
#   '필요시',
#   '촬영',
#   '분위기',
#   '래미안',
#   '놀이',
#   '가구',
#   '한세상',
#   '앵글',
#   '잡기',
#   '소파',
#   '부엌'],
#  ['전망',
#   '홍대',
#   '거실',
#   '촬영',
#   '가족',
#   '서재',
#   '근처',
#   '미니',
#   '연출',
#   '위치',
#   '영상',
#   '이자',
#   '아파트',
#   '자주',
#   '브랜드',
#   '추가',
#   '책장',
#   '소품',
#   '유지',
#   '상태',
#   '정말',
#   '거실',
#   '평형',
#   '연남동',
#   '가족',
#   '아이',
#   '신축',
#   '공원',
#   '정리',
#   '장소',
#   '거의',
#   '느낌',
#   '촬영',
#   '분위기',
#   '상암동',
#   '미니',
#   '지은지',
#   '차지',
#   '베란다',
#   '전망',
#   '홍대',
#   '가구',
#   '근처',
#   '방송국'],
#  ['광고',
#   '카페',
#   '촬영',
#   '라운지',
#   '분위기',
#   '영화',
#   '컨셉',
#   '가격',
#   '위치',
#   '영상',
#   '이동',
#   '사용',
#   '일반',
#   '포켓볼',
#   '상이',
#   '수용',
#   '라운지',
#   '장시간',
#   '방이동',
#   '인원',
#   '영화',
#   '예능',
#   '도보',
#   '무선',
#   '소품',
#   '관료',
#   '올림픽공원역',
#   '추가',
#   '원상',
#   '최대',
#   '최소',
#   '다트',
#   '잉여',
#   '필수',
#   '문의',
#   '동영상',
#   '협상',
#   '사진촬영',
#   '대형',
#   '요금',
#   '마이크',
#   '유튜브',
#   '기기',
#   '미러볼',
#   '느낌',
#   '색조',
#   '거리',
#   '뮤비',
#   '종일',
#   '영업',
#   '사이',
#   '방이역',
#   '모던',
#   '촬영',
#   '할증',
#   '예약',
#   '모든',
#   '종류',
#   '일시',
#   '가능',
#   '시간',
#   '천장',
#   '약시',
#   '디제잉',
#   '프로젝터',
#   '이후',
#   '주차',
#   '스크린',
#   '인치',
#   '사진',
#   '규모',
#   '컨셉',
#   '대관',
#   '복구'],
#  ['인테리어',
#   '주택',
#   '전원',
#   '별채',
#   '조성',
#   '잔디',
#   '실내',
#   '언덕',
#   '특징',
#   '주변',
#   '구분',
#   '귤밭',
#   '복층',
#   '저희'],
#  ['사옥',
#   '전망',
#   '야경',
#   '올림픽',
#   '공원',
#   '노을',
#   '미니',
#   '올림픽공원역',
#   '위치',
#   '호선',
#   '아파트',
#   '강동구',
#   '야경',
#   '바로',
#   '남향',
#   '올림픽공원역',
#   '군더더기',
#   '공원',
#   '종일',
#   '촬영',
#   '분위기',
#   '전망',
#   '올림픽',
#   '가지',
#   '여러가지',
#   '일대',
#   '탁트인',
#   '햇살',
#   '하루'],
#  ['강화도',
#   '시골',
#   '대형',
#   '주택',
#   '뮤직비디오',
#   '위치',
#   '광고',
#   '화보',
#   '대여',
#   '일요일',
#   '평일',
#   '기존',
#   '촬영',
#   '강화도',
#   '드라마',
#   '다른',
#   '예약',
#   '수락',
#   '영화',
#   '제외',
#   '시골',
#   '숲속'],
#  ['피시방',
#   '일반',
#   '영업',
#   '씨방',
#   '상업',
#   '공간',
#   '형식',
#   '공휴일',
#   '사용',
#   '언제',
#   '주말',
#   '분위기',
#   '겔러리',
#   '가능',
#   '익일',
#   '목요일'],
#  ['인테리어', '카페', '규모', '흡연실', '환경'],
#  ['광고',
#   '코딩',
#   '녹음실',
#   '녹음',
#   '강남',
#   '영상',
#   '남녀',
#   '시설',
#   '코딩',
#   '샤워',
#   '스튜디오',
#   '영화',
#   '분리',
#   '광고',
#   '화장실',
#   '최적화',
#   '이용',
#   '유튜브',
#   '머신',
#   '촬영',
#   '드라마',
#   '가능',
#   '냉온',
#   '로비',
#   '공용',
#   '주차',
#   '수기',
#   '커피'],
#  ['감성', '공간', '대관', '성북구', '촬영', '특수', '조명', '운동', '컨셉', '대관'],
#  ['한남동',
#   '대안',
#   '갤러리',
#   '장소',
#   '복합',
#   '이태원',
#   '문화',
#   '공간',
#   '전시',
#   '대관',
#   '스모그',
#   '시설',
#   '수용',
#   '이태원',
#   '예술',
#   '와이파이',
#   '공간',
#   '외부',
#   '대안',
#   '액자',
#   '상상',
#   '행사',
#   '스툴',
#   '수납',
#   '최적화',
#   '마켓',
#   '촬영',
#   '전시',
#   '컬러',
#   '접근성',
#   '색상',
#   '무관',
#   '조성',
#   '빙기',
#   '위치',
#   '심플',
#   '인원',
#   '화이트',
#   '사인',
#   '환경',
#   '풍기',
#   '카페',
#   '용도',
#   '세면대',
#   '냉장고',
#   '여러',
#   '공연',
#   '모든',
#   '냉온',
#   '쇼케이스',
#   '작품',
#   '프로젝터',
#   '레일',
#   '실내',
#   '수기',
#   '조명',
#   '커피',
#   '운영',
#   '대한',
#   '다이나믹',
#   '파티',
#   '윈도우',
#   '팝업',
#   '스토어',
#   '안내',
#   '실현',
#   '보드',
#   '머신',
#   '예술가',
#   '통해',
#   '분위기',
#   '화공',
#   '디자인',
#   '코드',
#   '전자레인지',
#   '연출',
#   '내부',
#   '이자',
#   '인포',
#   '전시장',
#   '호리',
#   '자랑',
#   '큐알',
#   '성격',
#   '술집',
#   '복합',
#   '서울',
#   '화장실',
#   '오픈',
#   '장소',
#   '이용',
#   '테이블',
#   '로고',
#   '최고',
#   '방문',
#   '플리',
#   '장비',
#   '스피커',
#   '정보',
#   '평소',
#   '의자'],
#  ['농장',
#   '매실',
#   '보은',
#   '마당',
#   '오두막',
#   '잔디',
#   '산속',
#   '시크릿',
#   '동산',
#   '주차장',
#   '왕래',
#   '마당',
#   '지대',
#   '공터',
#   '주차',
#   '모던',
#   '풍경',
#   '시간',
#   '근처',
#   '길가',
#   '편이'],
#  ['카페',
#   '터치',
#   '분위기',
#   '무인',
#   '자판기',
#   '커피숍',
#   '머신',
#   '인테리어',
#   '카페',
#   '개념',
#   '이태리',
#   '촬영',
#   '무인',
#   '자동',
#   '제외'],
#  ['신혼집',
#   '미니',
#   '근처',
#   '영상',
#   '아파트',
#   '잠깐',
#   '제품',
#   '사용',
#   '최대한',
#   '흰색',
#   '인원',
#   '신혼집',
#   '규모',
#   '수리',
#   '전동칫솔',
#   '추가',
#   '공간',
#   '변형',
#   '닉스',
#   '이사',
#   '이력',
#   '가전제품',
#   '레트로',
#   '물건',
#   '광고',
#   '인테리어',
#   '용마산',
#   '오히려',
#   '평일',
#   '바이럴',
#   '마음',
#   '설치',
#   '목적',
#   '회색조',
#   '거실',
#   '풀이',
#   '고려',
#   '공원',
#   '오시',
#   '생수',
#   '구성',
#   '맘껏',
#   '직장',
#   '장소',
#   '오전',
#   '욕실',
#   '대여',
#   '드릴',
#   '카메라',
#   '전집',
#   '종류',
#   '촬영',
#   '주중',
#   '회사',
#   '제공',
#   '장비',
#   '주위',
#   '전체',
#   '내용',
#   '미니',
#   '평소',
#   '대방동',
#   '금번',
#   '무방',
#   '무채색',
#   '사진',
#   '노량진',
#   '여러가지',
#   '조명',
#   '금년',
#   '도심',
#   '평이',
#   '와이프',
#   '인서트',
#   '활용'],
#  ['마리나',
#   '회장',
#   '카페',
#   '반포',
#   '보트',
#   '요트',
#   '럭셔리',
#   '동작',
#   '리버',
#   '느낌',
#   '리뉴',
#   '관심',
#   '모습',
#   '마치',
#   '공간',
#   '여러분',
#   '외국',
#   '저희'],
#  ['관리',
#   '헤어',
#   '일산',
#   '미용실',
#   '두피',
#   '살롱',
#   '위치',
#   '프리',
#   '기석',
#   '사용',
#   '일반',
#   '개별룸',
#   '요일',
#   '주말',
#   '사전예약',
#   '실제',
#   '인테리어',
#   '최소',
#   '헤어',
#   '느낌',
#   '미용실',
#   '모던',
#   '촬영',
#   '보통',
#   '예약',
#   '프리미엄',
#   '달리',
#   '홈쇼핑',
#   '요청',
#   '일산',
#   '상담',
#   '한적',
#   '월요일',
#   '살롱'],
#  ['다트',
#   '술집',
#   '카페',
#   '실내',
#   '맥주',
#   '양궁',
#   '사격장',
#   '무료',
#   '다트',
#   '카페',
#   '실내',
#   '맥주',
#   '주차',
#   '양궁',
#   '사격'],
#  ['분당',
#   '가게',
#   '카페',
#   '샌드위치',
#   '위치',
#   '연출',
#   '인테리어',
#   '오후',
#   '가게',
#   '정자동',
#   '평일',
#   '일요일',
#   '촬영',
#   '분당',
#   '가능',
#   '시간',
#   '선호',
#   '협의'],
#  ['주택',
#   '빈방',
#   '경상남도',
#   '위치',
#   '때문',
#   '사용',
#   '도시가스',
#   '인테리어',
#   '마산합포구',
#   '상태',
#   '장기간',
#   '설치',
#   '거실',
#   '계약',
#   '구성',
#   '렌즈',
#   '비교',
#   '욕실',
#   '대여',
#   '서로',
#   '가스',
#   '집기',
#   '촬영',
#   '방임',
#   '다른',
#   '합의',
#   '주택',
#   '창원시',
#   '비어',
#   '그대로',
#   '최적',
#   '부엌'],
#  ['정원', '가든', '카페', '정말', '아주'],
#  ['이면', '강남', '지하철'],
#  ['케이',
#   '터링',
#   '파티',
#   '카페',
#   '직장인',
#   '예술가',
#   '프라이',
#   '작업실',
#   '모임',
#   '와인',
#   '위치',
#   '레이스',
#   '장점',
#   '파티',
#   '사용',
#   '폴딩도어',
#   '근방',
#   '스튜디오',
#   '공간',
#   '주차장',
#   '휴일',
#   '무료',
#   '카페',
#   '클래스',
#   '세로',
#   '가로수길',
#   '현재',
#   '인접',
#   '주변',
#   '랜덤',
#   '테이블',
#   '공영',
#   '공휴일',
#   '준비',
#   '모임',
#   '사설',
#   '수업',
#   '테라스',
#   '플레이',
#   '가장',
#   '활용',
#   '원데이',
#   '주차',
#   '신사동',
#   '의자',
#   '부엌'],
#  ['케이',
#   '터링',
#   '파티',
#   '카페',
#   '직장인',
#   '예술가',
#   '프라이',
#   '작업실',
#   '모임',
#   '와인',
#   '위치',
#   '레이스',
#   '장점',
#   '파티',
#   '사용',
#   '폴딩도어',
#   '근방',
#   '스튜디오',
#   '공간',
#   '주차장',
#   '휴일',
#   '무료',
#   '카페',
#   '클래스',
#   '세로',
#   '가로수길',
#   '현재',
#   '인접',
#   '주변',
#   '랜덤',
#   '테이블',
#   '공영',
#   '공휴일',
#   '준비',
#   '모임',
#   '사설',
#   '수업',
#   '테라스',
#   '플레이',
#   '가장',
#   '활용',
#   '원데이',
#   '주차',
#   '신사동',
#   '의자',
#   '부엌'],
#  ['강연',
#   '지하',
#   '행사',
#   '라운지',
#   '신사역',
#   '소규모',
#   '팬미팅',
#   '전시',
#   '독특',
#   '천정',
#   '위치',
#   '파티',
#   '사용',
#   '메인',
#   '라운지',
#   '브랜드',
#   '신사역',
#   '지하공간',
#   '공간',
#   '팬미팅',
#   '강연',
#   '가로수길',
#   '현재',
#   '행사',
#   '고가',
#   '대여',
#   '느낌',
#   '전시',
#   '에이'],
#  ['강연',
#   '지하',
#   '행사',
#   '라운지',
#   '신사역',
#   '소규모',
#   '팬미팅',
#   '전시',
#   '독특',
#   '천정',
#   '위치',
#   '파티',
#   '사용',
#   '메인',
#   '라운지',
#   '브랜드',
#   '신사역',
#   '지하공간',
#   '공간',
#   '팬미팅',
#   '강연',
#   '가로수길',
#   '현재',
#   '행사',
#   '고가',
#   '대여',
#   '느낌',
#   '전시',
#   '에이'],
#  ['벽난로',
#   '고기',
#   '펜션',
#   '토방',
#   '숯불',
#   '가마솥',
#   '벽난로',
#   '전원주택',
#   '고기',
#   '펜션',
#   '단체',
#   '특색',
#   '거실',
#   '토방',
#   '숯불',
#   '시골',
#   '가마솥'],
#  ['한남동',
#   '주방',
#   '자연',
#   '쿠킹',
#   '전통',
#   '가마솥',
#   '위치',
#   '주택가',
#   '버전',
#   '렌탈',
#   '주방',
#   '위해',
#   '사용',
#   '한국',
#   '설렁탕',
#   '음식',
#   '렌탈비',
#   '김은아',
#   '스튜디오',
#   '실제',
#   '추가',
#   '소품',
#   '보유',
#   '작업',
#   '광고',
#   '양해',
#   '모델링',
#   '평상',
#   '상태',
#   '설치',
#   '문의',
#   '가정',
#   '대형',
#   '현대',
#   '너른',
#   '도시락',
#   '촬영',
#   '복구',
#   '전체',
#   '참조',
#   '인분',
#   '책정',
#   '한남동',
#   '이상',
#   '저희',
#   '스핀오프',
#   '해석',
#   '활용',
#   '별도',
#   '단순',
#   '조리',
#   '전통',
#   '가마솥',
#   '부엌'],
#  ['성주',
#   '해인사',
#   '잔디',
#   '정원',
#   '가야산',
#   '경관',
#   '마당',
#   '연못',
#   '잔디',
#   '정자',
#   '자연',
#   '는걸',
#   '공간',
#   '유실수',
#   '손주',
#   '자식',
#   '감상',
#   '햇살'],
#  ['가정',
#   '위치',
#   '아파트',
#   '사용',
#   '대상',
#   '유희',
#   '주로',
#   '광장',
#   '일요일',
#   '건축',
#   '실로',
#   '방이',
#   '현재',
#   '거실',
#   '가정',
#   '아이',
#   '교실',
#   '단지',
#   '원중',
#   '가능',
#   '시간',
#   '정도',
#   '산책',
#   '형태',
#   '어린이집',
#   '연령',
#   '월요일',
#   '보육',
#   '중앙'],
#  ['가정', '순천만', '전남', '순천', '가정', '정원'],
#  ['가정', '유투브', '사용', '입자', '촬영', '주말', '오시', '기타', '선호'],
#  ['가정', '강아지', '직장인', '가족', '거주', '대학생', '부부', '중년'],
#  ['가정',
#   '방도',
#   '베란다',
#   '놀이',
#   '일반',
#   '모두',
#   '거실',
#   '주말',
#   '가정',
#   '화장실',
#   '주중',
#   '촬영',
#   '아이',
#   '거주',
#   '중인'],
#  ['주택',
#   '성내동',
#   '강동구',
#   '빌라',
#   '가정',
#   '강동역',
#   '서울시',
#   '신축',
#   '위치',
#   '내부',
#   '세탁실',
#   '주방',
#   '평일',
#   '모두',
#   '강동구',
#   '빌라',
#   '주말',
#   '거실',
#   '화장실',
#   '신축',
#   '서울시',
#   '얼마',
#   '건물',
#   '협의'],
#  ['디자인',
#   '베란다',
#   '아파트',
#   '식물',
#   '안방',
#   '가구',
#   '거실',
#   '모던',
#   '가정',
#   '부엌',
#   '위치',
#   '아파트',
#   '베란다',
#   '느낌',
#   '동네',
#   '거실',
#   '가정',
#   '자락',
#   '후암동',
#   '컨셉',
#   '남산'],
#  ['광고',
#   '대리석',
#   '아파트',
#   '촬영',
#   '가정',
#   '신혼집',
#   '쇼핑몰',
#   '대관',
#   '위치',
#   '아파트',
#   '전망',
#   '부분',
#   '평일',
#   '부산',
#   '촬영',
#   '주말',
#   '시공간',
#   '조명',
#   '분위기',
#   '일정',
#   '수의',
#   '은평',
#   '협의'],
#  ['까페',
#   '대리석',
#   '아파트',
#   '심플',
#   '모던',
#   '가정',
#   '까페',
#   '느낌',
#   '일반',
#   '심플',
#   '모던',
#   '가정',
#   '공간',
#   '컨셉'],
#  ['까페',
#   '대리석',
#   '아파트',
#   '심플',
#   '모던',
#   '가정',
#   '까페',
#   '느낌',
#   '일반',
#   '심플',
#   '모던',
#   '가정',
#   '공간',
#   '컨셉'],
#  ['가정', '인천', '아파트', '서재', '위치', '인천', '거의', '가구', '거실', '가정', '다른'],
#  ['가정', '인천', '아파트', '서재', '위치', '인천', '거의', '가구', '거실', '가정', '다른'],
#  ['아파트',
#   '모던',
#   '가정',
#   '주말',
#   '소음',
#   '가능',
#   '근처',
#   '아파트',
#   '시설',
#   '무엇',
#   '방해',
#   '심플',
#   '주말',
#   '추가',
#   '바로',
#   '공간',
#   '하루',
#   '조율',
#   '주차장',
#   '통일로',
#   '평일',
#   '올해',
#   '문의',
#   '복합',
#   '구파발역',
#   '대형',
#   '미리',
#   '이용',
#   '오전',
#   '외곽순환',
#   '몰이',
#   '답변',
#   '촬영',
#   '주시',
#   '저녁',
#   '롯데',
#   '주위',
#   '편의',
#   '시간',
#   '송추',
#   '연락',
#   '장시',
#   '아주',
#   '여유',
#   '주차',
#   '주상',
#   '도로',
#   '신규'],
#  ['하우스',
#   '파티',
#   '게스트하우스',
#   '럭셔리',
#   '펜션',
#   '가정',
#   '서울',
#   '도시',
#   '공간',
#   '단독주택',
#   '일반',
#   '주차공간',
#   '주말',
#   '협소하',
#   '정원',
#   '추가',
#   '공간',
#   '외부',
#   '관광객',
#   '구조',
#   '홍대입구역',
#   '유료',
#   '소형차',
#   '취소',
#   '게스트하우스',
#   '상태',
#   '회신',
#   '공지',
#   '현관',
#   '거실',
#   '일정',
#   '사전',
#   '이용',
#   '코로나',
#   '욕실',
#   '전용',
#   '요금',
#   '하우스',
#   '대의',
#   '객실',
#   '느낌',
#   '인근',
#   '확인',
#   '기간',
#   '모임',
#   '보통',
#   '예약',
#   '주중',
#   '파티룸',
#   '전체',
#   '가능',
#   '할인',
#   '평소',
#   '생동감',
#   '안쪽',
#   '테라스',
#   '여부',
#   '요청',
#   '출입문',
#   '주차',
#   '배치',
#   '얼마',
#   '실시',
#   '운영',
#   '대관',
#   '저희',
#   '개층'],
#  ['레트로',
#   '가정',
#   '큰집',
#   '쓰리룸',
#   '채광',
#   '대형',
#   '원목',
#   '위치',
#   '조심',
#   '방해',
#   '지대',
#   '모두',
#   '수용',
#   '완료',
#   '숙소',
#   '로부터',
#   '논현',
#   '공간',
#   '채광',
#   '매우',
#   '도보',
#   '원목',
#   '소품',
#   '환경',
#   '중인',
#   '주차장',
#   '초등학교',
#   '인테리어',
#   '해당',
#   '경우',
#   '기본',
#   '평지',
#   '작은방',
#   '거실',
#   '주변',
#   '자유',
#   '방만',
#   '대관',
#   '이용',
#   '관리',
#   '하우스',
#   '호수',
#   '독층',
#   '비밀',
#   '느낌',
#   '인근',
#   '거리',
#   '통해',
#   '촬영',
#   '시간대',
#   '소음',
#   '분위기',
#   '모든',
#   '장비',
#   '스태프',
#   '전체',
#   '거주',
#   '정도',
#   '구비',
#   '하나',
#   '옥상',
#   '전반',
#   '편이',
#   '분실',
#   '공용',
#   '중간',
#   '해주시',
#   '베란다',
#   '별도',
#   '출입문',
#   '가구',
#   '주차',
#   '단독',
#   '파손',
#   '신논현역',
#   '역시',
#   '공사',
#   '공영',
#   '운영',
#   '햇살',
#   '활용'],
#  ['평수',
#   '아파트',
#   '모던',
#   '가정',
#   '복합',
#   '주상',
#   '대형',
#   '인테리어',
#   '추천',
#   '모던',
#   '복합',
#   '주상',
#   '장소'],
#  ['주택',
#   '일산',
#   '빌라',
#   '가정',
#   '개인',
#   '방송',
#   '투룸',
#   '하우스',
#   '게스트하우스',
#   '킨텍스',
#   '문의',
#   '거실',
#   '평소',
#   '대화역',
#   '촬영',
#   '운영',
#   '근처',
#   '투룸',
#   '햇살'],
#  ['가정', '아파트', '베란다', '가정', '시간'],
#  ['복도',
#   '레트로',
#   '빈티',
#   '아파트',
#   '촬영',
#   '가정',
#   '이태원',
#   '혼사',
#   '대관',
#   '뮤직비디오',
#   '레이스',
#   '선정',
#   '무게',
#   '그동안',
#   '남성',
#   '지금',
#   '혼자',
#   '슈퍼',
#   '공간',
#   '바로',
#   '최근',
#   '이야기',
#   '다수',
#   '감성',
#   '촬영',
#   '예약',
#   '분위기',
#   '가구',
#   '조명',
#   '인스타그램',
#   '호스트'],
#  ['복도',
#   '레트로',
#   '빈티',
#   '아파트',
#   '촬영',
#   '가정',
#   '이태원',
#   '혼사',
#   '대관',
#   '뮤직비디오',
#   '레이스',
#   '선정',
#   '무게',
#   '그동안',
#   '남성',
#   '지금',
#   '혼자',
#   '슈퍼',
#   '공간',
#   '바로',
#   '최근',
#   '이야기',
#   '다수',
#   '감성',
#   '촬영',
#   '예약',
#   '분위기',
#   '가구',
#   '조명',
#   '인스타그램',
#   '호스트'],
#  ['람사', '가정', '가족', '아파트', '테라스', '다방', '파우더', '가정', '룸각', '가족', '화장실'],
#  ['아파트',
#   '근교',
#   '클래식',
#   '우드',
#   '가정',
#   '서울',
#   '아파트',
#   '인테리어',
#   '클래식',
#   '느낌',
#   '평일',
#   '모두',
#   '우드',
#   '촬영',
#   '가정',
#   '주말',
#   '일정',
#   '전체',
#   '장소',
#   '진행'],
#  ['아파트',
#   '근교',
#   '클래식',
#   '우드',
#   '가정',
#   '서울',
#   '아파트',
#   '인테리어',
#   '클래식',
#   '느낌',
#   '평일',
#   '모두',
#   '우드',
#   '촬영',
#   '가정',
#   '주말',
#   '일정',
#   '전체',
#   '장소',
#   '진행'],
#  ['테라스',
#   '홍대',
#   '가정',
#   '서교동',
#   '내츄럴',
#   '주차장',
#   '위치',
#   '테라스',
#   '느낌',
#   '홍대',
#   '거리',
#   '메인',
#   '주차',
#   '엘리베이터',
#   '공간',
#   '사람',
#   '햇살',
#   '구조'],
#  ['테라스',
#   '홍대',
#   '입구',
#   '가정',
#   '내츄럴',
#   '위치',
#   '주방',
#   '테라스',
#   '느낌',
#   '홍대',
#   '주차',
#   '정문',
#   '엘리베이터',
#   '공간',
#   '사람',
#   '분리',
#   '햇살',
#   '유료'],
#  ['가정',
#   '아파트',
#   '엔틱',
#   '아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['가정',
#   '아파트',
#   '엔틱',
#   '아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['가정',
#   '아파트',
#   '엔틱',
#   '아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['목포',
#   '아파트',
#   '김대중',
#   '광장',
#   '영산강',
#   '가정',
#   '주변',
#   '평화',
#   '센터',
#   '컨벤션',
#   '까페',
#   '목포',
#   '아파트',
#   '광장',
#   '영산강',
#   '갓바위',
#   '공원',
#   '주변',
#   '평화'],
#  ['목포',
#   '아파트',
#   '김대중',
#   '광장',
#   '영산강',
#   '가정',
#   '주변',
#   '평화',
#   '센터',
#   '컨벤션',
#   '까페',
#   '목포',
#   '아파트',
#   '광장',
#   '영산강',
#   '갓바위',
#   '공원',
#   '주변',
#   '평화'],
#  ['일산', '가정', '아파트', '일산', '세가족'],
#  ['하우스',
#   '대여',
#   '아파트',
#   '그램',
#   '장소',
#   '스타',
#   '가정',
#   '촬영',
#   '홈인',
#   '테리어',
#   '홈스',
#   '대관',
#   '위치',
#   '우드',
#   '한강',
#   '공간',
#   '구조',
#   '카페',
#   '야산',
#   '거실',
#   '가정',
#   '마주',
#   '정돈',
#   '알파룸',
#   '느낌',
#   '창밖',
#   '모던',
#   '개인',
#   '분위기',
#   '지니',
#   '전망',
#   '신도시',
#   '가구',
#   '햇살',
#   '활용'],
#  ['어항',
#   '작고',
#   '화초',
#   '가정',
#   '해수어',
#   '어항',
#   '작고',
#   '마리',
#   '게스트',
#   '일반',
#   '또한',
#   '화초',
#   '요일',
#   '가정',
#   '분위기',
#   '해수어',
#   '시간',
#   '그냥',
#   '고양이'],
#  ['광주',
#   '가정',
#   '자연',
#   '가족',
#   '경기',
#   '생활',
#   '주방',
#   '지정',
#   '사용',
#   '광주',
#   '경험',
#   '빌라',
#   '강남',
#   '공간',
#   '경기',
#   '빵빵',
#   '퇴근',
#   '평일',
#   '문의',
#   '거실',
#   '현관',
#   '가정',
#   '널널',
#   '가족',
#   '화장실',
#   '주변',
#   '오전',
#   '에어컨',
#   '영화제',
#   '촬영',
#   '차량',
#   '가능',
#   '시간',
#   '다용도실',
#   '해둘',
#   '주차',
#   '타임'],
#  ['촬영장',
#   '대여',
#   '아파트',
#   '가정',
#   '층집',
#   '건물',
#   '위치',
#   '신월',
#   '아파트',
#   '통과',
#   '축구장',
#   '양천구',
#   '일반',
#   '초소',
#   '정문',
#   '금액',
#   '산책로',
#   '외부',
#   '주차장',
#   '세금',
#   '아마',
#   '크게',
#   '제약',
#   '편입',
#   '또한',
#   '거실',
#   '크레인',
#   '가정',
#   '주변',
#   '장소',
#   '오전',
#   '발행',
#   '관리',
#   '사무소',
#   '대여',
#   '방문',
#   '출근시간',
#   '놀이터',
#   '촬영',
#   '여비',
#   '계산서',
#   '차량',
#   '협조',
#   '기준',
#   '저녁',
#   '시간',
#   '구분',
#   '시엔',
#   '협의',
#   '베란다',
#   '안쪽',
#   '모델',
#   '잔디',
#   '포함',
#   '주차',
#   '벤츠',
#   '부엌'],
#  ['대여',
#   '제품',
#   '바이럴',
#   '자취',
#   '촬영',
#   '가정',
#   '여자',
#   '대관',
#   '연출',
#   '영상',
#   '제품',
#   '사이드',
#   '방해',
#   '모두',
#   '배경',
#   '패드',
#   '톤앤',
#   '무상',
#   '스튜디오',
#   '공간',
#   '외부',
#   '분리',
#   '매우',
#   '소품',
#   '광고',
#   '쁘띠',
#   '바이럴',
#   '와인잔',
#   '여성',
#   '거실',
#   '베이지',
#   '사실',
#   '식기',
#   '웜톤',
#   '장소',
#   '와인',
#   '그레이',
#   '전용',
#   '유튜브',
#   '취향',
#   '가전',
#   '대여',
#   '저택',
#   '각종',
#   '느낌',
#   '룩스',
#   '관련',
#   '필요시',
#   '고급',
#   '촬영',
#   '연결',
#   '소음',
#   '드라마',
#   '개인',
#   '저녁',
#   '주류',
#   '전체',
#   '구비',
#   '전반',
#   '진행',
#   '계단',
#   '저격',
#   '조명도',
#   '생각',
#   '거부',
#   '틱톡',
#   '매너',
#   '별도',
#   '포함',
#   '고풍',
#   '아이보리',
#   '투룸입니',
#   '배치',
#   '조명',
#   '소규모',
#   '시기',
#   '역시',
#   '호도',
#   '모바일',
#   '밝기',
#   '대관',
#   '스탠드'],
#  ['가정',
#   '섭외',
#   '빼기',
#   '동선',
#   '주방',
#   '가구',
#   '거실',
#   '촬영',
#   '배치',
#   '안성맞춤',
#   '햇볕',
#   '화이트',
#   '소품',
#   '일자'],
#  ['촬영',
#   '가정',
#   '차편',
#   '전망',
#   '단독주택',
#   '호선',
#   '오후',
#   '지하철',
#   '사전',
#   '삼송역',
#   '환상',
#   '주차',
#   '사이',
#   '촬영',
#   '주말',
#   '문의',
#   '주중',
#   '근처',
#   '오전'],
#  ['대여',
#   '아파트',
#   '거실',
#   '촬영',
#   '가정',
#   '고층',
#   '공간',
#   '남향',
#   '유튜브',
#   '대여',
#   '아파트',
#   '아일랜드',
#   '식탁',
#   '거실',
#   '촬영',
#   '정원',
#   '소품',
#   '미니',
#   '남향',
#   '부엌'],
#  ['테라스',
#   '모델링',
#   '가제',
#   '정원',
#   '용산',
#   '단독주택',
#   '섭외',
#   '위해',
#   '종종',
#   '요일',
#   '영화',
#   '정원',
#   '모델링',
#   '일요일',
#   '아이',
#   '이용',
#   '선호',
#   '오전',
#   '대여',
#   '놀이터',
#   '촬영',
#   '시간대',
#   '드라마',
#   '가능',
#   '전체',
#   '협의',
#   '오후',
#   '테라스',
#   '요청',
#   '도심',
#   '월요일'],
#  ['세대',
#   '주인',
#   '가족',
#   '장비',
#   '식탁',
#   '다가',
#   '내부',
#   '주차공간',
#   '건물',
#   '유지',
#   '등반',
#   '인테리어',
#   '내외',
#   '세대',
#   '암벽등반',
#   '상태',
#   '쇼파',
#   '거실',
#   '살림',
#   '주인',
#   '주변',
#   '정리',
#   '모든',
#   '장비',
#   '이나',
#   '주택',
#   '주차',
#   '사진',
#   '다가',
#   '취미'],
#  ['광고',
#   '아파트',
#   '촬영',
#   '신혼집',
#   '가족',
#   '드라마',
#   '잡지',
#   '몇번',
#   '아파트',
#   '미세먼지',
#   '현장',
#   '북한',
#   '화이트',
#   '처럼',
#   '카페',
#   '거실',
#   '감성',
#   '포차',
#   '하우스',
#   '상황',
#   '안방',
#   '촬영',
#   '뿜뿜',
#   '촬영장',
#   '베란다',
#   '아주',
#   '소로',
#   '신혼',
#   '파주',
#   '산이'],
#  ['북유럽',
#   '번화가',
#   '아파트',
#   '촬영',
#   '가족',
#   '내츄럴',
#   '위치',
#   '장점',
#   '아파트',
#   '때문',
#   '주말',
#   '세트',
#   '도보',
#   '소품',
#   '남향',
#   '민락',
#   '극장',
#   '인테리어',
#   '용도',
#   '설치',
#   '고속도로',
#   '방면',
#   '미리',
#   '이용',
#   '내츄럴',
#   '북유럽',
#   '스타일',
#   '각종',
#   '거리',
#   '종일',
#   '곳곳',
#   '자연',
#   '로데오거리',
#   '미니',
#   '의정부',
#   '협의',
#   '모델하우스',
#   '장외',
#   '비어',
#   '조명',
#   '지구',
#   '야간',
#   '하루',
#   '활용'],
#  ['탑층',
#   '이케아',
#   '촬영',
#   '스타',
#   '편안함',
#   '가족',
#   '필드',
#   '화이트',
#   '노을',
#   '조금',
#   '아파트',
#   '화이트',
#   '조율',
#   '공간',
#   '확장',
#   '남향',
#   '평일',
#   '거실',
#   '서울',
#   '스케줄',
#   '경기도',
#   '미리',
#   '오전',
#   '장면',
#   '신혼부부',
#   '사이',
#   '촬영',
#   '주시',
#   '시간',
#   '연락',
#   '오후',
#   '공사',
#   '노을',
#   '정리정돈'],
#  ['번화가',
#   '영상',
#   '대여',
#   '홍대',
#   '바이럴',
#   '촬영',
#   '가정',
#   '가족',
#   '장소',
#   '위치',
#   '아파트',
#   '자주',
#   '눈앞',
#   '편안함',
#   '공간',
#   '확장',
#   '기와',
#   '서대문구',
#   '신촌',
#   '거실',
#   '마포구',
#   '정리',
#   '오전',
#   '탑층',
#   '사이',
#   '촬영',
#   '시간',
#   '정도',
#   '편이',
#   '오후',
#   '베란다',
#   '홍대',
#   '일대',
#   '공사',
#   '햇살'],
#  ['오이',
#   '펜션',
#   '단체',
#   '야외',
#   '가평',
#   '코스',
#   '가족',
#   '레저',
#   '정원',
#   '장점',
#   '커플',
#   '시설',
#   '오이',
#   '사용',
#   '유럽',
#   '심플',
#   '레저',
#   '정원',
#   '노래방',
#   '주차장',
#   '인테리어',
#   '세미나',
#   '부대',
#   '단체',
#   '가족',
#   '대형',
#   '스타일',
#   '객실',
#   '야외',
#   '모던',
#   '코스',
#   '자연',
#   '사이즈',
#   '체육',
#   '휴식',
#   '촬영',
#   '구비',
#   '바베큐',
#   '잔디',
#   '펜션',
#   '저희'],
#  ['펜션',
#   '가족',
#   '스파',
#   '위치',
#   '동의보감',
#   '예담',
#   '선사',
#   '화이트',
#   '로우',
#   '카페',
#   '호강',
#   '산청읍',
#   '대원사',
#   '레드',
#   '그레이',
#   '명소',
#   '둘레길',
#   '남사',
#   '블루',
#   '야외',
#   '코스',
#   '몬드리안',
#   '바베큐',
#   '레프',
#   '펜션',
#   '수영장',
#   '지리산',
#   '컨셉',
#   '그린'],
#  ['까페',
#   '강변',
#   '독채',
#   '웨딩',
#   '스몰',
#   '북한',
#   '가평',
#   '야외',
#   '경기',
#   '위치',
#   '대지',
#   '파티',
#   '최선',
#   '언제',
#   '라운지',
#   '독채펜션',
#   '터미널',
#   '정원',
#   '설악',
#   '공간',
#   '위트',
#   '생명력',
#   '주차장',
#   '빈티',
#   '무료',
#   '접근',
#   '카페',
#   '파란',
#   '청평',
#   '더욱',
#   '단풍',
#   '서울',
#   '하늘',
#   '세미',
#   '고속도로',
#   '겨울',
#   '대형',
#   '대중교통',
#   '프레이',
#   '사철',
#   '이용',
#   '북유럽',
#   '스타일',
#   '하우스',
#   '각종',
#   '장소',
#   '완비',
#   '버스',
#   '사시',
#   '거리',
#   '춘천',
#   '야외',
#   '매력',
#   '모던',
#   '촬영',
#   '자연',
#   '지니',
#   '진입',
#   '우천',
#   '타고',
#   '작품',
#   '대비',
#   '여름',
#   '웨딩',
#   '가을',
#   '주차',
#   '평의',
#   '이벤트',
#   '대관',
#   '활용'],
#  ['마당',
#   '주택',
#   '노출',
#   '잔디',
#   '아침',
#   '가평',
#   '정원',
#   '시골',
#   '고요',
#   '수목원',
#   '연출',
#   '위치',
#   '전원주택',
#   '언제',
#   '배경',
#   '녹음',
#   '주말',
#   '돌출',
#   '모델링',
#   '풍경',
#   '시골',
#   '이용',
#   '아래층',
#   '마당',
#   '촬영',
#   '자연',
#   '개인',
#   '연락',
#   '잔디',
#   '콘크리트'],
#  ['별장',
#   '황토',
#   '잣나무',
#   '가평',
#   '구들',
#   '힐링',
#   '설악',
#   '촬영장',
#   '마당',
#   '앞산',
#   '눈앞',
#   '소로',
#   '아치',
#   '더욱',
#   '가평',
#   '현관',
#   '설악면',
#   '한양대',
#   '학과',
#   '워치',
#   '영화',
#   '극영화'],
#  ['카폐', '청평', '가평', '갤러리', '카페', '환상', '가평', '코스', '드라이브', '로코', '호명'],
#  ['각종',
#   '생일',
#   '파티',
#   '촬영',
#   '모임',
#   '서울',
#   '강남',
#   '스터디',
#   '대관',
#   '최고',
#   '다트',
#   '스크린',
#   '홀덤',
#   '비어퐁',
#   '노래방',
#   '공간',
#   '운영',
#   '테이블',
#   '전자'],
#  ['영상',
#   '세미나',
#   '강연',
#   '원데이',
#   '촬영',
#   '간담',
#   '비롯',
#   '직무',
#   '공간',
#   '무료',
#   '강연',
#   '클래스',
#   '캠프',
#   '리얼타임',
#   '활동',
#   '모임',
#   '모든',
#   '제공',
#   '단기',
#   '마이',
#   '독서',
#   '형태',
#   '교육',
#   '원데이',
#   '프로젝터',
#   '잇츠',
#   '스타트업',
#   '대관',
#   '취미'],
#  ['마케팅',
#   '파티',
#   '도산',
#   '로데오',
#   '스포츠',
#   '루프',
#   '작업실',
#   '브랜드',
#   '모임',
#   '사무실',
#   '공원',
#   '강남',
#   '소규모',
#   '신사동',
#   '감각',
#   '북한',
#   '야경',
#   '루프',
#   '레이',
#   '복층',
#   '정원',
#   '공간',
#   '응접실',
#   '일요일',
#   '아이디어',
#   '창고',
#   '공원',
#   '화장실',
#   '이용',
#   '마련',
#   '도산',
#   '인스피',
#   '압구정동',
#   '야외',
#   '명정',
#   '회의',
#   '휴식',
#   '가능',
#   '감상',
#   '벽난로',
#   '천고',
#   '테라스',
#   '보이',
#   '사무',
#   '상시',
#   '산이',
#   '근처',
#   '햇살'],
#  ['법률',
#   '사무소',
#   '사무실',
#   '감각',
#   '위치',
#   '사무소',
#   '인테리어',
#   '역삼역',
#   '디자인',
#   '로펌',
#   '기본',
#   '가구',
#   '소형',
#   '미드',
#   '법률',
#   '모티브',
#   '감각',
#   '유니크',
#   '테헤란로'],
#  ['레트로',
#   '하우스',
#   '빈티',
#   '자취',
#   '투룸',
#   '감각',
#   '지층',
#   '생활',
#   '자취',
#   '독립',
#   '도보',
#   '자랑',
#   '최근',
#   '감각',
#   '레트로',
#   '빈티',
#   '이기',
#   '모델링',
#   '집등',
#   '개조',
#   '대학생',
#   '현대',
#   '사회',
#   '하우스',
#   '집의',
#   '그림',
#   '곳곳',
#   '촬영',
#   '계단',
#   '주택',
#   '활용',
#   '옛날',
#   '사진',
#   '가지',
#   '염창역',
#   '부엌'],
#  ['브라',
#   '대여',
#   '파티',
#   '카페',
#   '샤워',
#   '공간',
#   '이벤트',
#   '감성',
#   '원목',
#   '영상',
#   '커플',
#   '제품',
#   '파티',
#   '네츄럴',
#   '우드',
#   '샤워',
#   '소재',
#   '복층',
#   '화이트',
#   '공간',
#   '서비스',
#   '분야',
#   '메르',
#   '생일',
#   '클래스',
#   '베이지',
#   '고가',
#   '강의',
#   '시무',
#   '이용',
#   '브라',
#   '촬영',
#   '추억',
#   '셀프',
#   '모든',
#   '프로필',
#   '분위기',
#   '제공',
#   '형태',
#   '연말',
#   '원데이',
#   '가구',
#   '쇼핑몰',
#   '우정',
#   '저희'],
#  ['렌탈',
#   '광고',
#   '욕조',
#   '바이럴',
#   '촬영',
#   '자연',
#   '셀프',
#   '그네',
#   '감성',
#   '인터뷰',
#   '연출',
#   '렌탈',
#   '영상',
#   '참고',
#   '사용',
#   '광합성',
#   '욕조',
#   '현장',
#   '샤워',
#   '인원',
#   '결제',
#   '스튜디오',
#   '과시',
#   '추가',
#   '채광',
#   '조화',
#   '규칙',
#   '지원',
#   '유니크',
#   '바이럴',
#   '기본',
#   '소개',
#   '각각',
#   '감성',
#   '이용',
#   '장소',
#   '요금',
#   '북유럽',
#   '출사',
#   '각종',
#   '화보',
#   '촬영',
#   '자연',
#   '개인',
#   '다른',
#   '모든',
#   '시간',
#   '가능',
#   '컬러',
#   '면적',
#   '아이템',
#   '온수',
#   '하단',
#   '배치',
#   '쇼핑몰',
#   '그네',
#   '부착',
#   '효율'],
#  ['주차장',
#   '불광천',
#   '테라스',
#   '카페',
#   '분위기',
#   '감성',
#   '전면',
#   '불광천',
#   '촬영장',
#   '호선',
#   '테라스',
#   '축제',
#   '벚꽃',
#   '소로',
#   '매장',
#   '서울',
#   '응암역',
#   '바로',
#   '출구'],
#  ['감성',
#   '가득',
#   '오래돤',
#   '레슨',
#   '모델링',
#   '주택',
#   '실로',
#   '사용',
#   '향수',
#   '힐링',
#   '양지',
#   '감수성',
#   '장소',
#   '구조'],
#  ['감성', '맛집', '친구', '감성', '대화', '가운데', '공간', '정리', '스스로', '지인'],
#  ['빈티',
#   '광고',
#   '화보',
#   '마켓',
#   '사진',
#   '촬영',
#   '블로그',
#   '개인',
#   '감성',
#   '동남아',
#   '경리',
#   '연출',
#   '위치',
#   '스테이',
#   '오늘',
#   '메인',
#   '매체',
#   '복판',
#   '빈티',
#   '해외',
#   '관심',
#   '소개',
#   '서울',
#   '대로',
#   '초입',
#   '하우스',
#   '유난',
#   '사랑',
#   '촬영',
#   '분위기',
#   '경리',
#   '리빙',
#   '전문',
#   '컨셉',
#   '네이버'],
#  ['펜션',
#   '촬영',
#   '테리어',
#   '홈인',
#   '수영장',
#   '정원',
#   '감성',
#   '위치',
#   '양평',
#   '직접',
#   '원룸',
#   '손수',
#   '스튜디오',
#   '정원',
#   '부지',
#   '박아',
#   '전원',
#   '특색',
#   '서울',
#   '각각',
#   '데코',
#   '그림',
#   '객실',
#   '촬영',
#   '자연',
#   '바베큐',
#   '주택',
#   '펜션',
#   '평의',
#   '수영장',
#   '그린'],
#  ['바베큐',
#   '테라스',
#   '오두막',
#   '촬영',
#   '자연',
#   '복층',
#   '감성',
#   '구조',
#   '연출',
#   '유럽',
#   '원룸',
#   '나무',
#   '코티지',
#   '산속',
#   '스튜디오',
#   '복층',
#   '정원',
#   '공간',
#   '바로',
#   '인테리어',
#   '마감',
#   '표현',
#   '바베큐',
#   '형태',
#   '테라스',
#   '잔디',
#   '실내',
#   '화로'],
#  ['북유럽',
#   '마당',
#   '전망',
#   '내추럴',
#   '강가',
#   '심플',
#   '모던',
#   '화이트',
#   '비담',
#   '미니',
#   '영상',
#   '동선',
#   '참고',
#   '최소한',
#   '야경',
#   '보상',
#   '폴딩도어',
#   '확보',
#   '공간',
#   '지방',
#   '오송역',
#   '액자',
#   '물품',
#   '정말',
#   '사철',
#   '준비',
#   '마련',
#   '사시',
#   '집기',
#   '중부',
#   '촬영',
#   '시간대',
#   '야간',
#   '다른',
#   '도시',
#   '전체',
#   '블랙',
#   '가을',
#   '주차',
#   '사진',
#   '배치',
#   '기도',
#   '도구',
#   '거구',
#   '문제',
#   '경부',
#   '주방',
#   '이내',
#   '화이트',
#   '건너',
#   '강쪽',
#   '원목',
#   '데크',
#   '옥내',
#   '비품',
#   '카페',
#   '여러',
#   '구성',
#   '욕실',
#   '대여',
#   '주간',
#   '드릴',
#   '느낌',
#   '마감',
#   '모든',
#   '노선',
#   '수고',
#   '미니',
#   '복도',
#   '연락',
#   '조명도',
#   '안쪽',
#   '청주',
#   '은하',
#   '살림살이',
#   '배려',
#   '전원주택',
#   '내추럴',
#   '주말',
#   '러리',
#   '한편',
#   '옥외',
#   '철도',
#   '오시',
#   '소형',
#   '신축',
#   '중정',
#   '가전',
#   '거리',
#   '야외',
#   '주시',
#   '차량',
#   '정도',
#   '전면',
#   '여름',
#   '석양',
#   '비현실적',
#   '노을',
#   '허공',
#   '여분',
#   '때문',
#   '모두',
#   '남쪽',
#   '스타',
#   '덩치',
#   '강남',
#   '감히',
#   '소품',
#   '보유',
#   '주차장',
#   '최소',
#   '서쪽',
#   '거실',
#   '등등',
#   '주변',
#   '고속도로',
#   '곳도',
#   '미리',
#   '마당',
#   '방문',
#   '커트',
#   '포인트',
#   '전반',
#   '생각',
#   '바베큐',
#   '거나',
#   '공터',
#   '잔디',
#   '가구',
#   '모닥불',
#   '일리',
#   '스탭진',
#   '컨셉',
#   '그냥'],
#  ['북유럽',
#   '마당',
#   '전망',
#   '내추럴',
#   '강가',
#   '심플',
#   '모던',
#   '화이트',
#   '비담',
#   '미니',
#   '영상',
#   '동선',
#   '참고',
#   '최소한',
#   '야경',
#   '보상',
#   '폴딩도어',
#   '확보',
#   '공간',
#   '지방',
#   '오송역',
#   '액자',
#   '물품',
#   '정말',
#   '사철',
#   '준비',
#   '마련',
#   '사시',
#   '집기',
#   '중부',
#   '촬영',
#   '시간대',
#   '야간',
#   '다른',
#   '도시',
#   '전체',
#   '블랙',
#   '가을',
#   '주차',
#   '사진',
#   '배치',
#   '기도',
#   '도구',
#   '거구',
#   '문제',
#   '경부',
#   '주방',
#   '이내',
#   '화이트',
#   '건너',
#   '강쪽',
#   '원목',
#   '데크',
#   '옥내',
#   '비품',
#   '카페',
#   '여러',
#   '구성',
#   '욕실',
#   '대여',
#   '주간',
#   '드릴',
#   '느낌',
#   '마감',
#   '모든',
#   '노선',
#   '수고',
#   '미니',
#   '복도',
#   '연락',
#   '조명도',
#   '안쪽',
#   '청주',
#   '은하',
#   '살림살이',
#   '배려',
#   '전원주택',
#   '내추럴',
#   '주말',
#   '러리',
#   '한편',
#   '옥외',
#   '철도',
#   '오시',
#   '소형',
#   '신축',
#   '중정',
#   '가전',
#   '거리',
#   '야외',
#   '주시',
#   '차량',
#   '정도',
#   '전면',
#   '여름',
#   '석양',
#   '비현실적',
#   '노을',
#   '허공',
#   '여분',
#   '때문',
#   '모두',
#   '남쪽',
#   '스타',
#   '덩치',
#   '강남',
#   '감히',
#   '소품',
#   '보유',
#   '주차장',
#   '최소',
#   '서쪽',
#   '거실',
#   '등등',
#   '주변',
#   '고속도로',
#   '곳도',
#   '미리',
#   '마당',
#   '방문',
#   '커트',
#   '포인트',
#   '전반',
#   '생각',
#   '바베큐',
#   '거나',
#   '공터',
#   '잔디',
#   '가구',
#   '모닥불',
#   '일리',
#   '스탭진',
#   '컨셉',
#   '그냥'],
#  ['렌탈',
#   '작업실',
#   '도곡동',
#   '강남',
#   '양재',
#   '위치',
#   '영상',
#   '호선',
#   '대만',
#   '파티',
#   '얽매',
#   '요일',
#   '스튜디오',
#   '공간',
#   '건물',
#   '주차장',
#   '출입',
#   '선택',
#   '이야기',
#   '목적',
#   '복합',
#   '매봉역',
#   '미리',
#   '이용',
#   '활동',
#   '강남구',
#   '인근',
#   '촬영',
#   '워크샵',
#   '문화',
#   '화공',
#   '해주시',
#   '바이브',
#   '주차',
#   '배치',
#   '도곡동',
#   '소규모',
#   '연등',
#   '공영'],
#  ['선릉역', '연습실', '거울', '강남', '도보', '평의', '거울', '강남', '선릉역', '연습실', '장소'],
#  ['로펌',
#   '모던',
#   '삼성동',
#   '사무실',
#   '오피스',
#   '강남',
#   '호선',
#   '참고',
#   '사용',
#   '회의실',
#   '주말',
#   '한층',
#   '오피스',
#   '봉은사',
#   '도보',
#   '휴일',
#   '인테리어',
#   '한정',
#   '삼성',
#   '기본',
#   '현재',
#   '동시',
#   '화장실',
#   '구성',
#   '오픈',
#   '세팅',
#   '인근',
#   '모던',
#   '엘레베이터',
#   '비실',
#   '한지',
#   '사무실',
#   '개인',
# ...
#  ['영상',
#   '유튜브',
#   '세미나',
#   '홍대',
#   '회의실',
#   '합정',
#   '촬영',
#   '룩북',
#   '연출',
#   '위치',
#   '영상',
#   '사항',
#   '언제',
#   '인원',
#   '소재',
#   '스튜디오',
#   '추가',
#   '조정',
#   '필수',
#   '에폭시',
#   '바닥',
#   '문의',
#   '합정',
#   '무드',
#   '스트릿',
#   '인기',
#   '사전',
#   '미리',
#   '옵션',
#   '각종',
#   '대여',
#   '웍스',
#   '느낌',
#   '층고',
#   '촬영',
#   '자연',
#   '장비',
#   '협의',
#   '사방',
#   '앤드',
#   '상담'],
#  ['초교', '역삼', '원룸', '영상', '역삼', '사진', '원룸', '촬영', '근처', '초교'],
#  ['정원', '정원', '북한'],
#  ['공간', '산속', '아파트', '아파트', '전원주택', '촬영', '마비', '마을', '주변', '산책로', '수목원'],
#  ['강아지',
#   '규어',
#   '전망',
#   '강아지',
#   '도사',
#   '아파트',
#   '인테리어',
#   '타일',
#   '거실',
#   '신경',
#   '고급',
#   '아이방',
#   '공사',
#   '비숑',
#   '동탄'],
#  ['삶속', '일상', '평범', '공간', '일상'],
#  ['텐텐',
#   '상남동',
#   '실내',
#   '창원',
#   '양궁',
#   '남점',
#   '체험',
#   '상남동',
#   '창원',
#   '실내',
#   '이색',
#   '양궁',
#   '가능'],
#  ['주방', '모델', '상도동', '빌라', '주부', '주방', '상도동', '빌라', '평이', '식탁', '고요'],
#  ['상수',
#   '대여',
#   '주택',
#   '파티',
#   '홍대',
#   '드라마',
#   '영화',
#   '공간',
#   '대관',
#   '조합',
#   '디자인',
#   '한국',
#   '플랜',
#   '테리어',
#   '전통',
#   '공간'],
#  ['햇빛',
#   '아파트',
#   '아주',
#   '고층',
#   '새집',
#   '위치',
#   '영상',
#   '호선',
#   '아파트',
#   '언제',
#   '모두',
#   '주말',
#   '도보',
#   '소품',
#   '남향',
#   '구조',
#   '광고',
#   '인테리어',
#   '평일',
#   '거실',
#   '미리',
#   '선호',
#   '최신',
#   '타워',
#   '신금호역',
#   '단지',
#   '촬영',
#   '강추',
#   '잡지',
#   '전망',
#   '날짜',
#   '탁트인'],
#  ['상가',
#   '서교동',
#   '주택',
#   '주차장',
#   '홍대입구역',
#   '상가',
#   '위치',
#   '주택',
#   '홍대',
#   '거리',
#   '주변',
#   '편의',
#   '특성',
#   '도보',
#   '바로',
#   '출구',
#   '이용'],
#  ['한남동',
#   '아파트',
#   '살기',
#   '서민',
#   '혼자',
#   '리빙',
#   '위치',
#   '한남동',
#   '아파트',
#   '서민',
#   '키친',
#   '용산구',
#   '구조',
#   '규모',
#   '욕실'],
#  ['아파트',
#   '쾌적',
#   '상암',
#   '주차',
#   '취사',
#   '서울',
#   '마포',
#   '가능',
#   '경기',
#   '주차장',
#   '아파트',
#   '아주',
#   '완비',
#   '취사',
#   '촬영',
#   '주변',
#   '햇살'],
#  ['서울',
#   '공덕',
#   '마포',
#   '공덕역',
#   '참고',
#   '사용',
#   '우드',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '화이트',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '건물',
#   '주차장',
#   '유료',
#   '최대',
#   '서울',
#   '오피스텔',
#   '이용',
#   '요금',
#   '조화로',
#   '지하',
#   '촬영',
#   '분위기',
#   '제공',
#   '스피커',
#   '이점',
#   '발생',
#   '주차',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['서울',
#   '공덕',
#   '마포',
#   '공덕역',
#   '참고',
#   '사용',
#   '마샬',
#   '원룸',
#   '파스텔',
#   '사전예약',
#   '인원',
#   '마포',
#   '화이트',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '서울',
#   '오피스텔',
#   '조화로',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['서울',
#   '공덕',
#   '마포',
#   '공덕역',
#   '참고',
#   '사용',
#   '우드',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '서울',
#   '오피스텔',
#   '그레이',
#   '조화로',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['서울',
#   '공덕',
#   '마포',
#   '공덕역',
#   '참고',
#   '사용',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '그린',
#   '서울',
#   '오피스텔',
#   '조화로',
#   '옐로우',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['작업실', '서울', '방배동', '카페', '작업실', '개인', '미디어', '작가', '분위기'],
#  ['빈티',
#   '주택',
#   '카페',
#   '유럽',
#   '가구',
#   '모던',
#   '서울',
#   '위치',
#   '게스트',
#   '유럽',
#   '채광',
#   '매우',
#   '구조',
#   '고양이',
#   '거실',
#   '마포구',
#   '이용',
#   '촬영',
#   '천장',
#   '다용도실',
#   '주택',
#   '마리',
#   '연상',
#   '옷방',
#   '이후',
#   '합정동',
#   '부엌'],
#  ['평범',
#   '자취',
#   '원룸',
#   '회사원',
#   '서울',
#   '대학생',
#   '내츄럴',
#   '연출',
#   '시설',
#   '참고',
#   '이동',
#   '자체',
#   '자취',
#   '원룸',
#   '현실',
#   '주자',
#   '남성',
#   '실제',
#   '화이트',
#   '소품',
#   '커튼',
#   '건물',
#   '물건',
#   '처음',
#   '대가',
#   '새벽',
#   '장안동',
#   '회사원',
#   '등등',
#   '주변',
#   '두운',
#   '주인공',
#   '오피스텔',
#   '접이식',
#   '이용',
#   '요금',
#   '비교',
#   '준비',
#   '느낌',
#   '책상',
#   '촬영',
#   '동대문구',
#   '초반',
#   '차량',
#   '드라마',
#   '거주',
#   '구비',
#   '편의점',
#   '편이',
#   '재량',
#   '연락',
#   '도움',
#   '이후',
#   '주차',
#   '가지',
#   '독립영화',
#   '조명',
#   '재연',
#   '분야'],
#  ['화이트하우스',
#   '홍대',
#   '합정',
#   '동영상',
#   '촬영',
#   '서울',
#   '미니',
#   '화이트',
#   '투룸',
#   '원목',
#   '도보',
#   '각기',
#   '해당',
#   '거리',
#   '합정역',
#   '거주',
#   '촬영',
#   '조명',
#   '저녁',
#   '분위기',
#   '화이트',
#   '다른',
#   '공간',
#   '투룸',
#   '햇살',
#   '원목'],
#  ['서울', '식당', '강남구', '면적', '레스토랑', '평의', '모던', '서울', '소재', '논현동'],
#  ['렌탈',
#   '엔틱',
#   '홍대',
#   '합정',
#   '서울',
#   '서교동',
#   '자연',
#   '티크',
#   '샹들리',
#   '크리스탈',
#   '영화',
#   '공간',
#   '꿈결',
#   '위로',
#   '유러',
#   '재현',
#   '무드',
#   '엔틱크',
#   '대형',
#   '탁자',
#   '저택',
#   '피안',
#   '블루',
#   '고급',
#   '푸른',
#   '오브',
#   '포인트',
#   '카페트',
#   '소파',
#   '샹들리'],
#  ['렌탈',
#   '엔틱',
#   '홍대',
#   '합정',
#   '서울',
#   '서교동',
#   '자연',
#   '티크',
#   '샹들리',
#   '크리스탈',
#   '영화',
#   '공간',
#   '꿈결',
#   '위로',
#   '유러',
#   '재현',
#   '무드',
#   '엔틱크',
#   '대형',
#   '탁자',
#   '저택',
#   '피안',
#   '블루',
#   '고급',
#   '푸른',
#   '오브',
#   '포인트',
#   '카페트',
#   '소파',
#   '샹들리'],
#  ['렌탈',
#   '화보',
#   '테라스',
#   '뮤비',
#   '홍대',
#   '합정',
#   '촬영',
#   '서교동',
#   '프로필',
#   '비밀',
#   '가득',
#   '화원',
#   '스튜디오',
#   '온실',
#   '모던',
#   '채운',
#   '티크',
#   '오브',
#   '화분',
#   '화이트',
#   '베이스',
#   '감성'],
#  ['렌탈',
#   '존트',
#   '홍대',
#   '합정',
#   '거실',
#   '티크',
#   '서교동',
#   '호리',
#   '인테리어',
#   '테라스',
#   '저택',
#   '무드',
#   '자연',
#   '호리',
#   '스튜디오',
#   '모티브',
#   '이용',
#   '양식'],
#  ['렌탈',
#   '존트',
#   '홍대',
#   '합정',
#   '거실',
#   '티크',
#   '서교동',
#   '호리',
#   '인테리어',
#   '테라스',
#   '저택',
#   '무드',
#   '자연',
#   '호리',
#   '스튜디오',
#   '모티브',
#   '이용',
#   '양식'],
#  ['렌탈',
#   '임대',
#   '촬영',
#   '자연',
#   '서울',
#   '용산구',
#   '공간',
#   '쇼핑몰',
#   '채광',
#   '광렌탈',
#   '관리자',
#   '위치',
#   '렌탈',
#   '위해',
#   '부족함',
#   '패션',
#   '라운지',
#   '브랜드',
#   '호리',
#   '스튜디오',
#   '공간',
#   '채광',
#   '가시',
#   '인테리어',
#   '세로',
#   '월길',
#   '여성',
#   '문의',
#   '서울',
#   '자부',
#   '사전',
#   '중심',
#   '디자이너',
#   '사진작가',
#   '의류',
#   '촬영',
#   '후암동',
#   '자연',
#   '차량',
#   '휴식',
#   '남산',
#   '높이',
#   '디자인',
#   '테라스',
#   '가장',
#   '노력',
#   '사진',
#   '주차',
#   '규모',
#   '쇼핑몰',
#   '컨텐츠',
#   '가로',
#   '저희'],
#  ['새입',
#   '아파트',
#   '가락',
#   '헬리',
#   '언제',
#   '촬영',
#   '서울',
#   '분위기',
#   '조명',
#   '주단',
#   '가능',
#   '정원',
#   '시티',
#   '아파트',
#   '가장',
#   '언제',
#   '주차',
#   '촬영',
#   '화장실',
#   '서울',
#   '인원',
#   '가능',
#   '공원',
#   '이내',
#   '주위',
#   '시간',
#   '협의'],
#  ['새입',
#   '아파트',
#   '가락',
#   '헬리',
#   '언제',
#   '촬영',
#   '서울',
#   '분위기',
#   '조명',
#   '주단',
#   '가능',
#   '정원',
#   '시티',
#   '아파트',
#   '가장',
#   '언제',
#   '주차',
#   '촬영',
#   '화장실',
#   '서울',
#   '인원',
#   '가능',
#   '공원',
#   '이내',
#   '주위',
#   '시간',
#   '협의'],
#  ['스테이',
#   '서울역',
#   '문제',
#   '위치',
#   '사용',
#   '집주인',
#   '옥집',
#   '실제',
#   '정원',
#   '모델링',
#   '용도',
#   '거실',
#   '서울역',
#   '개조',
#   '스타일',
#   '모던',
#   '촬영',
#   '거주',
#   '편이',
#   '실내',
#   '북촌',
#   '규모',
#   '근처'],
#  ['스테이',
#   '서울역',
#   '문제',
#   '위치',
#   '사용',
#   '집주인',
#   '옥집',
#   '실제',
#   '정원',
#   '모델링',
#   '용도',
#   '거실',
#   '서울역',
#   '개조',
#   '스타일',
#   '모던',
#   '촬영',
#   '거주',
#   '편이',
#   '실내',
#   '북촌',
#   '규모',
#   '근처'],
#  ['루프', '서울', '휴게실', '위치', '디자인', '평풍', '최근', '루프', '자락', '서울', '남산'],
#  ['대여',
#   '파티',
#   '홍대',
#   '합정역',
#   '장소',
#   '서울',
#   '전체',
#   '대관',
#   '위치',
#   '오후',
#   '이용도',
#   '파티',
#   '평일',
#   '합정역',
#   '편입',
#   '이용',
#   '모던',
#   '주말',
#   '가능',
#   '저녁',
#   '파티룸',
#   '시간',
#   '공간',
#   '주로',
#   '대관',
#   '편이'],
#  ['피아노', '서재', '거실', '초등학생', '아이'],
#  ['빈티',
#   '책방',
#   '서점',
#   '촬영',
#   '분당',
#   '독립',
#   '인터뷰',
#   '연출',
#   '독립',
#   '영화',
#   '공간',
#   '소품',
#   '회관',
#   '최애',
#   '아날로그',
#   '최적화',
#   '장소',
#   '인터뷰',
#   '느낌',
#   '다큐멘터리',
#   '닜는',
#   '촬영',
#   '기억',
#   '서점',
#   '여러가지',
#   '마을',
#   '저희'],
#  ['동영상',
#   '북카페',
#   '모임',
#   '촬영',
#   '유튜버',
#   '소규모',
#   '강의',
#   '서초동',
#   '공간',
#   '대관',
#   '우리나라',
#   '모두',
#   '직접',
#   '레이',
#   '교육학',
#   '마치',
#   '공간',
#   '대학',
#   '원목',
#   '인테리어',
#   '카페',
#   '연구원',
#   '여자',
#   '클래스',
#   '현재',
#   '구성',
#   '장소',
#   '디자이너',
#   '아카데미',
#   '출판',
#   '설계',
#   '매장',
#   '촬영',
#   '모임',
#   '개인',
#   '출신',
#   '디자인',
#   '전문',
#   '활용',
#   '서점',
#   '가구',
#   '목수',
#   '소규모',
#   '운영',
#   '파리'],
#  ['서희',
#   '위치',
#   '톨게이트',
#   '가톨릭',
#   '변경',
#   '인근',
#   '시내',
#   '거리',
#   '강릉',
#   '관동',
#   '시간대',
#   '진입',
#   '가능',
#   '대학교',
#   '협의'],
#  ['아파트',
#   '선경',
#   '잠깐',
#   '일반',
#   '자녀',
#   '남편',
#   '이용',
#   '삼일',
#   '가정',
#   '이구',
#   '휴가',
#   '휴식',
#   '보시',
#   '공간',
#   '외국'],
#  ['바디',
#   '성북구',
#   '헬스장',
#   '프로필',
#   '피티',
#   '운동',
#   '공간',
#   '요가',
#   '보헤미안',
#   '인테리어',
#   '햇빛',
#   '레슨',
#   '필라테스',
#   '문의',
#   '촬영',
#   '공간',
#   '스튜디오',
#   '운동',
#   '진행'],
#  ['렌탈',
#   '주방',
#   '거실',
#   '자연',
#   '서울',
#   '성수동',
#   '뚝섬역',
#   '쇼핑몰',
#   '탈시',
#   '위치',
#   '렌탈',
#   '다리미',
#   '조기',
#   '화물',
#   '인피니트',
#   '처리',
#   '강남',
#   '스튜디오',
#   '자랑',
#   '서비스',
#   '차비',
#   '사다리',
#   '주차장',
#   '입지',
#   '걸이',
#   '무료',
#   '나머지',
#   '문의',
#   '동영상',
#   '인접',
#   '최적화',
#   '스트로',
#   '광고지',
#   '지면',
#   '최고',
#   '대여',
#   '화보',
#   '준비',
#   '설비',
#   '행거',
#   '지하',
#   '이웃',
#   '기점',
#   '촬영',
#   '차량',
#   '성수동',
#   '제공',
#   '스팀',
#   '주시',
#   '적재',
#   '전력',
#   '연락',
#   '성수대교',
#   '최적',
#   '사진',
#   '상담',
#   '엘리베이터',
#   '서울숲',
#   '유료'],
#  ['갤러리',
#   '카페',
#   '신촌',
#   '성수동',
#   '서울숲',
#   '분위기',
#   '살롱',
#   '채광',
#   '시설',
#   '사용',
#   '예술',
#   '채광',
#   '공간',
#   '매우',
#   '주차장',
#   '신촌',
#   '경우',
#   '주변',
#   '그간',
#   '중심',
#   '교통',
#   '지하',
#   '촬영',
#   '문화',
#   '여유',
#   '규모',
#   '살롱',
#   '활용'],
#  ['용공',
#   '영상',
#   '화보',
#   '세미나',
#   '촬영',
#   '강의',
#   '성수동',
#   '공간',
#   '위치',
#   '렌탈',
#   '시설',
#   '음향',
#   '프로젝트',
#   '심플',
#   '스튜디오',
#   '공간',
#   '바로',
#   '인테리어',
#   '최대',
#   '바닥',
#   '성수역',
#   '준비',
#   '파우더',
#   '헤링본',
#   '모던',
#   '매력',
#   '자연',
#   '테라스',
#   '탈의실',
#   '주차',
#   '가지',
#   '통창',
#   '규모',
#   '성수'],
#  ['쇼핑몰', '성수동', '대관', '카페', '성수동', '카페'],
#  ['렌탈',
#   '카페',
#   '거리',
#   '촬영',
#   '서울',
#   '성수동',
#   '쇼핑몰',
#   '채광',
#   '소품',
#   '컬러풀',
#   '연출',
#   '위치',
#   '다리미',
#   '단위',
#   '퇴장',
#   '참고',
#   '사항',
#   '사용',
#   '위해',
#   '이동',
#   '인원',
#   '호리',
#   '스튜디오',
#   '추가',
#   '채광',
#   '말씀',
#   '소품',
#   '가시',
#   '전신',
#   '주차장',
#   '오렌지',
#   '입장',
#   '대가',
#   '기본',
#   '이용자',
#   '무드',
#   '청구',
#   '민영',
#   '구성',
#   '민트',
#   '테이블',
#   '준비',
#   '느낌',
#   '룸당',
#   '촬영',
#   '차량',
#   '오브',
#   '성수동',
#   '스팀',
#   '거울',
#   '약시',
#   '파크',
#   '시간',
#   '기준',
#   '예약',
#   '다른',
#   '진행',
#   '분실',
#   '헹거',
#   '숙지',
#   '비용',
#   '세차장',
#   '발생',
#   '이상',
#   '주차',
#   '가구',
#   '파손',
#   '성수',
#   '컬러풀',
#   '벽지'],
#  ['스터디',
#   '카페',
#   '내부',
#   '작업',
#   '인테리어',
#   '사용',
#   '공간',
#   '분위기',
#   '가능',
#   '성신여대역',
#   '스터디',
#   '인터뷰'],
#  ['매장', '용품', '성인', '인천', '갈산역', '거리', '지하', '인용', '매장', '부평', '출구'],
#  ['아파트', '성호', '모던', '계통', '아파트', '그레이'],
#  ['세미나',
#   '파티',
#   '클래스',
#   '미팅',
#   '원데이',
#   '모임',
#   '회의',
#   '인터뷰',
#   '화공',
#   '위치',
#   '프로그램',
#   '미팅',
#   '클래스',
#   '원데이',
#   '모임',
#   '복합',
#   '충무로역',
#   '회의',
#   '출구'],
#  ['세미나',
#   '파티',
#   '클래스',
#   '원데이',
#   '촬영',
#   '모임',
#   '회의',
#   '독서',
#   '위치',
#   '프로그램',
#   '클래스',
#   '강연',
#   '원데이',
#   '모임',
#   '독서',
#   '충무로역',
#   '회의',
#   '출구',
#   '진행'],
#  ['세미나',
#   '파티',
#   '클래스',
#   '원데이',
#   '촬영',
#   '모임',
#   '회의',
#   '독서',
#   '위치',
#   '프로그램',
#   '클래스',
#   '강연',
#   '원데이',
#   '모임',
#   '독서',
#   '충무로역',
#   '회의',
#   '출구',
#   '진행'],
#  ['세비',
#   '임차',
#   '유럽',
#   '예술',
#   '공간',
#   '건물',
#   '광고',
#   '카페',
#   '자리',
#   '현재',
#   '학암',
#   '스파크',
#   '거리',
#   '이천',
#   '촬영',
#   '전체',
#   '부분',
#   '주택',
#   '세비',
#   '활용',
#   '비어',
#   '잡고',
#   '상가',
#   '동이'],
#  ['판매점', '세종', '휴대폰', '느낌', '휴대폰', '매장', '번잡', '개인', '판매점', '사무실'],
#  ['세종시', '세종시', '스타일', '마메', '아파트', '그릇', '집안', '분위기', '화이트', '전체'],
#  ['별장',
#   '빈티',
#   '하우스',
#   '레트로',
#   '주택',
#   '드하',
#   '타이',
#   '펜션',
#   '주말',
#   '우스',
#   '코타츠',
#   '빈티',
#   '하우스',
#   '타이',
#   '아기자기',
#   '감성'],
#  ['대여',
#   '강북',
#   '노래',
#   '녹음실',
#   '보컬',
#   '서울',
#   '셀프',
#   '연습실',
#   '미아',
#   '비용',
#   '브리',
#   '결과물',
#   '퀄리티',
#   '스튜디오'],
#  ['대여',
#   '그램',
#   '장소',
#   '촬영',
#   '셀프',
#   '홈스',
#   '대관',
#   '위치',
#   '호선',
#   '아파트',
#   '사용',
#   '심플',
#   '요일',
#   '도보',
#   '공간',
#   '소품',
#   '평형',
#   '서울',
#   '선호',
#   '신혼부부',
#   '동향',
#   '영등포구',
#   '주중',
#   '모든',
#   '신풍역',
#   '출구',
#   '전반',
#   '톤앤무드',
#   '햇살'],
#  ['영화',
#   '드라마',
#   '소개팅',
#   '분위기',
#   '위치',
#   '경험',
#   '공간',
#   '평수',
#   '해방촌',
#   '좌석',
#   '평정',
#   '다수',
#   '이용',
#   '촬영',
#   '분위기',
#   '가능',
#   '시간',
#   '정도',
#   '잡지',
#   '오후',
#   '안쪽',
#   '주차',
#   '쇼핑몰'],
#  ['영화',
#   '드라마',
#   '소개팅',
#   '분위기',
#   '위치',
#   '경험',
#   '공간',
#   '평수',
#   '해방촌',
#   '좌석',
#   '평정',
#   '다수',
#   '이용',
#   '촬영',
#   '분위기',
#   '가능',
#   '시간',
#   '정도',
#   '잡지',
#   '오후',
#   '안쪽',
#   '주차',
#   '쇼핑몰'],
#  ['대여',
#   '카페',
#   '촬영',
#   '소규모',
#   '겔러',
#   '쇼핑몰',
#   '채광',
#   '전시',
#   '커피숍',
#   '의정부',
#   '위치',
#   '사무소',
#   '카페',
#   '커피숍',
#   '심플',
#   '사진',
#   '촬영',
#   '도보',
#   '컨셉',
#   '의정부역'],
#  ['클래스',
#   '플랜',
#   '제주도',
#   '모임',
#   '쿠킹',
#   '테리어',
#   '소규모',
#   '커피',
#   '주방',
#   '제주',
#   '주차공간',
#   '요일',
#   '휴무',
#   '커피숖',
#   '일요일',
#   '클래스',
#   '시내',
#   '거실',
#   '테리어',
#   '주변',
#   '관계',
#   '사전',
#   '조그만',
#   '느낌',
#   '촬영',
#   '쿠킹',
#   '약시',
#   '가능',
#   '플랜',
#   '커피',
#   '컨셉'],
#  ['극장',
#   '유튜브',
#   '악기',
#   '일산',
#   '복합',
#   '공연장',
#   '콘서트',
#   '공간',
#   '영상',
#   '대수',
#   '프로젝트',
#   '극장',
#   '인테리어',
#   '무료',
#   '악기',
#   '좌석',
#   '설치',
#   '문의',
#   '강의',
#   '오디오',
#   '스케줄',
#   '최적화',
#   '관계',
#   '통합',
#   '이용',
#   '촬영',
#   '이상',
#   '스크린',
#   '주차',
#   '사진',
#   '시스템'],
#  ['위치',
#   '개입',
#   '대여',
#   '사이드',
#   '미래',
#   '일요일',
#   '평일',
#   '송도신도시',
#   '심야시간',
#   '도시',
#   '심야',
#   '테이블',
#   '오전',
#   '고요'],
#  ['송도',
#   '갤러리',
#   '파크',
#   '위치',
#   '하우스',
#   '테라스',
#   '케이블카',
#   '한눈',
#   '해변',
#   '제일',
#   '바다',
#   '부산',
#   '보이',
#   '송도해수욕장',
#   '평이',
#   '점망'],
#  ['송산',
#   '진입',
#   '정원',
#   '시티',
#   '그린',
#   '대지',
#   '주택',
#   '제곱미터',
#   '거실',
#   '난로',
#   '단독',
#   '태양광',
#   '난방',
#   '정원',
#   '화덕',
#   '전기',
#   '시골',
#   '이용',
#   '건물',
#   '보일러'],
#  ['유투브',
#   '제품',
#   '촬영',
#   '자연',
#   '셀프',
#   '쇼핑몰',
#   '소독',
#   '감성',
#   '상세',
#   '시설',
#   '와이파이',
#   '도보',
#   '공간',
#   '전신',
#   '라운드',
#   '인테리어',
#   '클래스',
#   '식물',
#   '쇼파',
#   '스툴',
#   '접이식',
#   '촬영',
#   '전등',
#   '전시',
#   '무늬',
#   '색상',
#   '원데이',
#   '음성인식',
#   '위치',
#   '브라운',
#   '화이트',
#   '투명',
#   '주로',
#   '원목',
#   '사다리',
#   '걸이',
#   '클래식',
#   '용도',
#   '설치',
#   '스마트',
#   '행거',
#   '매력',
#   '자연',
#   '유투브',
#   '전화기',
#   '제품',
#   '파티',
#   '블루투스',
#   '우드',
#   '스튜디오',
#   '세트',
#   '원형',
#   '전문의',
#   '안내',
#   '방기',
#   '카메라',
#   '거리',
#   '바지',
#   '프로필',
#   '잡지',
#   '필립스',
#   '스탠드',
#   '활용',
#   '다리미',
#   '배경',
#   '사각형',
#   '조화',
#   '소품',
#   '필수',
#   '대형',
#   '테이블',
#   '이용',
#   '어플',
#   '변경',
#   '철제',
#   '의류',
#   '모임',
#   '아크릴',
#   '스팀',
#   '거울',
#   '스피커',
#   '가능',
#   '신문',
#   '체크',
#   '화정역',
#   '셀카',
#   '모래시계',
#   '다이얼',
#   '쇼핑몰',
#   '의자'],
#  ['카페',
#   '일산',
#   '촬영',
#   '서울',
#   '파주',
#   '분위기',
#   '쇼핑몰',
#   '가면',
#   '위치',
#   '주차공간',
#   '심플',
#   '라인',
#   '추가',
#   '최소',
#   '최대',
#   '카페',
#   '용도',
#   '현재',
#   '또한',
#   '고가',
#   '공원',
#   '여러',
#   '코너',
#   '호수',
#   '매장',
#   '모던',
#   '촬영',
#   '진행',
#   '건강',
#   '주차',
#   '쇼핑몰',
#   '상가',
#   '운영',
#   '대관',
#   '방송국'],
#  ['렌탈',
#   '대여',
#   '마켓',
#   '블로그',
#   '촬영',
#   '모임',
#   '쇼핑몰',
#   '공간',
#   '장소',
#   '촬영',
#   '시선',
#   '분위기',
#   '공간',
#   '외부'],
#  ['아파트',
#   '야경',
#   '촬영',
#   '쇼핑몰',
#   '장소',
#   '연락',
#   '타워',
#   '구리타워',
#   '야경',
#   '촬영',
#   '보이',
#   '아이',
#   '롯데'],
#  ['렌탈',
#   '대여',
#   '유튜브',
#   '감성',
#   '홍대',
#   '촬영',
#   '자연',
#   '쇼핑몰',
#   '공간',
#   '대관',
#   '장소',
#   '연출',
#   '위치',
#   '렌탈',
#   '서로',
#   '위디',
#   '홍대',
#   '배경',
#   '아이보리',
#   '공간',
#   '다른',
#   '운영',
#   '스튜디오',
#   '화이트',
#   '감성',
#   '컨셉',
#   '트렌디'],
#  ['렌탈',
#   '대여',
#   '유튜브',
#   '감성',
#   '홍대',
#   '촬영',
#   '자연',
#   '쇼핑몰',
#   '공간',
#   '대관',
#   '장소',
#   '연출',
#   '위치',
#   '렌탈',
#   '서로',
#   '위디',
#   '홍대',
#   '배경',
#   '아이보리',
#   '공간',
#   '다른',
#   '운영',
#   '스튜디오',
#   '화이트',
#   '감성',
#   '컨셉',
#   '트렌디'],
#  ['수도권', '위치', '공덕역', '남산타워', '애오개역', '가정', '서울역', '발코니'],
#  ['수원', '모던', '예약', '인테리어', '심플'],
#  ['렌탈',
#   '제품',
#   '가장',
#   '촬영',
#   '호리',
#   '수유',
#   '렌탈',
#   '배경',
#   '주말',
#   '스튜디오',
#   '추가',
#   '검정색',
#   '조율',
#   '평일',
#   '기본',
#   '문의',
#   '맥스',
#   '구성',
#   '기분',
#   '이용',
#   '오전',
#   '리즌',
#   '백색',
#   '시간',
#   '오후',
#   '별도',
#   '조명',
#   '여간',
#   '야간'],
#  ['렌탈',
#   '제품',
#   '가장',
#   '촬영',
#   '호리',
#   '수유',
#   '렌탈',
#   '배경',
#   '주말',
#   '스튜디오',
#   '추가',
#   '검정색',
#   '조율',
#   '평일',
#   '기본',
#   '문의',
#   '맥스',
#   '구성',
#   '기분',
#   '이용',
#   '오전',
#   '리즌',
#   '백색',
#   '시간',
#   '오후',
#   '별도',
#   '조명',
#   '여간',
#   '야간'],
#  ['포차',
#   '술집',
#   '수원',
#   '캠퍼스',
#   '경희대',
#   '썸띵',
#   '언제',
#   '영업',
#   '국제',
#   '문의',
#   '이외',
#   '영통',
#   '시간',
#   '대관'],
#  ['아파트', '그림', '숲뷰', '아트', '신축', '콘도', '미니'],
#  ['라이프',
#   '아파트',
#   '청주',
#   '육아',
#   '영유',
#   '미니',
#   '라이프',
#   '소품',
#   '아파트',
#   '오후',
#   '일요일',
#   '사용',
#   '실천',
#   '직접',
#   '제외',
#   '촬영',
#   '아이',
#   '맘껏',
#   '공간',
#   '미니',
#   '숲속',
#   '오전'],
#  ['책장',
#   '테이블',
#   '거실',
#   '차창',
#   '일품',
#   '채광',
#   '거실',
#   '촬영',
#   '가정',
#   '배치',
#   '글쓰기',
#   '숲뷰',
#   '책장',
#   '공간',
#   '테이블'],
#  ['사당역',
#   '아파트',
#   '전주',
#   '전집',
#   '남현동',
#   '관악산',
#   '관음사',
#   '숲속',
#   '고양이',
#   '아파트',
#   '은동',
#   '날수',
#   '정원',
#   '집안',
#   '관악산',
#   '수의',
#   '등산로'],
#  ['네추럴',
#   '우드',
#   '심플',
#   '침실',
#   '거실',
#   '풍경',
#   '벚꽃',
#   '미니',
#   '숲속',
#   '푸릇푸릇',
#   '여름',
#   '가을',
#   '알록달록',
#   '동향',
#   '더욱',
#   '아침',
#   '거실',
#   '산책로',
#   '맞이',
#   '나무',
#   '단풍',
#   '겨울왕국',
#   '산이',
#   '겨울',
#   '벚꽃',
#   '숲속',
#   '햇살'],
#  ['다락방',
#   '하우스',
#   '테라스',
#   '광진구',
#   '쉐어',
#   '나무',
#   '모던',
#   '서울',
#   '거울',
#   '복층',
#   '계단',
#   '내부',
#   '사용',
#   '우드',
#   '나무',
#   '복층',
#   '잠시',
#   '소품',
#   '건물',
#   '구조',
#   '다락방',
#   '쉐어',
#   '방이',
#   '주전',
#   '거실',
#   '신축',
#   '전용',
#   '하우스',
#   '대여',
#   '거울',
#   '계단',
#   '테라스',
#   '사진',
#   '부엌'],
#  ['스냅', '촬영', '인물', '사진', '위치', '공간', '한남동', '번지'],
#  ['정원', '스몰', '웨딩', '웨딩', '연인', '단지', '북한', '야생화'],
#  ['음악회',
#   '웨딩',
#   '동백',
#   '스몰',
#   '촬영',
#   '영화',
#   '동산',
#   '장소',
#   '별장',
#   '동백동',
#   '곳자왈',
#   '제주',
#   '호텔',
#   '거리',
#   '공항',
#   '자리',
#   '람사르',
#   '추천',
#   '장소',
#   '플로',
#   '먼물깍',
#   '산이',
#   '사진촬영',
#   '바로',
#   '습지'],
#  ['스위트',
#   '아파트',
#   '인테리어',
#   '오후',
#   '느낌',
#   '오전',
#   '심플',
#   '요일',
#   '평형',
#   '사우동',
#   '소재',
#   '화이트',
#   '시간',
#   '김포',
#   '경기',
#   '선호'],
#  ['스카이', '시티', '해돋이', '요즈음', '소개', '거실', '아침', '요새'],
#  ['한양대',
#   '왕십리',
#   '스터디',
#   '카페',
#   '내부',
#   '작업',
#   '인테리어',
#   '사용',
#   '분위기',
#   '왕십리역',
#   '가능',
#   '공간',
#   '스터디',
#   '인터뷰'],
#  ...]

# %%
## Case 2) 코어 태그 추출 (부분적으로 기존 태그 + description + coreTag )
def getCoreTags2(n):
    coreTagList=[]
    okt=Okt()    
    descript=getDescList(n) # 한글자 이상만 뽑음
    tags=getTagList(n)  # tag를 한번 더 파싱
    for k in range(len(descript)):
        coreTags=[]
        for t in range(len(tags[k])):
            if (len(tags[k][t])>0)&(tags[k][t] in descript[k]): # 태그가 description 단어에도 있는지 확인
                coreTags.append(tags[k][t])
        if (len(tags[k])<=3): # 태그 수가 없으면 디스크립션으로
            coreTagList.append(descript[k])
        elif((len(tags[k])>3)&(len(coreTags)<3)):  # 디스크립션과 일치하는 태그가 없는데 기존 태그 많으면 기존 태그 사용
            coreTagList.append(tags[k])
        elif(len(coreTags)>=3): # 디스크립션과 일치하는 태그가 많으면 일치태그 사용
            coreTagList.append(coreTags)
    return coreTagList

# %%
# %time CoreTagDate2=getCoreTags2(1852)
CoreTagDate2
# Out:
# [['클래식', '홍대', '빌라', '모던'],
#  ['벽난로', '전망', '루프', '고풍', '자연', '명수'],
#  ['벽난로', '전망', '루프', '고풍', '자연', '명수'],
#  ['선유도', '아파트', '가정', '평투룸', '신축'],
#  ['햇빛',
#   '주방',
#   '직장',
#   '북향',
#   '평일',
#   '전문의',
#   '직접',
#   '가구',
#   '거실',
#   '촬영',
#   '신축',
#   '서재',
#   '관계',
#   '공간',
#   '부부'],
#  ['위치',
#   '세탁실',
#   '찾기',
#   '주방',
#   '사용',
#   '남편',
#   '직접',
#   '빌라',
#   '서재',
#   '바로',
#   '건물',
#   '구조',
#   '주차장',
#   '수원',
#   '친구',
#   '인테리어',
#   '거실',
#   '공원',
#   '다이닝',
#   '화장실',
#   '경기도',
#   '겸용',
#   '여권',
#   '월드컵경기',
#   '드레스',
#   '맞은편',
#   '가까이',
#   '침실',
#   '공용',
#   '베란다',
#   '신혼',
#   '주차',
#   '벽돌',
#   '사이사이',
#   '민원'],
#  ['아파트', '반포', '잠원동', '잠원역', '소형', '강남'],
#  ['광고', '자취', '가구', '원룸', '여자'],
#  ['라이프', '싱글', '원룸', '주거', '고시원', '천호역'],
#  ['블루', '골드', '모던', '서울', '화이트'],
#  ['평수', '테라스', '아이방', '복층'],
#  ['아파트',
#   '사항',
#   '사용',
#   '모두',
#   '주말',
#   '분장',
#   '소품',
#   '확장',
#   '실로',
#   '평일',
#   '화장실',
#   '관계',
#   '단지',
#   '개화',
#   '가능',
#   '시간',
#   '특이',
#   '남서',
#   '안쪽',
#   '서현역',
#   '장대',
#   '공사'],
#  ['칸막이', '공간', '화실', '평의'],
#  ['주차', '차량', '가능', '화장실', '공간'],
#  ['모던', '아이방', '아파트', '정원'],
#  ['가구', '모던', '가정', '접시', '루왁', '오디오', '층집', '레디', '화이트', '소품'],
#  ['베란다', '촬영', '아이', '여의도'],
#  ['소개', '자연', '층집'],
#  ['카페', '심플', '모던', '두운', '근처', '공간', '효창동'],
#  ['심풀', '남자', '시민', '자취', '양재천', '공원', '고인돌', '숲역', '서초구'],
#  ['하우스', '아파트', '우드', '심플', '모던', '신혼집', '추럴', '화이트'],
#  ['연출',
#   '위치',
#   '호선',
#   '분당선',
#   '주방',
#   '빌라',
#   '특징',
#   '뚝섬역',
#   '화이트',
#   '말씀',
#   '남향',
#   '구조',
#   '평일',
#   '거실',
#   '서울',
#   '다이닝',
#   '미리',
#   '테이블',
#   '오전',
#   '그레이',
#   '프레',
#   '대의',
#   '느낌',
#   '블루',
#   '화초',
#   '모던',
#   '촬영',
#   '초반',
#   '자연',
#   '성수동',
#   '분위기',
#   '시한',
#   '저녁',
#   '하나',
#   '침실',
#   '컬러',
#   '협의',
#   '배색',
#   '주차',
#   '서울숲',
#   '저희'],
#  ['가정', '화장실', '반지하', '빌라'],
#  ['옥수동', '신혼집', '아파트', '금호동'],
#  ['아파트', '심플', '모던', '평인', '테리어', '가정', '화이트', '그레이'],
#  ['주방', '쇼파', '거실', '모던', '애견'],
#  ['화이트하우스', '플랜', '촬영', '가정', '테리어', '화이트', '테이블', '원목'],
#  ['평일', '로쏘', '주말', '촬영'],
#  ['인테리어', '카페', '사용', '거의', '이용자', '아침', '촬영', '운영', '가능', '감성', '스터디'],
#  ['후곡', '아파트', '일산', '마을', '파트'],
#  ['위치',
#   '때문',
#   '사용',
#   '요일',
#   '소품',
#   '원상',
#   '현재',
#   '반지하',
#   '선호',
#   '세팅',
#   '촬용',
#   '장비',
#   '가능',
#   '시간',
#   '공실이',
#   '복귀',
#   '주택',
#   '수진동',
#   '성남'],
#  ['장기', '촬영', '작업실', '셀프', '복층', '영화', '월세'],
#  ['네추럴', '원형', '주방', '사진빨', '심플', '조명', '거울', '화이트', '계단'],
#  ['밤하늘', '바다', '단독', '자연', '맑은', '시골'],
#  ['단독주택',
#   '사용',
#   '위로',
#   '차고',
#   '운정신도시',
#   '주변',
#   '장소',
#   '오전',
#   '대여',
#   '검색',
#   '모든',
#   '가능',
#   '시간',
#   '잡지',
#   '오후',
#   '공터',
#   '주차',
#   '사진',
#   '파주',
#   '뒷마당',
#   '앞마당'],
#  ['정원', '소품', '야간'],
#  ['주택'],
#  ['한남동', '모던', '복합', '주상', '정원'],
#  ['테라스', '주택', '홍대', '연남동', '꽃길'],
#  ['벽난로', '주택', '설경', '데크'],
#  ['벽난로', '주택', '설경', '데크'],
#  ['하숙집', '학생', '마당', '기숙사', '층집', '옥상'],
#  ['마당', '네츄럴', '햇살', '나무', '층집', '창문', '사계절'],
#  ['별장', '웨딩', '제주', '스몰', '평정', '야외', '바닷가', '촬영', '힐링', '주독'],
#  ['위치',
#   '경치',
#   '때문',
#   '중이',
#   '빌라',
#   '주말',
#   '이태원',
#   '조율',
#   '현재',
#   '일정',
#   '선호',
#   '공휴일',
#   '신혼부부',
#   '촬영',
#   '주중',
#   '거주',
#   '바깥',
#   '경리',
#   '중턱'],
#  ['갤러리', '신혼집', '화이트', '미니', '원목'],
#  ['아파트', '촬영', '가정', '남향'],
#  ['아파트', '주방', '우드', '거실', '모던', '화이트', '소품', '아기'],
#  ['아파트', '주방', '우드', '거실', '모던', '화이트', '소품', '아기'],
#  ['아파트', '학생', '휴량', '북카페', '자연', '축제', '천일홍', '수채화'],
#  ['아파트', '식물', '촬영', '소품'],
#  ['스타일', '영상', '아파트', '일몰', '브이', '차편', '촬영', '모던', '로그', '소품'],
#  ['아파트', '국적', '심플', '압구정', '모던', '분위기', '화이트', '미니'],
#  ['아파트', '국적', '심플', '압구정', '모던', '분위기', '화이트', '미니'],
#  ['아파트', '모던', '화이트', '고양이'],
#  ['아파트', '한강', '아이', '화이트'],
#  ['신혼집', '강뷰', '대면', '주방'],
#  ['아파트', '심플', '주차', '모던', '가능', '그레이'],
#  ['라면',
#   '아파트',
#   '베란다',
#   '인테리어',
#   '지하철',
#   '평일',
#   '혹시',
#   '나무',
#   '촬영',
#   '석수역',
#   '보기',
#   '시간',
#   '협의'],
#  ['모델링'],
#  ['우드', '잠실', '화이트', '미니'],
#  ['아파트', '전망', '서재', '거실'],
#  ['아파트', '전망', '사용', '대우', '한강', '서울', '금호동', '소재', '부터'],
#  ['남자', '아이방', '아파트', '고층'],
#  ['하우스', '아파트', '심플', '고층', '아이'],
#  ['가족사', '상가', '옥상', '주택', '루프', '해먹', '복층', '다가', '건물', '계단'],
#  ['통기타', '하우스', '여자', '케렌', '쉐어', '시아', '빌라', '쓰리룸', '셰어'],
#  ['홍대입구역', '주택'],
#  ['위치', '거제도', '아파트'],
#  ['독채',
#   '게스트',
#   '인조잔디',
#   '주말',
#   '공간',
#   '다락방',
#   '평일',
#   '추천',
#   '또한',
#   '거실',
#   '장소',
#   '하우스',
#   '서로',
#   '느낌',
#   '촬영',
#   '예약',
#   '다른',
#   '제공',
#   '분위기',
#   '옥상',
#   '진행',
#   '테라스',
#   '프라이',
#   '포함',
#   '컨셉',
#   '저희'],
#  ['분위기', '테라스', '건물', '카페'],
#  ['목동', '깨끗', '양천구', '강서구', '등촌역', '심플', '가정', '염창역'],
#  ['평수', '느낌', '촬영', '모임', '휴양지', '세미', '대형'],
#  ['강남구', '마루', '우드', '추럴', '화이트', '헤링', '원목'],
#  ['아파트', '조명', '용산'],
#  ['가정', '오후'],
#  ['아파트', '목재', '그릇', '촬영'],
#  ['아들',
#   '흙집',
#   '구리',
#   '도로',
#   '자리',
#   '왕방',
#   '직접',
#   '사이',
#   '지은',
#   '자락',
#   '강남',
#   '시간',
#   '동두천',
#   '부부',
#   '개통',
#   '포천'],
#  ['전망', '소형', '가족', '아파트'],
#  ['아파트', '인테리어', '평일', '올해', '모두', '문의', '주말'],
#  ['아파트', '인테리어', '평일', '올해', '모두', '문의', '주말'],
#  ['대여', '아파트', '촬영', '드라마', '화이트', '미니'],
#  ['아파트', '카페', '느낌', '일산', '촬영', '모던', '경기도', '소품', '컬러'],
#  ['아파트', '내추럴', '숲뷰'],
#  ['최상급', '아파트', '촬영', '모던'],
#  ['하우스', '갤러리', '그림', '클래식', '가구', '셀프', '소품'],
#  ['하우스', '갤러리', '그림', '클래식', '가구', '셀프', '소품'],
#  ['리본', '아파트', '마루'],
#  ['다락방', '초대형', '한남동', '벽난로', '산장', '씨티', '빌라', '옥수동', '한강', '분위기', '복층'],
#  ['다락방', '초대형', '한남동', '벽난로', '산장', '씨티', '빌라', '옥수동', '한강', '분위기', '복층'],
#  ['유러', '양재동', '피안', '빌라', '모던', '복층'],
#  ['유러', '양재동', '피안', '빌라', '모던', '복층'],
#  [],
#  ['마케팅',
#   '위치',
#   '패션',
#   '오피스',
#   '뮤직',
#   '공간',
#   '유니크',
#   '광고',
#   '무드',
#   '서브컬쳐',
#   '감성',
#   '중심',
#   '언노운',
#   '머셜',
#   '거리',
#   '컨셉',
#   '회사',
#   '사무실',
#   '출신',
#   '언더그라운드',
#   '프라이',
#   '대기업',
#   '명의',
#   '지인'],
#  ['아파트', '설치', '광교신도시', '요일', '가능'],
#  ['위치', '사용', '분위기', '무대', '마포구', '성산동'],
#  ['테라스', '갤러리', '노출', '루프', '촬영', '현대', '유니크'],
#  ['광고', '아파트', '뉴트', '촬영', '서울', '드라마', '컬러'],
#  ['광고', '아파트', '뉴트', '촬영', '서울', '드라마', '컬러'],
#  ['장소', '촬영', '가정', '영화', '대관'],
#  ['셔터', '마크', '사진', '루버'],
#  ['셔터', '마크', '사진', '루버'],
#  ['테마', '카페', '촬영', '장소'],
#  ['빈티', '촬영', '작업실', '공간', '잡지'],
#  ['잔듸', '촬영', '시골'],
#  ['홍대', '야구', '연습장'],
#  ['펍입니', '이상', '수용', '분위기'],
#  ['일링',
#   '주방',
#   '타운하우스',
#   '광합성',
#   '자체',
#   '유리',
#   '스타',
#   '멍하니',
#   '이방',
#   '채광',
#   '평수',
#   '공간',
#   '원목',
#   '산옆',
#   '수다',
#   '방이',
#   '기본',
#   '거실',
#   '화분',
#   '신축',
#   '게임',
#   '박스',
#   '테이블',
#   '새소리',
#   '전용',
#   '스타일',
#   '밤새',
#   '취향',
#   '느낌',
#   '만화책',
#   '곳곳',
#   '모던',
#   '촬영',
#   '초반',
#   '집안',
#   '침대',
#   '창문',
#   '부부',
#   '침실',
#   '파라솔',
#   '바베큐',
#   '테라스',
#   '방석',
#   '듣기',
#   '가구',
#   '브릭',
#   '신혼',
#   '보이',
#   '역시',
#   '커피',
#   '노리',
#   '소파',
#   '대신'],
#  ['래미안', '놀이', '한세상'],
#  ['전망', '홍대', '거실', '촬영', '가족', '근처', '미니'],
#  ['촬영', '라운지', '영화', '컨셉'],
#  ['인테리어',
#   '주택',
#   '전원',
#   '별채',
#   '조성',
#   '잔디',
#   '실내',
#   '언덕',
#   '특징',
#   '주변',
#   '구분',
#   '귤밭',
#   '복층',
#   '저희'],
#  ['전망', '야경', '올림픽', '공원', '올림픽공원역'],
#  ['강화도', '시골', '대형', '주택'],
#  ['피시방', '일반', '영업', '씨방', '상업', '공간'],
#  ['인테리어', '카페', '규모', '흡연실', '환경'],
#  ['광고', '코딩', '녹음실', '녹음', '강남'],
#  ['감성', '공간', '대관', '성북구'],
#  ['대안', '장소', '복합', '이태원', '공간', '전시'],
#  ['농장', '매실', '보은', '마당', '오두막', '잔디', '산속', '시크릿', '동산'],
#  ['카페', '터치', '분위기', '무인', '자판기', '커피숍'],
#  ['근처',
#   '영상',
#   '아파트',
#   '잠깐',
#   '제품',
#   '사용',
#   '최대한',
#   '흰색',
#   '인원',
#   '신혼집',
#   '규모',
#   '수리',
#   '전동칫솔',
#   '추가',
#   '공간',
#   '변형',
#   '닉스',
#   '이사',
#   '이력',
#   '가전제품',
#   '레트로',
#   '물건',
#   '광고',
#   '인테리어',
#   '용마산',
#   '오히려',
#   '평일',
#   '바이럴',
#   '마음',
#   '설치',
#   '목적',
#   '회색조',
#   '거실',
#   '풀이',
#   '고려',
#   '공원',
#   '오시',
#   '생수',
#   '구성',
#   '맘껏',
#   '직장',
#   '장소',
#   '오전',
#   '욕실',
#   '대여',
#   '드릴',
#   '카메라',
#   '전집',
#   '종류',
#   '촬영',
#   '주중',
#   '회사',
#   '제공',
#   '장비',
#   '주위',
#   '전체',
#   '내용',
#   '미니',
#   '평소',
#   '대방동',
#   '금번',
#   '무방',
#   '무채색',
#   '사진',
#   '노량진',
#   '여러가지',
#   '조명',
#   '금년',
#   '도심',
#   '평이',
#   '와이프',
#   '인서트',
#   '활용'],
#  ['마리나', '회장', '카페', '반포', '보트', '요트', '럭셔리', '동작'],
#  ['헤어', '일산', '미용실', '살롱'],
#  ['다트', '카페', '실내', '맥주', '양궁'],
#  ['샌드위치',
#   '위치',
#   '연출',
#   '인테리어',
#   '오후',
#   '가게',
#   '정자동',
#   '평일',
#   '일요일',
#   '촬영',
#   '분당',
#   '가능',
#   '시간',
#   '선호',
#   '협의'],
#  ['경상남도',
#   '위치',
#   '때문',
#   '사용',
#   '도시가스',
#   '인테리어',
#   '마산합포구',
#   '상태',
#   '장기간',
#   '설치',
#   '거실',
#   '계약',
#   '구성',
#   '렌즈',
#   '비교',
#   '욕실',
#   '대여',
#   '서로',
#   '가스',
#   '집기',
#   '촬영',
#   '방임',
#   '다른',
#   '합의',
#   '주택',
#   '창원시',
#   '비어',
#   '그대로',
#   '최적',
#   '부엌'],
#  ['정말', '아주'],
#  ['이면', '강남', '지하철'],
#  ['파티', '카페', '모임'],
#  ['파티', '카페', '모임'],
#  ['강연', '행사', '라운지', '신사역', '팬미팅', '전시'],
#  ['강연', '행사', '라운지', '신사역', '팬미팅', '전시'],
#  ['벽난로', '고기', '펜션', '토방', '숯불', '가마솥'],
#  ['한남동', '주방', '전통', '가마솥'],
#  ['성주', '해인사', '잔디', '정원', '가야산'],
#  ['위치',
#   '아파트',
#   '사용',
#   '대상',
#   '유희',
#   '주로',
#   '광장',
#   '일요일',
#   '건축',
#   '실로',
#   '방이',
#   '현재',
#   '거실',
#   '가정',
#   '아이',
#   '교실',
#   '단지',
#   '원중',
#   '가능',
#   '시간',
#   '정도',
#   '산책',
#   '형태',
#   '어린이집',
#   '연령',
#   '월요일',
#   '보육',
#   '중앙'],
#  ['순천만', '전남', '순천', '가정', '정원'],
#  ['유투브', '사용', '입자', '촬영', '주말', '오시', '기타', '선호'],
#  ['강아지', '직장인', '가족', '거주', '대학생', '부부', '중년'],
#  ['방도',
#   '베란다',
#   '놀이',
#   '일반',
#   '모두',
#   '거실',
#   '주말',
#   '가정',
#   '화장실',
#   '주중',
#   '촬영',
#   '아이',
#   '거주',
#   '중인'],
#  ['강동구', '빌라', '서울시', '신축'],
#  ['베란다', '아파트', '거실', '가정'],
#  ['광고', '대리석', '아파트', '촬영', '가정', '신혼집', '쇼핑몰', '대관'],
#  ['까페', '심플', '모던', '가정'],
#  ['까페', '심플', '모던', '가정'],
#  ['가정', '인천', '아파트', '서재'],
#  ['가정', '인천', '아파트', '서재'],
#  ['아파트', '모던', '가정', '주말', '소음', '가능', '근처'],
#  ['하우스', '게스트하우스', '공간'],
#  ['레트로', '가정', '큰집', '쓰리룸', '채광', '대형', '원목'],
#  ['모던', '복합', '주상'],
#  ['주택', '일산', '빌라', '가정', '개인', '방송', '투룸'],
#  ['가정', '시간'],
#  ['복도', '레트로', '빈티', '아파트', '촬영', '가정', '이태원', '혼사', '대관'],
#  ['복도', '레트로', '빈티', '아파트', '촬영', '가정', '이태원', '혼사', '대관'],
#  ['람사', '가정', '가족', '아파트'],
#  ['아파트', '클래식', '우드', '가정'],
#  ['아파트', '클래식', '우드', '가정'],
#  ['테라스', '홍대', '가정', '서교동', '내츄럴'],
#  ['테라스', '홍대', '입구', '가정', '내츄럴'],
#  ['아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['아파트',
#   '일반',
#   '모두',
#   '우드',
#   '소나무',
#   '주말',
#   '인테리어',
#   '평일',
#   '가정',
#   '선호',
#   '느낌',
#   '촬영',
#   '티크',
#   '분위기',
#   '시간',
#   '전체',
#   '창문',
#   '가구',
#   '보이'],
#  ['목포', '아파트', '광장', '영산강', '주변', '평화'],
#  ['목포', '아파트', '광장', '영산강', '주변', '평화'],
#  ['일산', '세가족'],
#  ['하우스', '대여', '아파트', '그램', '장소', '스타', '가정', '촬영', '홈인', '테리어', '홈스', '대관'],
#  ['어항', '작고', '화초', '가정', '해수어'],
#  ['광주', '가정', '가족', '경기'],
#  ['대여', '아파트', '가정'],
#  ['대여', '제품', '바이럴', '촬영', '대관'],
#  ['빼기', '동선', '주방', '가구', '거실', '촬영', '배치', '안성맞춤', '햇볕', '화이트', '소품', '일자'],
#  ['촬영', '가정', '차편', '전망'],
#  ['대여', '아파트', '거실', '촬영', '남향'],
#  ['테라스', '모델링', '정원'],
#  ['세대', '주인', '장비', '다가'],
#  ['광고', '아파트', '촬영', '신혼집', '가족', '드라마', '잡지'],
#  ['북유럽', '아파트', '내츄럴'],
#  ['촬영', '화이트', '노을'],
#  ['번화가', '영상', '대여', '홍대', '바이럴', '촬영', '가정', '가족', '장소'],
#  ['오이', '펜션', '단체', '야외', '코스', '가족', '레저', '정원'],
#  ['위치',
#   '동의보감',
#   '예담',
#   '선사',
#   '화이트',
#   '로우',
#   '카페',
#   '호강',
#   '산청읍',
#   '대원사',
#   '레드',
#   '그레이',
#   '명소',
#   '둘레길',
#   '남사',
#   '블루',
#   '야외',
#   '코스',
#   '몬드리안',
#   '바베큐',
#   '레프',
#   '펜션',
#   '수영장',
#   '지리산',
#   '컨셉',
#   '그린'],
#  ['까페', '강변', '독채', '웨딩', '스몰', '북한', '가평', '야외', '경기'],
#  ['마당', '잔디', '시골'],
#  ['별장', '황토', '잣나무', '가평', '구들', '힐링', '설악'],
#  ['갤러리', '카페', '환상', '가평', '코스', '드라이브', '로코', '호명'],
#  ['각종', '생일', '파티', '촬영', '모임', '서울', '강남', '스터디', '대관'],
#  ['영상', '세미나', '강연', '원데이', '촬영', '간담'],
#  ['도산', '루프', '공원'],
#  ['법률', '사무소', '감각'],
#  ['레트로', '하우스', '빈티', '자취', '감각'],
#  ['브라', '파티', '샤워', '공간'],
#  ['렌탈', '욕조', '바이럴', '촬영', '자연', '그네', '감성'],
#  ['주차장', '불광천', '테라스', '카페', '분위기', '감성'],
#  ['오래돤', '레슨', '모델링', '주택', '실로', '사용', '향수', '힐링', '양지', '감수성', '장소', '구조'],
#  ['친구', '감성', '대화', '가운데', '공간', '정리', '스스로', '지인'],
#  ['빈티', '촬영', '경리'],
#  ['펜션', '촬영', '수영장', '정원'],
#  ['바베큐', '테라스', '복층'],
#  ['마당', '내추럴', '화이트', '미니'],
#  ['마당', '내추럴', '화이트', '미니'],
#  ['렌탈', '작업실', '도곡동', '강남', '양재'],
#  ['선릉역', '연습실', '거울', '강남'],
#  ['모던', '사무실', '오피스'],
#  ['카페', '촬영', '강남', '인생', '양재', '대관'],
#  ['카페', '촬영', '강남', '인생', '양재', '대관'],
#  ['영상', '광고', '역삼역', '제품', '사진', '촬영', '대행', '호리', '강남', '룩북'],
#  ['신사', '유튜브', '역삼', '촬영', '유튜버', '호리', '강남', '논현'],
#  ['렌탈', '유튜브', '청담동', '셀프', '무인', '강남'],
#  ['대여', '주방', '파티', '강남', '공간'],
#  ['타워', '서밋', '반포', '야경', '촬영', '강남', '교보', '옥상'],
#  ['강남구', '그림', '도산', '미술', '학원', '신사동', '압구정', '민화', '동양화', '공원', '수묵화'],
#  ['임원', '강남구', '학동역', '회의실', '사무실', '오피스', '논현동'],
#  ['위치', '하우스', '조율', '모던', '가능', '예약', '시간', '사전', '바로', '강남역'],
#  ['위치', '하우스', '조율', '모던', '가능', '예약', '시간', '사전', '바로', '강남역'],
#  ['단독주택',
#   '북유럽',
#   '강남구',
#   '디자이너',
#   '디자인',
#   '진품',
#   '가구',
#   '주말',
#   '배치',
#   '대환영',
#   '화이트',
#   '근처',
#   '이용',
#   '건물',
#   '수서역'],
#  ['위치', '하우스', '조율', '모던', '가능', '예약', '시간', '사전', '바로', '강남역'],
#  ['렌탈', '주택', '강남', '쓰리룸', '반지하', '논현역', '강남역'],
#  ['대치동', '강남', '삼성역'],
#  ['모던', '광고', '강남', '인터뷰'],
#  ['영상', '호리', '화이트'],
#  ['렌탈', '주역', '호리', '논현동'],
#  ['영상', '존트', '사진', '호리', '강남'],
#  ['국제',
#   '규모',
#   '강남',
#   '부터',
#   '논현',
#   '평수',
#   '구조',
#   '유일',
#   '최대',
#   '중대',
#   '대대',
#   '포켓',
#   '대형',
#   '강남역',
#   '느낌',
#   '사이',
#   '촬영',
#   '프리미엄',
#   '까페',
#   '오후',
#   '실내',
#   '구장',
#   '탁트인',
#   '야간'],
#  ['존트', '호리', '대형', '강남역'],
#  ['위치', '뱅뱅', '계열', '모던', '강남', '화이트', '사거리', '복층', '침실', '구조'],
#  ['렌탈', '촬영', '자연'],
#  ['카페', '파티', '아지트', '작업실'],
#  ['극장', '베란다', '갤러리', '공원', '화이트', '리조트'],
#  ['마당', '주택', '구옥', '한국'],
#  ['카페', '유리창', '바다', '강릉', '정동진'],
#  ['강변', '주방', '야경', '모던', '프렌치', '조명'],
#  ['게스트하우스', '바지선', '모닥불', '소나무', '정원', '노래방', '소품'],
#  ['게스트하우스', '바지선', '모닥불', '소나무', '정원', '노래방', '소품'],
#  ['독신남', '강북', '성북구', '심플', '모던', '강북구', '노원구'],
#  ['독신남', '강북', '성북구', '심플', '모던', '강북구', '노원구'],
#  ['다락방', '배경', '한강'],
#  ['아파트', '신혼집', '다른', '분위기', '강남'],
#  ['강서구', '네츄럴', '심플', '서울', '화이트', '공간', '블랙', '코지'],
#  ['영상', '세미나', '걱정', '강연', '신촌', '촬영', '모임', '찍기', '소음', '신촌역', '장소'],
#  ['건어물', '거진항', '강원도', '가게'],
#  ['위치',
#   '장면',
#   '인테리어',
#   '평일',
#   '펜션',
#   '부대',
#   '바다',
#   '촬영',
#   '해수욕장',
#   '강원도',
#   '바로',
#   '이용',
#   '선호'],
#  ['세미나', '모임', '소규모', '쇼룸', '공간'],
#  ['영상', '강의실', '회의실', '바이럴', '작은방', '촬영', '강남'],
#  ['세미나', '강의실', '촬영', '강의'],
#  ['진돗개', '자연', '강화도', '최고급', '가재'],
#  ['기독교', '강화도', '교회', '양관'],
#  ['방음', '개인', '방송'],
#  ['카페', '고척동', '개인', '분위기'],
#  ['분위기', '개인', '복층', '카페'],
#  ['카페', '송정', '철길', '애견', '폐역'],
#  ['작고', '카페', '동네', '심플', '모던', '개인'],
#  ['위치',
#   '환갑',
#   '파티',
#   '교육방송',
#   '국제',
#   '원룸',
#   '알라딘',
#   '돌잔치',
#   '영화',
#   '공간',
#   '건물',
#   '중고서점',
#   '오피스텔',
#   '영화제',
#   '인근',
#   '거리',
#   '전주',
#   '스몰',
#   '미술',
#   '사무실',
#   '대전',
#   '문화',
#   '전시',
#   '웨딩',
#   '유니클로',
#   '마을',
#   '기린',
#   '상가'],
#  ['위치',
#   '그래퍼',
#   '인테리어',
#   '수준',
#   '갤러리',
#   '건물',
#   '창가',
#   '포토',
#   '작업실',
#   '각각',
#   '조명',
#   '스튜디오',
#   '화가',
#   '중앙',
#   '명의',
#   '작품',
#   '안양천'],
#  ['갤러리', '아파트', '유럽', '거실', '조명'],
#  ['책방', '갤러리', '서점', '작업실', '독립'],
#  ['병원', '에스테', '분위기', '공간'],
#  ['골드', '갤러리', '카페'],
#  ['마당', '주택', '농가', '갤러리', '정원', '화가', '시골'],
#  ['피로연', '기원', '바둑', '카페', '돌잔치'],
#  ['책방', '벽난로', '카페', '북카페', '어린이'],
#  ['예술',
#   '공간',
#   '라이프',
#   '자리',
#   '이야기',
#   '연남동',
#   '자유',
#   '대중',
#   '활동',
#   '스타일',
#   '갤러리',
#   '통해',
#   '시도',
#   '제안',
#   '시절',
#   '전시',
#   '작품',
#   '진행',
#   '연남',
#   '프로그램',
#   '전달',
#   '노력',
#   '작가',
#   '일상',
#   '주목',
#   '누구'],
#  ['세미나', '갤러리', '클래스', '강연', '전시회'],
#  ['세미나', '갤러리', '강연', '워크샵', '전시회'],
#  ['바닥', '거실', '나무', '마루', '합정동'],
#  ['바닥', '거실', '나무', '마루', '합정동'],
#  ['주택', '해방촌', '거실', '루프'],
#  ['아파트', '거실'],
#  ['위치',
#   '렌탈',
#   '레이스',
#   '일반',
#   '모두',
#   '실제',
#   '화이트',
#   '공간',
#   '건물',
#   '최소',
#   '인테리어',
#   '현재',
#   '가정',
#   '작업실',
#   '덴마크',
#   '인근',
#   '지하',
#   '검색',
#   '개인',
#   '거주',
#   '가능',
#   '시간',
#   '미니',
#   '주택',
#   '일산',
#   '사진',
#   '단독',
#   '소규모',
#   '운영',
#   '대관'],
#  ['위치',
#   '렌탈',
#   '레이스',
#   '일반',
#   '모두',
#   '실제',
#   '화이트',
#   '공간',
#   '건물',
#   '최소',
#   '인테리어',
#   '현재',
#   '가정',
#   '작업실',
#   '덴마크',
#   '인근',
#   '지하',
#   '검색',
#   '개인',
#   '거주',
#   '가능',
#   '시간',
#   '미니',
#   '주택',
#   '일산',
#   '사진',
#   '단독',
#   '소규모',
#   '운영',
#   '대관'],
#  ['중간', '중심', '일반', '가정', '배치', '공간', '중정', '작품'],
#  ['위치',
#   '영상',
#   '호선',
#   '시설',
#   '사용',
#   '스튜디오',
#   '공간',
#   '도보',
#   '세미나',
#   '목적',
#   '이마트',
#   '강의',
#   '게임',
#   '주변',
#   '테이블',
#   '마트',
#   '거리',
#   '촬영',
#   '모임',
#   '편의',
#   '편의점',
#   '사진',
#   '미터',
#   '농협',
#   '이벤트',
#   '다이소',
#   '소파'],
#  ['모던', '인테리어', '심플', '가구'],
#  ['주방', '빌라', '모던', '거실', '분위기'],
#  ['주방', '거실', '블랙', '서재', '화이트', '미니', '남향'],
#  ['아파트', '거실', '아이방'],
#  ['호수', '아파트', '그림', '느낌', '공원'],
#  ['호수', '아파트', '그림', '느낌', '공원'],
#  ['베란다', '거실', '모던', '가정', '화이트', '정원', '잡지'],
#  ['우드', '거실', '햇살'],
#  ['주택', '느낌', '일반', '거실', '촬영', '자연', '커튼'],
#  ['거제도', '앞펜션', '제일', '바다'],
#  ['특급', '호텔', '럭셔리', '거제', '촬영', '장소', '경남', '수영장', '오션', '공간', '거제도', '라마'],
#  ['호텔', '럭셔리', '오션', '공간'],
#  ['특급', '호텔', '럭셔리', '거제', '촬영', '장소', '경남', '수영장', '휴가', '오션', '공간', '라마'],
#  ['특급', '호텔', '럭셔리', '거제', '촬영', '장소', '경남', '수영장', '휴가', '오션', '공간', '라마'],
#  ['테라스', '자취', '빌라', '화장실', '화이트', '투룸', '미니'],
#  ['테라스', '자취', '빌라', '화장실', '화이트', '투룸', '미니'],
#  ['블럭', '내부', '시멘트', '구로', '건축가', '대구', '건축', '건축사', '강판'],
#  ['차고', '게러', '창고', '고양이'],
#  ['영화',
#   '세미나',
#   '게스트하우스',
#   '거리',
#   '회신',
#   '바다',
#   '년회',
#   '부산',
#   '해운대',
#   '회송',
#   '워크숍',
#   '망년',
#   '동백섬'],
#  ['다락방', '마당', '게스트하우스', '공원', '낙산'],
#  ['민박', '주택', '파티', '게스트하우스', '홍대', '펜션', '입구', '서울', '호스텔'],
#  ['호스텔', '종로', '로비'],
#  ['일산동', '빌라', '복층'],
#  ['화보', '촬영', '분당', '성남', '영화', '경기', '장소'],
#  ['레트로', '빈티', '심플', '뉴트', '가정', '경기', '화이트', '미니', '원목'],
#  ['마당', '느낌', '잔디', '우드'],
#  ['기지역', '수도권', '성남동', '성남', '경기도'],
#  ['모던', '신혼집', '경기도'],
#  ['키친', '촬영', '쿠킹', '대관'],
#  ['아파트', '촬영', '하남', '경기도'],
#  ['호수', '촬영', '방송', '경기도', '광교'],
#  ['광주', '주차', '가능', '경기도', '채광'],
#  ['광주시', '호리', '경기도'],
#  ['남양주', '심플', '가정', '경기도'],
#  ['원룸', '모던', '야당'],
#  ['경남', '소품', '양산'],
#  ['카페', '이태원', '애견'],
#  ['파티', '클래스', '자연', '쿠킹'],
#  ['생활', '작업실', '공간'],
#  ['별장', '계곡', '등산로'],
#  ['주택', '해방촌', '루프', '계단'],
#  ['주택', '해방촌', '루프', '계단'],
#  ['벽난로', '피아노', '책장', '메그', '계단'],
#  ['벽난로', '피아노', '책장', '메그', '계단'],
#  ['옥탑', '옥상', '주택', '계단'],
#  ['계단', '쇼파', '시계', '조명', '복층', '식탁', '샹들리', '스탠드'],
#  ['테라스', '가구', '복층', '유니크'],
#  ['다락방', '느낌', '원목', '나무', '복층', '구조'],
#  ['빈티', '중후', '클래식', '가구', '분위기', '서재', '어르신', '담소', '장소'],
#  ['빈티', '중후', '클래식', '가구', '분위기', '서재', '어르신', '담소', '장소'],
#  ['신도림', '갤러리', '백지장', '모임', '가옥'],
#  ['전망', '유리', '고급', '부산', '해운대', '탁트인'],
#  ['테라스', '단지', '소나무', '빌라', '정원'],
#  ['테라스', '주택', '빌라', '풍경'],
#  ['코팅', '마당', '웨인', '제주도'],
#  ['위치',
#   '보드',
#   '용도',
#   '설치',
#   '거실',
#   '테이블',
#   '라운지',
#   '서울',
#   '미터',
#   '분위기',
#   '수동',
#   '복층',
#   '마포구',
#   '와인'],
#  ['고급', '호수', '아파트'],
#  ['광고', '주택', '고급', '촬영', '루프', '정원', '대형'],
#  ['삼겹살', '고기', '소고기', '한식당'],
#  ['일반', '나름', '가정', '고양이'],
#  ['러블리', '카페', '고양이'],
#  ['모델', '아기', '고양이'],
#  ['독채', '군산', '주택', '시골'],
#  ['독채', '군산', '주택', '시골'],
#  ['해변', '아파트', '바다'],
#  ['아파트', '석양', '청주', '야경', '고층', '노을', '불빛', '웰시'],
#  ['아파트', '고층', '도시'],
#  ['산조', '아파트', '북한', '고층', '신축'],
#  ['일반', '주거', '아파트'],
#  ['오후', '목요일', '오전'],
#  ['아팟입니', '전망', '바다'],
#  ['아파트', '중산층', '일반', '가정', '전형'],
#  ['아파트', '전망', '석양', '바다', '소형', '고층', '시흥'],
#  ['송도국제도시', '인천', '아파트', '대교', '아주', '바다', '고층', '남향'],
#  ['아파트', '모던', '화이트', '블랙'],
#  ['채광', '인천', '고층', '아파트'],
#  ['정원', '자연', '고층', '아파트'],
#  ['나주', '오후', '오전'],
#  ['레트로', '고택', '옛날', '게스트하우스'],
#  ['레트로', '고택', '옛날', '게스트하우스'],
#  ['빈티', '주택', '나무'],
#  ['빈티', '주택', '나무'],
#  ['일산', '블루', '골드'],
#  ['위치',
#   '사용',
#   '천호동',
#   '개정',
#   '주말',
#   '휴무',
#   '주차장',
#   '카페',
#   '평일',
#   '테이블',
#   '거리',
#   '종일',
#   '촬영',
#   '저녁',
#   '가능',
#   '시간',
#   '정도',
#   '협의',
#   '골목길',
#   '오후',
#   '이후',
#   '로데오',
#   '월요일',
#   '골목',
#   '하루',
#   '유료'],
#  ['클래스', '백지장', '촬영', '공소', '공간', '문래'],
#  ['한남동', '회의실', '루프', '워크샵', '테디', '오피스', '공간'],
#  ['공간', '전망'],
#  ['공덕역', '평일', '문의', '날짜', '가능', '오피스텔', '선호'],
#  ['촬영', '모임', '공간', '장소'],
#  ['꽃차', '주방', '공유'],
#  ['공부', '보습', '학생', '학원'],
#  ['아파텔', '모임', '부방'],
#  ['공부', '거실', '서재'],
#  ['위치',
#   '주택',
#   '용인',
#   '지역',
#   '개발',
#   '공터',
#   '제작',
#   '단지',
#   '언제',
#   '주차',
#   '촬영',
#   '가건물',
#   '규모',
#   '공간',
#   '이용',
#   '주위'],
#  ['공연', '촬영', '연주회', '콘서트'],
#  ['음향', '카메라', '공연', '중계', '올인원', '조명', '스트림', '라이브'],
#  ['공연', '리허설', '촬영', '무대', '공간'],
#  ['공연', '리허설', '촬영', '무대', '공간'],
#  ['연습실', '공연장', '파티'],
#  ['디자인', '작업실', '소규모', '사무실', '공연장'],
#  ['홍대', '단풍', '공원', '벚꽃'],
#  ['아파트', '거실', '공원', '자동', '바로', '중문'],
#  ['고깔', '아파트', '공원', '복층'],
#  ['촬영', '가정', '스튜디오'],
#  ['주방', '역삼동', '클래스', '공유'],
#  ['촬영', '공장', '사무실', '가능'],
#  ['공장', '대형', '파주'],
#  ['아파트', '평일', '사이', '평의', '공주', '시간'],
#  ['마당', '주택', '목조'],
#  ['광고', '화보', '촬영', '영화'],
#  ['테라스', '게스트하우스', '호스텔', '정원', '장소'],
#  ['촬영', '광고', '드라마', '가능'],
#  ['디테', '자동차', '광고', '일링', '세차장', '광택', '촬영'],
#  ['북유럽', '광고', '촬영', '화이트'],
#  ['북유럽', '광고', '촬영', '화이트'],
#  ['광고', '촬영', '복층'],
#  ['광고', '촬영', '복층'],
#  ['광고', '촬영', '복층'],
#  ['광고', '촬영', '드라마'],
#  ['키친', '우드', '촬영', '오븐', '다이닝', '요리', '햇살'],
#  ['아파트', '촬영', '광교'],
#  ['호수', '수원', '공원', '광교', '컨벤션'],
#  ['옥상', '주택', '광명'],
#  ['옥상', '주택', '광명'],
#  ['해변', '광안', '바다'],
#  ['부산', '소품', '화보', '광안'],
#  ['라이프', '광주', '심플', '모던', '화이트', '광역시', '미니'],
#  ['모던', '클래식', '전망', '광화문'],
#  ['환영', '해주시', '거리', '광흥', '촬영', '가정'],
#  ['가정', '거실'],
#  ['교습', '부방', '장소'],
#  ['플랜', '테리어', '분위기'],
#  ['카페', '파티', '단체', '촬영', '모임', '이벤트', '장소'],
#  ['대림역', '모던', '신축', '커튼'],
#  ['단독주택',
#   '이상',
#   '구분',
#   '빈집',
#   '구옥',
#   '별채',
#   '본채',
#   '다집',
#   '예약',
#   '수리',
#   '소재',
#   '합정동',
#   '앞마당'],
#  ['주택', '식물', '원목'],
#  ['글로벌', '기숙사', '국제', '서울'],
#  ['뮤직', '까페', '라이브', '군산'],
#  ['뮤직', '까페', '라이브', '군산'],
#  ['귀촌', '귀농', '고양이'],
#  ['장작',
#   '하우스',
#   '마당',
#   '그루',
#   '사용',
#   '주차공간',
#   '잔디',
#   '난로',
#   '컨테이너',
#   '귤나무',
#   '허름',
#   '겨울',
#   '가마솥'],
#  ['음악학', '아파트', '레슨', '은마', '그랜드피아노', '학원', '대치동', '피아노', '첼로'],
#  ['대리석', '주방', '놀이', '모던', '고급'],
#  ['산조', '조적', '놀이터', '모던', '어린이', '욕실', '그레이'],
#  ['전면', '전망', '심플', '모던', '화이트', '그레이'],
#  ['하우스', '모던', '천안', '그레이'],
#  ['모던', '영등포', '그레이'],
#  ['모던', '영등포', '그레이'],
#  ['너리', '공간', '공존', '화이트'],
#  ['저녁놀', '베란다', '식물'],
#  ['빈티', '액자', '그림', '도자기', '조명', '공간', '늑한'],
#  ['아파트',
#   '그림',
#   '지역',
#   '주차공간',
#   '조성',
#   '청주',
#   '단지',
#   '도자기',
#   '정원',
#   '구성',
#   '공간',
#   '작품',
#   '활용'],
#  ['위치',
#   '시야',
#   '수욜',
#   '아파트',
#   '그림',
#   '탁트인',
#   '골프장',
#   '실내',
#   '아침',
#   '풍경월욜',
#   '저녁',
#   '미술품',
#   '최고급',
#   '경기도',
#   '한성',
#   '시간',
#   '이용'],
#  ['웨딩', '파티', '미팅', '스몰', '루프', '촬영', '글램핑', '스터디', '대관'],
#  ['웨딩', '파티', '미팅', '스몰', '루프', '촬영', '글램핑', '스터디', '대관'],
#  ['보유', '위치', '포항', '요트', '글램핑'],
#  ['보유', '위치', '포항', '요트', '글램핑'],
#  ['엠티', '수원', '기와집', '단체', '수영장', '대학생', '시골', '수련', '운동장'],
#  ['클래식', '모던', '복합', '주상'],
#  ['복도', '길이', '아파트', '느낌', '일산', '색감', '거실', '복합', '백석동', '통창', '주상', '경기도'],
#  ['단위',
#   '아파트',
#   '유보',
#   '한강',
#   '반도',
#   '환경',
#   '상태',
#   '현재',
#   '의도',
#   '공원',
#   '주변',
#   '구성',
#   '소도구',
#   '김포',
#   '신후',
#   '구래동',
#   '호수',
#   '통해',
#   '촬영',
#   '차량',
#   '분위기',
#   '촬영장',
#   '요즘',
#   '아주',
#   '소로',
#   '신도시',
#   '실내',
#   '실외',
#   '도로',
#   '상가'],
#  ['단위',
#   '아파트',
#   '유보',
#   '한강',
#   '반도',
#   '환경',
#   '상태',
#   '현재',
#   '의도',
#   '공원',
#   '주변',
#   '구성',
#   '소도구',
#   '김포',
#   '신후',
#   '구래동',
#   '호수',
#   '통해',
#   '촬영',
#   '차량',
#   '분위기',
#   '촬영장',
#   '요즘',
#   '아주',
#   '소로',
#   '신도시',
#   '실내',
#   '실외',
#   '도로',
#   '상가'],
#  ['위치',
#   '대여',
#   '주방',
#   '거의',
#   '평일',
#   '신도시',
#   '사람',
#   '한강',
#   '거실',
#   '가정',
#   '촬영',
#   '소음',
#   '주말',
#   '신축',
#   '화장실',
#   '바깥',
#   '김포',
#   '건물'],
#  ['인테리어', '마당', '아파트', '평형', '주말', '화이트', '정도', '선호'],
#  ['까페', '빈티', '아파트', '느낌', '씨티', '조명', '복층', '남산'],
#  ['베란다', '연애', '참견', '서울', '확장'],
#  ['대리석', '와인', '바닥', '파티'],
#  ['위치',
#   '아파트',
#   '욕조',
#   '샤워',
#   '기흥구',
#   '미니멀리즘',
#   '추구',
#   '화이트',
#   '벚꽃',
#   '바로',
#   '공간',
#   '부스',
#   '구조',
#   '물건',
#   '나머지',
#   '용인시',
#   '평일',
#   '골프장',
#   '쇼파',
#   '거실',
#   '화장실',
#   '경기도',
#   '선호',
#   '에어컨',
#   '공간활용',
#   '전부',
#   '거리',
#   '놀이터',
#   '안방',
#   '지하',
#   '모던',
#   '촬영',
#   '분위기',
#   '침대',
#   '시간',
#   '전체',
#   '오후',
#   '전망',
#   '마북동',
#   '동네',
#   '주차',
#   '아침',
#   '아이방',
#   '한성',
#   '개중',
#   '근처'],
#  ['아파트', '심플', '안방', '모던', '신축', '미니', '침실'],
#  ['아파트',
#   '알파',
#   '야경',
#   '서재',
#   '구애',
#   '데리',
#   '고양이',
#   '작은방',
#   '부담',
#   '아이',
#   '신축',
#   '주변',
#   '센트럴',
#   '사람',
#   '곳곳',
#   '촬영',
#   '바다',
#   '베드룸',
#   '분위기',
#   '협조',
#   '파크',
#   '가능',
#   '시간',
#   '포인트',
#   '협의',
#   '비용',
#   '마리',
#   '주차',
#   '조명',
#   '역사'],
#  ['탄천', '인근', '분당', '아파트'],
#  ['정말', '안방', '심플', '거실', '보기', '부방', '겨울', '유지'],
#  ['기분', '장소'],
#  ['스코프', '주방', '쇼파', '아이', '책장', '테이블', '원목'],
#  ['인테리어',
#   '요즘',
#   '시간',
#   '식물',
#   '평일',
#   '마크',
#   '영시',
#   '메로',
#   '파주',
#   '공간',
#   '화이트',
#   '트렌드',
#   '근처',
#   '금릉역',
#   '선호'],
#  ['조금', '아파트', '탑층', '모델링', '오전', '심플', '신혼집', '복층', '사다리'],
#  ['위치',
#   '아파트',
#   '인테리어',
#   '광진구',
#   '심플',
#   '편입',
#   '자양동',
#   '거실',
#   '호환',
#   '특징',
#   '가능',
#   '신축',
#   '화이트',
#   '조화',
#   '평수',
#   '블랙',
#   '활용'],
#  ['위치',
#   '아파트',
#   '인테리어',
#   '광진구',
#   '심플',
#   '편입',
#   '자양동',
#   '거실',
#   '호환',
#   '특징',
#   '가능',
#   '신축',
#   '화이트',
#   '조화',
#   '평수',
#   '블랙',
#   '활용'],
#  ['카페', '파주', '디저트'],
#  ['바베큐', '패치', '야외', '구장', '정원'],
#  ['광주시', '전원주택', '주택', '시간', '선택', '연예인', '요일', '고급', '거주', '오포읍', '유명'],
#  ['정원', '텃밭', '수국'],
#  ['반려견', '테라스', '가구', '나무', '공간', '유니크'],
#  ['뒷산', '마당', '연못'],
#  ['나무', '촬영', '해방촌', '주택'],
#  ['빈티', '하우스', '나무'],
#  ['빈티', '하우스', '나무'],
#  ['평일', '모두', '주말', '분위기', '오피스텔'],
#  ['위치',
#   '생활',
#   '공덕역',
#   '사전예약',
#   '마포',
#   '구애',
#   '말씀',
#   '소품',
#   '감각',
#   '화면',
#   '주차장',
#   '크게',
#   '서울',
#   '사전',
#   '대중교통',
#   '사람',
#   '이용도',
#   '느낌',
#   '표현',
#   '연결',
#   '주시',
#   '개인',
#   '시간',
#   '이용권',
#   '해주시',
#   '날짜',
#   '컬러풀'],
#  ['풍부', '한직', '언제', '실감', '촬영', '예약', '미리', '오피스텔'],
#  ['연락',
#   '위치',
#   '하우스',
#   '주택가',
#   '골목',
#   '주방',
#   '게스트하우스',
#   '킨텍스',
#   '나름',
#   '일산',
#   '거실',
#   '빌라',
#   '평소',
#   '촬영',
#   '운영',
#   '리아'],
#  ['위치',
#   '하우스',
#   '신흥시장',
#   '요즘',
#   '사용',
#   '남산타워',
#   '세상',
#   '루프',
#   '로서',
#   '보이',
#   '서울역',
#   '도심',
#   '독립',
#   '근처',
#   '지척',
#   '해방촌'],
#  ['마을', '필동', '남산', '원룸'],
#  ['유리창', '자취', '원룸', '저취방', '복층', '구조'],
#  ['홍대', '동교동', '원룸', '서울시'],
#  ['바이럴', '직장인', '자취', '원룸', '동대문', '드라마', '여자'],
#  ['북유럽', '아파트', '일산', '모던', '복층', '백석역'],
#  ['아파트', '일산', '원룸', '모던', '복층'],
#  ['파티', '복합', '주상'],
#  ['위치', '인테리어', '이태리', '가죽', '거울', '고층', '복층', '종각역', '오피스텔'],
#  ['햇빛', '카페', '식물', '원룸', '분위기', '평택'],
#  ['지층',
#   '빈티',
#   '하우스',
#   '스타일',
#   '인테리어',
#   '주택',
#   '가장',
#   '평일',
#   '원룸',
#   '오디오',
#   '스피커',
#   '저녁',
#   '구성',
#   '컨셉',
#   '저희',
#   '부부'],
#  ['연세대', '서강대', '신촌', '이대'],
#  ['연락', '호수', '일산', '원룸', '촬영', '공원', '침대', '공간', '소파', '오피스텔', '그레이'],
#  ['촬영', '대관', '원룸', '장소'],
#  ['홀로',
#   '광고',
#   '의방',
#   '휴양림',
#   '단체',
#   '작가',
#   '공간',
#   '휴식',
#   '색공간',
#   '정원',
#   '운동',
#   '요가',
#   '데크'],
#  ['베드', '테라스', '원룸', '셀프', '데이', '분리', '남산'],
#  ['시야', '촬영', '사무실'],
#  ['후암동', '남산', '마루'],
#  ['광고', '전망', '식물', '인더스트리얼', '촬영', '후암동', '서울역', '영화', '남산'],
#  ['빌라', '야경', '후암동'],
#  ['산조', '정체', '상암', '북한', '차량', '여의도', '공사', '안양천'],
#  ['남서', '사진', '노을'],
#  ['내부',
#   '인용',
#   '개울',
#   '플룻',
#   '피아노',
#   '정원',
#   '공간',
#   '계곡',
#   '정자',
#   '난로',
#   '대형',
#   '테이블',
#   '장소',
#   '촬영',
#   '모임',
#   '개인',
#   '바이올린',
#   '첼로',
#   '정도',
#   '벽난로',
#   '주택',
#   '보고',
#   '여명',
#   '화목',
#   '소로',
#   '조명',
#   '샹데리',
#   '가마솥'],
#  ['식물', '동네', '남양주', '플랜', '테리어', '신혼집', '공간', '햇살'],
#  ['벽난로', '마당', '남양주', '그네', '진접'],
#  ['낚시', '자라섬', '강변', '리버', '체험', '보트', '북한', '청평댐', '뷰강', '남이섬'],
#  ['어업', '바지선', '한강'],
#  ['장판',
#   '주방',
#   '게스트',
#   '별채',
#   '교체',
#   '구조',
#   '남해',
#   '싱크대',
#   '작은방',
#   '도배',
#   '창고',
#   '화장실',
#   '시골',
#   '임대',
#   '바다',
#   '텃밭',
#   '주거',
#   '촬영장',
#   '항구',
#   '소로',
#   '남면',
#   '마을',
#   '언덕'],
#  ['신답역', '거실', '아이', '도보', '남향'],
#  ['느낌', '내추럴', '촬영'],
#  ['강아지',
#   '위치',
#   '본집',
#   '호선',
#   '신이문역',
#   '아파트',
#   '모델링',
#   '일링',
#   '신혼부부',
#   '한번',
#   '내추럴',
#   '정도',
#   '경험',
#   '촬영',
#   '돌곶이역',
#   '신축',
#   '홈스',
#   '도보'],
#  ['풍경', '자연', '시골'],
#  ['빈티', '마루', '화이트', '채광', '원목', '내츄럴'],
#  ['빈티', '마루', '화이트', '채광', '원목', '내츄럴'],
#  ['바베큐', '테라스', '마당', '주택', '물놀이', '풍경', '산속', '시골', '냇물'],
#  ['오후', '오전', '요일', '가정', '가능', '조명', '운치', '시간', '햇살', '선호', '조정'],
#  ['유럽', '인테리어', '거실'],
#  ['주방', '거실', '침실'],
#  ['마당', '구조', '복층'],
#  ['연못', '기와', '정원', '데크'],
#  ['주차장', '사찰', '카페', '분위기', '저녁', '도심', '노을', '동산', '장소'],
#  ['파티', '공기', '맑은'],
#  ['주방', '우드', '심플', '거실', '아이방', '화이트', '감성', '미니', '침실', '원목'],
#  ['주차장', '한국', '전통'],
#  ['한강', '리스트', '주변', '화이트', '미니'],
#  ['한강', '리스트', '주변', '화이트', '미니'],
#  ['네추럴', '코지', '심플', '유러'],
#  ['하우스', '전망', '주방', '츄럴', '거실', '시공간', '아이방', '채광', '미니'],
#  ['대나무', '노출', '원목'],
#  ['위치', '가정', '아파트', '녹번'],
#  ['아파트', '베란다', '놀이터', '쇼파'],
#  ['강아지', '농가', '모델링', '주택', '촬영', '나무', '시골'],
#  ['농장', '매실', '보은', '마당', '잔디', '시크릿'],
#  ['모던', '쿠킹', '천장', '미니'],
#  ['모던', '쿠킹', '천장', '미니'],
#  ['타워', '디제이', '클럽', '지하', '주차'],
#  ['테라스', '주택', '노출', '유리', '모던', '가정', '코지', '계단'],
#  ['아파트', '주택', '다가', '구조'],
#  ['골목', '카페', '아늑', '촬영', '모임', '소규모', '다다', '독서', '대관'],
#  ['다락방', '아파트', '테라스'],
#  ['아파트', '소형', '단국대', '근처'],
#  ['유리', '단독', '연희동', '옥상'],
#  ['단독', '유럽', '주택', '판교'],
#  ['케이', '터링', '비용', '파티', '사용', '촬영', '단독', '쇼핑몰', '공간', '장소'],
#  ['화보', '자연', '강남', '옥상'],
#  ['화보', '자연', '강남', '정원'],
#  ['마당', '잔디', '루프', '수영장', '다이닝', '정원'],
#  ['마당', '잔디', '루프', '수영장', '다이닝', '정원'],
#  ['위치',
#   '내관',
#   '주택',
#   '지상',
#   '느낌',
#   '마당',
#   '외관',
#   '럭셔리',
#   '지하',
#   '모던',
#   '촬영',
#   '단독',
#   '파주',
#   '이용'],
#  ['위치',
#   '내관',
#   '주택',
#   '지상',
#   '느낌',
#   '마당',
#   '외관',
#   '럭셔리',
#   '지하',
#   '모던',
#   '촬영',
#   '단독',
#   '파주',
#   '이용'],
#  ['장식', '단독주택', '느낌', '제작', '실내', '예약', '유지'],
#  ['장식', '단독주택', '느낌', '제작', '실내', '예약', '유지'],
#  ['주택', '안개', '장수군', '산속', '공간'],
#  ['마을', '텃밭', '시골', '마당'],
#  ['마을', '텃밭', '시골', '마당'],
#  ['위치',
#   '하우스',
#   '내관',
#   '주택',
#   '지상',
#   '모델',
#   '느낌',
#   '외관',
#   '럭셔리',
#   '지하',
#   '모던',
#   '단독',
#   '파주'],
#  ['빈티', '망원동', '화이트'],
#  ['단독주택', '위치', '마당', '외관', '언제', '촬영', '대구'],
#  ['단독주택',
#   '여름',
#   '신도시',
#   '잔디',
#   '인천공항',
#   '소나무',
#   '초록',
#   '벽돌',
#   '보이',
#   '매력',
#   '창문',
#   '겨울',
#   '몽돌',
#   '중정'],
#  ['단독주택',
#   '여름',
#   '신도시',
#   '잔디',
#   '인천공항',
#   '소나무',
#   '초록',
#   '벽돌',
#   '보이',
#   '매력',
#   '창문',
#   '겨울',
#   '몽돌',
#   '중정'],
#  ['빈티', '화보', '자연', '강남', '정원'],
#  ['대들보', '잔디', '야외', '촬영', '정성', '고삼', '감나무', '저수지'],
#  ['대들보', '잔디', '야외', '촬영', '정성', '고삼', '감나무', '저수지'],
#  ['주방', '촬영', '분위기', '채광'],
#  ['마당', '거실', '촬영'],
#  ['광고', '북한', '뉴타운', '산정', '마을', '진관동', '은평'],
#  ['촬영', '자연', '공간'],
#  ['강변', '숲속', '단양', '의정원'],
#  ['강변', '숲속', '단양', '의정원'],
#  ['별장', '독채', '잔디', '펜션', '서울', '수영장', '정원'],
#  ['한식당', '식당', '단체', '모임', '대형'],
#  ['회식', '술집', '홍대', '데이트', '분위기'],
#  ['삼거리',
#   '상호',
#   '경희대',
#   '애니',
#   '완비',
#   '사용',
#   '중대',
#   '음료',
#   '대대',
#   '구장',
#   '휴식',
#   '가능',
#   '공간',
#   '장소',
#   '흡연실',
#   '협의'],
#  ['화장실', '사무실', '단기', '채광'],
#  ['연말', '파티', '카페', '촬영', '파주', '쇼핑몰', '감성', '대관'],
#  ['대여', '파티', '촬영', '동성로', '요리'],
#  ['대여', '파티', '촬영', '동성로', '요리'],
#  ['브라', '주택', '파티', '클래스', '원데이', '모임', '화이트', '대구'],
#  ['두산동', '주택', '언제', '촬영', '대구'],
#  ['아파트', '주방', '안방', '거실', '아이방', '대전'],
#  ['노은동', '전시', '아파트', '유성구'],
#  ['돌담', '제주', '시골'],
#  ['혜화역',
#   '위치',
#   '병원',
#   '교통',
#   '마로니에',
#   '성균관대',
#   '길이',
#   '주차',
#   '촬영',
#   '인접',
#   '학교',
#   '서울대',
#   '공원',
#   '주변',
#   '근처',
#   '성곽',
#   '창경궁'],
#  ['촬영', '학동', '사거리', '서비스'],
#  ['작업실', '음향', '사운드'],
#  ['커뮤니티', '운동', '장소', '댄스'],
#  ['영상', '댄스', '촬영', '연습', '연습실', '안무', '대관'],
#  ['영상', '댄스', '촬영', '연습', '연습실', '안무', '대관'],
#  ['술집', '카페', '아지트', '맥주', '데이트', '분위기'],
#  ['바베큐', '벽난로', '마당', '소나무', '정원', '데크'],
#  ['데크', '빌라', '고급'],
#  ['테라스', '한국', '주차', '가구', '정원', '전통', '도보'],
#  ['아파트', '우드', '신축', '화이트'],
#  ['독신남', '빈집', '복합', '마포', '공덕', '주상'],
#  ['빈티', '독일', '건축가', '가구', '화이트', '미니', '블랙'],
#  ['내부',
#   '오후',
#   '주택',
#   '선호',
#   '햇살',
#   '지하',
#   '분리',
#   '거주',
#   '공간',
#   '형식',
#   '남향',
#   '오전',
#   '계단'],
#  ['카페', '유럽', '연희동'],
#  ['모델링', '사용', '한참', '사무실', '철거', '다른', '분위기', '공간', '반쪽', '활용'],
#  ['가득', '거실', '촬영', '공간', '컬러', '원목'],
#  ['돌담', '카페', '제주', '과수원', '인근', '마을', '감귤'],
#  ['대여', '아파트', '원룸', '동대문', '촬영', '공간', '대관'],
#  ['화공', '빈티', '하우스', '벽돌', '침대', '테이블'],
#  ['카페나', '본교', '전원주택', '동덕여자대', '인근', '원룸', '학교', '분위기', '옵션', '제일'],
#  ['보유', '전경', '카페', '평일', '해변', '촬영', '자랑', '이용', '건물'],
#  ['빈티', '차고', '마당', '미국', '고동', '이태원', '동빙', '경리'],
#  ['스타일', '올리브', '아치', '중문', '나무', '프렌치', '조명', '소품', '햇살', '욕실', '판교'],
#  ['스타일', '올리브', '아치', '중문', '나무', '프렌치', '조명', '소품', '햇살', '욕실', '판교'],
#  ['한식당', '남자', '모두', '드림', '영통', '행복', '맛집', '쭈꾸미'],
#  ['회식', '술집', '홍대', '장소', '촬영', '모임', '드라마', '분위기', '대관', '사격장'],
#  ['회식', '술집', '홍대', '장소', '촬영', '모임', '드라마', '분위기', '대관', '사격장'],
#  ['정원', '촬영', '드라마', '영화', '대관'],
#  ['빈티', '영화', '유럽', '드라마', '잡지'],
#  ['전문', '신촌', '홍대', '입구', '촬영', '튜버', '유튜버', '드라마'],
#  ['시야', '마음', '주변', '주중', '햇볕', '제외', '광릉', '이용', '왕숙천', '수목원'],
#  ['빈티', '디자인', '공구', '가구', '목공', '기계'],
#  ['내부',
#   '호선',
#   '사용',
#   '주말',
#   '결제',
#   '압구정역',
#   '조율',
#   '도보',
#   '인테리어',
#   '최소',
#   '스케쥴',
#   '공휴일',
#   '모던',
#   '예약',
#   '회사',
#   '사무실',
#   '가능',
#   '시간',
#   '협의',
#   '디자인',
#   '이상',
#   '대관'],
#  ['모던', '소호', '사무실', '디자인'],
#  ['북카페', '사무실', '디자인'],
#  ['디자인', '갤러리', '문구', '모임', '시공간', '공간', '소품'],
#  ['규어', '디자인', '사무실'],
#  ['디자인', '체어', '가구', '오디오', '디터람스', '리지'],
#  ['위치', '디제잉', '뱅뱅', '부근', '양재', '사거리', '연습실', '강남역'],
#  ['위치', '디제잉', '뱅뱅', '부근', '양재', '사거리', '연습실', '강남역'],
#  ['일반', '온화', '가족', '평범'],
#  ['채광', '카페', '모던', '공간'],
#  ['경북', '축복', '행복', '호스트', '대구'],
#  ['연출',
#   '위치',
#   '뮤직비디오',
#   '호선',
#   '아파트',
#   '주방',
#   '마케팅',
#   '영상',
#   '제품',
#   '주말',
#   '브라운',
#   '특징',
#   '말씀',
#   '최근',
#   '원목',
#   '광고',
#   '인테리어',
#   '화랑대역',
#   '바이럴',
#   '소개',
#   '거실',
#   '듭니',
#   '서울',
#   '유명',
#   '시공',
#   '미리',
#   '장소',
#   '항시',
#   '대의',
#   '느낌',
#   '동향',
#   '지하',
#   '뉴스',
#   '촬영',
#   '초반',
#   '자연',
#   '분위기',
#   '시간',
#   '하나',
#   '잡지',
#   '진행',
#   '단편영화',
#   '협의',
#   '생각',
#   '주차',
#   '에스',
#   '저희'],
#  ['연출',
#   '위치',
#   '뮤직비디오',
#   '호선',
#   '아파트',
#   '주방',
#   '마케팅',
#   '영상',
#   '제품',
#   '주말',
#   '브라운',
#   '특징',
#   '말씀',
#   '최근',
#   '원목',
#   '광고',
#   '인테리어',
#   '화랑대역',
#   '바이럴',
#   '소개',
#   '거실',
#   '듭니',
#   '서울',
#   '유명',
#   '시공',
#   '미리',
#   '장소',
#   '항시',
#   '대의',
#   '느낌',
#   '동향',
#   '지하',
#   '뉴스',
#   '촬영',
#   '초반',
#   '자연',
#   '분위기',
#   '시간',
#   '하나',
#   '잡지',
#   '진행',
#   '단편영화',
#   '협의',
#   '생각',
#   '주차',
#   '에스',
#   '저희'],
#  ['조정', '느낌', '집월', '시간', '협의'],
#  ['위치', '동대문'],
#  ['떡볶이', '시설', '키카', '카페', '놀이터', '실내', '키즈', '영유', '베이비', '볶음밥', '영어'],
#  ['술집', '파티', '라운지', '분위기', '힙합', '와인', '트렌디'],
#  ['술집', '파티', '라운지', '분위기', '힙합', '와인', '트렌디'],
#  ['가구', '강릉', '촬영'],
#  ['소품', '인테리어', '화이트'],
#  ['편리',
#   '모두',
#   '주말',
#   '서재',
#   '공간',
#   '소품',
#   '주차장',
#   '평일',
#   '가정',
#   '선호',
#   '지하',
#   '촬영',
#   '가능',
#   '하나',
#   '부부',
#   '침실',
#   '국적',
#   '가구',
#   '주차',
#   '사진'],
#  ['편리',
#   '모두',
#   '주말',
#   '서재',
#   '공간',
#   '소품',
#   '주차장',
#   '평일',
#   '가정',
#   '선호',
#   '지하',
#   '촬영',
#   '가능',
#   '하나',
#   '부부',
#   '침실',
#   '국적',
#   '가구',
#   '주차',
#   '사진'],
#  ['럭셔리', '자연', '화장실', '채광', '욕실'],
#  ['럭셔리', '자연', '화장실', '채광', '욕실'],
#  ['하우스', '럭셔리', '모던', '화이트', '공간', '블랙'],
#  ['하우스', '럭셔리', '모던', '화이트', '공간', '블랙'],
#  ['주니', '블럭', '주니어', '버스', '카페', '벌집', '레고'],
#  ['오늘',
#   '자꾸',
#   '스타워즈',
#   '때문',
#   '가게',
#   '레로',
#   '공간',
#   '날때',
#   '상태',
#   '아이',
#   '정리',
#   '올린다',
#   '레고',
#   '거의',
#   '헤리포터',
#   '전시',
#   '생각',
#   '사진',
#   '시리즈',
#   '보시',
#   '취미'],
#  ['모두', '영업', '이외', '촬영', '시간', '목요일', '휴무'],
#  ['빈티', '레고', '카페'],
#  ['밸리', '위스키', '와인', '테크노', '판교'],
#  ['대여', '삼성동', '공간', '코엑스'],
#  ['영상', '렌탈', '대여', '촬영', '레이', '공간'],
#  ['영상', '렌탈', '대여', '촬영', '레이', '공간'],
#  ['영상', '렌탈', '대여', '촬영', '레이', '공간'],
#  ['영상', '렌탈', '대여', '촬영', '레이', '공간'],
#  ['레트로', '가구', '자개'],
#  ['빈티', '주택', '촬영', '소품'],
#  ['복도', '레트로', '빈티', '옥상', '주택', '모델링', '주방', '아이방', '다가'],
#  ['모던', '레트로', '하우스', '미니'],
#  ['렌탈', '영상', '남양주', '사진', '자연', '창고', '호리'],
#  ['존트', '사진', '호리'],
#  ['렌탈', '대여', '제품', '생일', '파티', '의류', '촬영', '서울', '공간', '대관', '장소', '명동'],
#  ['렌탈', '대여', '서울숲'],
#  ['렌탈', '대여', '성수동', '서울숲'],
#  ['렌탈', '자연', '성수동', '쇼핑몰'],
#  ['렌탈', '대여', '성수동'],
#  ['렌탈', '성수동', '서울숲'],
#  ['렌탈', '성수동', '서울숲'],
#  ['렌탈', '주방', '자연', '성수동', '쇼핑몰'],
#  ['렌탈', '촬영', '자연', '셀프', '쇼핑몰'],
#  ['신당동', '촬영', '공간'],
#  ['렌탈', '영상', '서초', '사당', '모델', '방배', '촬영', '셀프', '강남', '쇼핑몰'],
#  ['렌탈', '영상', '촬영', '자연', '호리', '쇼핑몰'],
#  ['렌탈', '패션', '셀프', '사진관', '호리', '쇼핑몰', '원주'],
#  ['렌탈', '대여', '마켓', '블로그', '촬영', '이벤트', '쇼핑몰', '공간', '대관'],
#  ['렌탈', '대여', '촬영', '자연', '관문', '강남', '대관'],
#  ['렌탈', '영상', '압구정', '촬영'],
#  ['렌탈', '촬영', '자연', '연희동'],
#  ['렌탈', '자연', '연희동', '정원'],
#  ['렌탈', '자연', '연희동', '정원'],
#  ['렌탈', '자연', '연희동', '정원'],
#  ['렌탈', '자연', '연희동', '정원'],
#  ['렌탈', '촬영', '자연', '강남', '채광', '논현동'],
#  ['렌탈', '영상', '침실', '거실', '자연', '욕실'],
#  ['렌탈', '한남동', '촬영', '자연', '쇼핑몰'],
#  ['렌탈', '촬영', '패션', '서울', '자연', '쇼핑몰', '채광'],
#  ['영상', '루프', '촬영'],
#  ['렌탈', '마켓', '블로그', '촬영', '서울', '쇼핑몰'],
#  ['렌탈', '홍대', '우드', '자연', '셀프', '서울', '광렌탈'],
#  ['렌탈', '주방', '자연', '성수동'],
#  ['렌탈', '대여', '파티', '촬영', '자연', '공간', '광흥창'],
#  ['렌탈', '대여', '파티', '촬영', '자연', '공간', '광흥창'],
#  ['대여', '촬영', '모임', '자연', '공간'],
#  ['렌탈', '홍대', '합정', '촬영', '호리'],
#  ['촬영장', '섭외', '대여', '장소', '촬영', '협찬', '대관'],
#  ['촬영장', '섭외', '대여', '장소', '촬영', '협찬', '대관'],
#  ['스타일', '한남동', '로프트', '빈티'],
#  ['타워', '테라스', '작업실', '롯데'],
#  ['한센', '루이스', '가구', '자연', '수입', '화이트', '리츠', '주의'],
#  ['연남동', '베이지', '촬영', '옥상'],
#  ['연남동', '베이지', '촬영', '옥상'],
#  ['게스트하우스', '루프', '자연', '프로필', '강남', '옥탑', '대관'],
#  ['옥상', '파티', '치맥', '야경', '루프', '모임', '용산구', '서울역', '옥탑', '남산'],
#  ['바베큐', '영상', '촬영', '옥탑방', '옥탑'],
#  ['유튜브', '광고', '파티', '루프', '모임', '촬영', '영화'],
#  ['루프', '성곽', '낙산'],
#  ['루프', '강남', '압구정', '신사동'],
#  ['루프'],
#  ['홍대', '연남동', '루프', '촬영', '옥탑방', '옥상'],
#  ['파티', '홍대', '한강', '루프', '옥탑바', '고양이'],
#  ['파티', '홍대', '한강', '루프', '옥탑바', '고양이'],
#  ['바베큐', '테라스', '주방', '호텔', '루프', '모던', '쿠킹', '신혼집', '요리'],
#  ['바베큐', '테라스', '주방', '호텔', '루프', '모던', '쿠킹', '신혼집', '요리'],
#  ['파티', '루프', '행사', '촬영', '쇼핑몰', '왕십리', '대관', '전시회'],
#  ['파티', '루프', '행사', '촬영', '쇼핑몰', '왕십리', '대관', '전시회'],
#  ['모델링', '동네', '화분', '아이', '화이트'],
#  ['하우스', '온천', '팬션겸'],
#  ['주거', '기분', '콘도', '리조트'],
#  ['카페', '플라워', '테리어'],
#  ['상수', '하우스', '테라스', '마당', '게스트하우스', '홍대', '쉐어', '정원'],
#  ['마당', '루프', '가능', '공간'],
#  ['내부',
#   '국내',
#   '전원주택',
#   '유럽',
#   '직접',
#   '서재',
#   '영화',
#   '인테리어',
#   '엔틱',
#   '방송사',
#   '경우',
#   '제약',
#   '품격',
#   '설치',
#   '거실',
#   '여러',
#   '주변',
#   '다수',
#   '구성',
#   '유명',
#   '대형',
#   '특성',
#   '이용',
#   '그릴',
#   '주간',
#   '가스',
#   '단지',
#   '야외',
#   '촬영',
#   '소음',
#   '드라마',
#   '시간',
#   '침실',
#   '엤으',
#   '전망',
#   '테라스',
#   '발생',
#   '주택',
#   '가구',
#   '도심',
#   '컨텐츠',
#   '컨셉',
#   '활용'],
#  ['주차장', '벽난로', '마당', '조경', '잔디', '정원', '앤티크'],
#  ['평일', '수금', '선호'],
#  ['다락방', '테라스', '정원'],
#  ['스트리트', '무료', '트리플', '주차', '갈비찜', '시간', '송도', '운영', '현대'],
#  ['카페', '심플', '모던', '신혼집', '마포구'],
#  ['공덕역', '모던', '가정', '아이방', '그레이'],
#  ['오후', '인테리어', '카페', '평일', '선호', '만화카페', '주말', '제외', '스터디', '오전'],
#  ['주방', '이케아', '자연', '주의'],
#  ['생활',
#   '시설',
#   '언제',
#   '망원',
#   '공간',
#   '처음',
#   '아지트',
#   '와중',
#   '부공',
#   '직장',
#   '장소',
#   '변경',
#   '모임',
#   '초점',
#   '개인',
#   '상업',
#   '옥탑',
#   '스타트업',
#   '운영'],
#  ['인테리어', '클래식', '감성', '느낌', '유럽', '매장', '촬영', '오토바이', '전시'],
#  ['위치',
#   '언제',
#   '국제',
#   '루프',
#   '영화',
#   '공간',
#   '외부',
#   '개방',
#   '환영',
#   '무척',
#   '설치',
#   '소가',
#   '호프',
#   '촬영장',
#   '강서구',
#   '신도시',
#   '실내',
#   '부산',
#   '실외'],
#  ['카페', '느낌', '호텔', '분위기', '화이트', '감성'],
#  ['주방', '마당', '공간'],
#  ['식물', '메인', '모던', '신혼집', '네이버', '그레이'],
#  ['주방', '주택', '싱글', '거실', '모던', '빌라', '가정', '신혼집', '옥상', '침실'],
#  ['모던', '미니', '심플', '화이트'],
#  ['북유럽', '심플', '모던', '복합', '주상', '화이트'],
#  ['모던', '일산', '브런치', '카페'],
#  ['테라스', '키친', '모던', '오픈'],
#  ['촬영장', '사용', '소로', '분당', '부부'],
#  ['주방', '자연', '화이트'],
#  ['테라스', '내추럴', '모던', '복층', '별내'],
#  ['모던', '신혼집', '내추럴', '소박'],
#  ['스타일', '아파트', '강조', '모던', '원목'],
#  ['스타일', '아파트', '강조', '모던', '원목'],
#  ['스타일', '아파트', '강조', '모던', '원목'],
#  ['전망', '심플', '모던', '고급', '신혼집'],
#  ['하우스', '전망', '화이트하우스', '가구', '모던', '분당', '화이트', '클레', '판교'],
#  ['하우스', '전망', '화이트하우스', '가구', '모던', '분당', '화이트', '클레', '판교'],
#  ['아파트',
#   '사용',
#   '한강',
#   '주말',
#   '스튜디오',
#   '최근',
#   '인테리어',
#   '최소',
#   '불로',
#   '거실',
#   '공원',
#   '페인트',
#   '촬영',
#   '식탁',
#   '컬러',
#   '호텔',
#   '가구',
#   '잠실',
#   '조명',
#   '공사'],
#  ['식당', '모던', '촬영'],
#  ['처럼', '아파트', '모두', '공간', '일상'],
#  ['서초', '방배', '강남'],
#  ['제품',
#   '주방',
#   '아파트',
#   '언제',
#   '포터',
#   '서재',
#   '소품',
#   '구조',
#   '인테리어',
#   '특유',
#   '가정',
#   '감성',
#   '느낌',
#   '드레스',
#   '공유',
#   '예약',
#   '분위기',
#   '침실',
#   '대부분',
#   '리반',
#   '가구',
#   '신혼',
#   '활용'],
#  ['파티', '장소', '모임', '스터디'],
#  ['스냅샷', '인더스트리얼', '포토', '공간'],
#  ['스냅샷', '인더스트리얼', '포토', '공간'],
#  ['영상', '합정역', '촬영', '모임', '공간'],
#  ['위치',
#   '파티',
#   '게스트',
#   '수용',
#   '최대한',
#   '타인',
#   '독립',
#   '공간',
#   '여우',
#   '모텔',
#   '회식',
#   '생일',
#   '평일',
#   '경우',
#   '처녀파티',
#   '강북구',
#   '서울',
#   '인근',
#   '야외',
#   '수유역',
#   '시선',
#   '의식',
#   '내용',
#   '바베큐',
#   '테라스',
#   '총각파티',
#   '용인'],
#  ['카페', '청주', '문의', '주시', '일정', '공예', '조율', '외곽', '전화'],
#  ['목포', '빈티', '친구', '주방', '연인', '쓰기', '옛날', '뉴트', '모임', '가족', '장소'],
#  ['화보', '무드', '키즈', '피크닉', '정원'],
#  ['고읍동', '오후', '무역', '양주시', '원단', '부터', '회사', '시간', '경기도', '선호'],
#  ['영상', '렌탈', '촬영', '자연', '상업', '대구'],
#  ['편안함', '쇼파', '원목'],
#  ['클래식', '심플', '모던', '로맨틱', '미니', '일상'],
#  ['심플', '화이트', '미니'],
#  ['홍대', '심플', '합정', '모던', '루프', '화이트', '미니'],
#  ['라이프', '이천', '복합', '대기실', '아이방', '배우', '주상', '미니'],
#  ['옥상', '주택', '복층'],
#  ['모던', '티비', '동네', '심플'],
#  ['빈티', '브라', '생일', '파티', '샤워', '일산', '모임', '미드', '소규모'],
#  ['빈티', '브라', '생일', '파티', '샤워', '일산', '모임', '미드', '소규모'],
#  ['대리석', '미술', '학원', '모던', '아동', '화이트', '교실', '전시'],
#  ['상반',
#   '대기실',
#   '화이트',
#   '공간',
#   '경기',
#   '개성',
#   '빈티',
#   '인테리어',
#   '에폭시',
#   '바닥',
#   '소개',
#   '다수',
#   '시공',
#   '스타일',
#   '영통구',
#   '프레',
#   '매칭',
#   '분위기',
#   '바깥',
#   '컬러',
#   '집닥',
#   '사이트',
#   '수원시',
#   '스카',
#   '베이스'],
#  ['대안', '우드', '합정', '자연', '망원', '화이트', '민트', '공간'],
#  ['옥상', '펜션', '빌라'],
#  ['낚시', '웨딩', '클래식', '캠핑', '야외', '바다', '수영장', '노을', '정원', '감성'],
#  ['낚시', '웨딩', '클래식', '캠핑', '야외', '바다', '수영장', '노을', '정원', '감성'],
#  ['흰여울', '카페', '바다', '마을'],
#  ['스타일', '아파트', '게스트하우스', '바다', '해운대', '프렌치', '신혼집', '가족', '근처'],
#  ['아파트', '일요일', '제외', '바다', '다대포항', '예약', '근처', '남향'],
#  ['숙대',
#   '내부',
#   '바베큐',
#   '빌딩',
#   '테라스',
#   '주택',
#   '옥탑',
#   '주차',
#   '나무',
#   '옥탑방',
#   '연결',
#   '재미',
#   '삼각지',
#   '서울역',
#   '사인',
#   '다가',
#   '개방',
#   '계단'],
#  ['모던', '하우스', '가족'],
#  ['위치',
#   '시작',
#   '빌라',
#   '샘플',
#   '구조',
#   '해당',
#   '운정',
#   '신축',
#   '경기도',
#   '반려동물',
#   '오픈',
#   '장소',
#   '전용',
#   '반려견',
#   '하우스',
#   '분양',
#   '촬영',
#   '시간',
#   '신도시',
#   '이제',
#   '사진',
#   '이구',
#   '파주'],
#  ['지층', '자취', '원룸', '혼자', '부엌'],
#  ['생활', '단편', '반지하', '서울', '허름', '투룸'],
#  ['장기', '허름', '원룸', '선풍기', '창문', '반지하'],
#  ['아파트', '전망', '울주군', '신축', '소재', '울산'],
#  ['키즈', '방이', '옛날', '카페'],
#  ['방배동', '아파트', '빌라', '큰집', '앤티크'],
#  ['촬영', '공간', '연습실'],
#  ['방배역', '공간', '연습실'],
#  ['사당역', '방배역', '사당', '방배', '촬영', '서울', '공간', '연습실', '대관', '상문고'],
#  ['사당', '지상', '방배', '단독', '연습실'],
#  ['광고', '비대', '촬영', '방송', '콘서트'],
#  ['촬영', '방송', '호리', '공간'],
#  ['유튜브', '화보', '촬영', '방송', '쇼핑몰'],
#  ['유튜브', '파티', '촬영', '신사역'],
#  ['연습실', '유튜버', '녹음실', '방음'],
#  ['호수', '카페', '베이비'],
#  ['별장', '촬영장', '렌탈', '파티', '펜션', '협찬', '촬영', '이색', '장소'],
#  ['병원', '상담', '진료', '데스크', '안내'],
#  ['레트로', '벽난로', '고풍', '복고', '계단'],
#  ['레트로', '벽난로', '고풍', '복고', '계단'],
#  ['유럽', '프랑스', '카페'],
#  ['마당', '주택', '바다', '복층', '정원'],
#  ['영상', '피아노', '신혼집', '복층', '대학생', '여자'],
#  ['영상', '피아노', '신혼집', '복층', '대학생', '여자'],
#  ['호수', '일산', '공원', '복층', '침실', '장항동'],
#  ['양재역', '복층', '정도', '오피스텔', '강남역'],
#  ['진접', '남양주'],
#  ['연출',
#   '타운하우스',
#   '인천공항',
#   '복층',
#   '조율',
#   '주로',
#   '다락방',
#   '문의',
#   '운서역',
#   '인근',
#   '시간대',
#   '주시',
#   '저녁',
#   '옥상',
#   '계단',
#   '테라스',
#   '복층집',
#   '타임',
#   '대관'],
#  ['테라스', '빌라', '복층', '근처', '야당'],
#  ['용문', '빌라', '양평', '복층'],
#  ['조명', '신축', '복층', '채광', '오피스텔', '건물'],
#  ['북유럽', '디자인', '자취', '혼사', '화이트', '소품', '복층'],
#  ['복층', '주방', '주택', '우드', '아이방', '화이트', '컨셉'],
#  ['테라스', '아이방', '샹들리'],
#  ['가정', '아이방', '부부', '침실'],
#  ['파티', '클럽', '부산', '힙합', '동양'],
#  ['아파트', '심플', '부산', '모던'],
#  ['부산', '해운대', '모던'],
#  ['테라스', '카페', '야경', '부산', '촬영', '자연', '분위기'],
#  ['대리석', '부엌', '촬영', '그레이'],
#  ['대리석', '부엌', '촬영', '그레이'],
#  ['위치',
#   '영상',
#   '호선',
#   '시설',
#   '사용',
#   '스튜디오',
#   '공간',
#   '도보',
#   '세미나',
#   '목적',
#   '이마트',
#   '강의',
#   '게임',
#   '주변',
#   '테이블',
#   '마트',
#   '거리',
#   '촬영',
#   '모임',
#   '편의',
#   '편의점',
#   '사진',
#   '미터',
#   '농협',
#   '이벤트',
#   '다이소',
#   '소파'],
#  ['소사동', '대여', '부천', '카페'],
#  ['부티', '호텔', '촬영', '선정릉'],
#  ['할머니', '아가', '대가', '여사', '배기', '부부'],
#  ['북유럽', '빈티', '디자인', '오리'],
#  ['북유럽', '빈티', '가구', '햇살'],
#  ['주차장',
#   '위치',
#   '복도',
#   '툇마루',
#   '주방',
#   '하나은행',
#   '마당',
#   '객실',
#   '경우',
#   '이야기',
#   '도문',
#   '거실',
#   '제공',
#   '지점',
#   '공간',
#   '안국동',
#   '욕실'],
#  ['사용', '하루', '사무실', '서재'],
#  ['제품', '화장품', '오리역', '촬영', '소호', '분당', '오피스'],
#  ['촬영', '분당', '아이', '화이트', '소품'],
#  ['분리', '주방', '원룸'],
#  ['인천', '카페', '브런치'],
#  ['위치',
#   '보드',
#   '용도',
#   '설치',
#   '스크린',
#   '거실',
#   '테이블',
#   '라운지',
#   '서울',
#   '미터',
#   '분위기',
#   '수동',
#   '복층',
#   '마포구',
#   '와인'],
#  ['브라', '대여', '생일', '파티', '샤워'],
#  ['홍대', '브라', '렌탈', '샤워'],
#  ['남자', '혼자'],
#  ['아파트',
#   '때문',
#   '모두',
#   '우드',
#   '메인',
#   '주말',
#   '마루',
#   '화이트',
#   '정원',
#   '인테리어',
#   '경우',
#   '평일',
#   '바닥',
#   '거실',
#   '집앞',
#   '고려',
#   '형제',
#   '아이',
#   '간접',
#   '구성',
#   '화장실',
#   '사전',
#   '선호',
#   '그레이',
#   '백열전구',
#   '느낌',
#   '안방',
#   '학원',
#   '촬영',
#   '웜하',
#   '자연',
#   '시간',
#   '전체',
#   '블랙',
#   '협의',
#   '대부분',
#   '티비',
#   '부분',
#   '기반',
#   '이구',
#   '학교',
#   '조명'],
#  ['일산', '화이트', '레드', '블랙'],
#  ['호수', '자주', '호텔', '동네', '노캄', '한류월드', '촬영', '인접', '공원'],
#  ['장점', '가게', '변신', '공간', '소품', '활용'],
#  ['조금', '한쪽', '빈방', '낙서', '벽면'],
#  ['사무실'],
#  ['아파트', '빈집', '촬영', '소형', '장소'],
#  ['전세', '모델링', '빈집', '만료', '그대로', '촬영', '이구', '계약', '제목'],
#  ['인테리어', '가구', '가전'],
#  ['빈티', '게스트하우스', '홍대'],
#  ['빈티', '레트로', '파티', '인더스트리얼', '올드'],
#  ['빈티', '레트로', '파티', '인더스트리얼', '올드'],
#  ['제품',
#   '방서',
#   '참고',
#   '브랜드',
#   '피아노',
#   '소품',
#   '환영',
#   '빈티',
#   '어서',
#   '공존',
#   '드릴',
#   '사이',
#   '모던',
#   '소방',
#   '촬영',
#   '디지털',
#   '비숑',
#   '하나',
#   '도움',
#   '가구',
#   '활용'],
#  ['반지하', '이태원', '카페'],
#  ['빈티', '스타일', '카페', '느낌', '게스트하우스'],
#  ['빈티', '레트로', '아늑', '홍대', '자취', '합정', '가정', '망원', '마포구'],
#  ['화보', '댄스', '촬영', '커버', '대형'],
#  ['화보', '댄스', '촬영', '커버', '대형'],
#  ['다락방', '빈티', '홈바', '옥상'],
#  ['안산', '원룸', '프렌치', '자연', '프랑스'],
#  ['빈티', '음식', '촬영', '요리'],
#  ['빈티', '레트로', '촬영'],
#  ['주차장', '프리', '자동차', '매장', '요일', '촬영', '페인팅', '시간', '장사'],
#  ['배경',
#   '아트',
#   '화이트',
#   '소품',
#   '남향',
#   '원목',
#   '빈티',
#   '인테리어',
#   '고가',
#   '가림',
#   '프랑스',
#   '대형',
#   '테이블',
#   '프린트',
#   '대여',
#   '촬영',
#   '오브',
#   '화병',
#   '프레임',
#   '도움',
#   '가구'],
#  ['위치',
#   '호선',
#   '지상',
#   '사항',
#   '수용',
#   '가산동',
#   '트리니티',
#   '내외',
#   '카페',
#   '지하철',
#   '문의',
#   '서울',
#   '오전',
#   '공휴일',
#   '지하',
#   '차량',
#   '저녁',
#   '금천구',
#   '전체',
#   '블랙',
#   '요청',
#   '주차',
#   '기타',
#   '대관'],
#  ['빈티', '정원', '소품'],
#  ['리얼', '남매', '모두', '빌라', '현실', '주말', '주중', '선호'],
#  ['빌라', '채광', '원목'],
#  ['빌라', '채광', '원목'],
#  ['거실', '피아노', '화장실', '침실'],
#  ['카페', '실내', '정원'],
#  ['기본', '아파트'],
#  ['주택', '심플', '제주도', '모던', '신혼집', '신축', '사계절'],
#  ['사당역', '스터디', '사당', '카페'],
#  ['사당역', '스터디', '사당', '카페'],
#  ['공연', '촬영', '더킹', '공간', '연습실'],
#  ['사당', '공간', '연습실'],
#  ['사당역', '사당', '연습실'],
#  ['사당역', '알파', '촬영', '공간', '연습실'],
#  ['골드', '촬영', '공간', '연습실'],
#  ['사당', '이수', '방배', '보컬', '연습실'],
#  ['이수', '옐로우', '공간', '블랙'],
#  ['이수역', '사당', '이수', '화이트', '공간', '연습실'],
#  ['사당역', '골드', '댄스', '연습실'],
#  ['사당역', '사당', '공간', '연습실'],
#  ['사당역', '레드윙', '공간', '연습실'],
#  ['사당역', '촬영', '공간', '연습실'],
#  ['사당역', '뜰리', '공간', '연습실'],
#  ['사당역', '앨런', '공간', '연습실'],
#  ['아트리', '사당역', '사당', '댄스', '연습실'],
#  ['사당역', '사당', '댄스', '연습실'],
#  ['사당', '공간', '연습실'],
#  ['사당', '호프만', '공간'],
#  ['골드', '연습실', '촬영', '사당동', '공간'],
#  ['키스', '옐로우', '연습실', '공간'],
#  ['트리', '사당역', '핑크', '남성역', '사당', '이수', '연습실', '촬영', '사당동', '공간', '이수역', '대관'],
#  ['옐로우', '촬영', '공간', '이수역', '대관'],
#  ['사당', '이수', '연습실', '공간', '이수역'],
#  ['연습실', '공간', '이수역', '출구'],
#  ['방배동', '사당', '방배', '연습실', '공간'],
#  ['방배동', '사당', '방배', '연습실', '공간'],
#  ['방배동', '사당', '방배', '연습실', '촬영'],
#  ['시공사',
#   '건축',
#   '사용',
#   '언제',
#   '주차공간',
#   '편리',
#   '사진',
#   '촬영',
#   '배치',
#   '파티션',
#   '사무실',
#   '관음죽',
#   '장소'],
#  ['일반',
#   '필요',
#   '퇴근',
#   '부서',
#   '문의',
#   '분당',
#   '선호',
#   '관리',
#   '촬영',
#   '사무실',
#   '가능',
#   '전체',
#   '시간',
#   '실무',
#   '협의',
#   '부분',
#   '면적',
#   '오후',
#   '이후',
#   '직원',
#   '카페테리아'],
#  ['돌담', '위치', '덕수궁', '사무실'],
#  ['사무실', '오피스', '강남', '드라마'],
#  ['카페', '교육장', '사무실'],
#  ['사무소', '디자인', '그림', '사무실'],
#  ['회의실', '사무실', '회사', '서재'],
#  ['위치', '전망', '포스코', '삼성동', '사거리', '코엑스', '오피스텔'],
#  ['임원', '회의실', '상담', '사무실', '오피스'],
#  ['휴일',
#   '요망',
#   '전망',
#   '사용',
#   '평일',
#   '한강',
#   '창밖',
#   '상담',
#   '사무실',
#   '소규모',
#   '분위기',
#   '기준',
#   '사전'],
#  ['위치',
#   '송파구',
#   '법조',
#   '인테리어',
#   '전망',
#   '타운',
#   '경우',
#   '평일',
#   '드릴',
#   '편입',
#   '부득이',
#   '주말',
#   '사무실',
#   '일정',
#   '문정동',
#   '조율',
#   '원칙',
#   '이용'],
#  ['위치',
#   '송파구',
#   '법조',
#   '인테리어',
#   '전망',
#   '타운',
#   '경우',
#   '평일',
#   '드릴',
#   '편입',
#   '부득이',
#   '주말',
#   '사무실',
#   '일정',
#   '문정동',
#   '조율',
#   '원칙',
#   '이용'],
#  ['근처', '인테리어', '오피스', '압구정역'],
#  ['연출', '디자인', '채광', '역삼', '회사', '사무실', '분위기', '천장', '근처', '오픈', '초교'],
#  ['회의실', '공유', '라운지', '사무실', '오피스', '공간'],
#  ['연출', '원룸', '사무실', '연습실'],
#  ['디자인', '카페', '미디어', '사무실', '분위기', '천장', '오픈'],
#  ['연출',
#   '위치',
#   '광선',
#   '사용',
#   '요일',
#   '주말',
#   '공간',
#   '블라인드',
#   '외부',
#   '바로',
#   '벚꽃',
#   '가로수',
#   '주차장',
#   '필요',
#   '작고',
#   '인테리어',
#   '북향',
#   '싱크대',
#   '평일',
#   '제약',
#   '현재',
#   '작업실',
#   '풍경',
#   '화장실',
#   '구성',
#   '감성',
#   '정리',
#   '지면',
#   '선호',
#   '최신',
#   '수준',
#   '느낌',
#   '삼선동',
#   '거리',
#   '자연',
#   '사무실',
#   '분위기',
#   '가능',
#   '전체',
#   '시간',
#   '미니',
#   '길가',
#   '협의',
#   '공용',
#   '대나무',
#   '약간',
#   '개천',
#   '성북구',
#   '녹색',
#   '직사',
#   '주차',
#   '윤중로',
#   '미터',
#   '통창',
#   '앵글',
#   '기타',
#   '성북천',
#   '도로'],
#  ['유튜브', '촬영', '소형', '사무실', '회사', '드라마', '화성'],
#  ['공간', '회의실', '사무실', '회의'],
#  ['위치', '일반', '집기', '한지', '사무실', '정신', '얼마', '경기도', '오픈', '정리', '의정부'],
#  ['사연', '이야기', '춘천', '흔적', '외로움', '도심', '소품'],
#  ['사연', '이야기', '춘천', '흔적', '외로움', '도심', '소품'],
#  ['사진', '촬영', '작업실', '음악', '영화', '연습실', '스터디', '대관', '안무'],
#  ['사진', '촬영', '작업실', '음악', '영화', '연습실', '스터디', '대관', '안무'],
#  ['사진가', '모던', '이태원', '미니'],
#  ['영상', '합정', '촬영'],
#  ['영상', '역삼', '사진', '원룸', '촬영', '근처', '초교'],
#  ['정원', '북한'],
#  ['아파트', '전원주택', '촬영', '마비', '마을', '주변', '산책로', '수목원'],
#  ['강아지', '도사', '아파트', '인테리어', '타일', '거실', '신경', '고급', '아이방', '공사', '비숑', '동탄'],
#  ['공간', '일상'],
#  ['상남동', '실내', '창원', '양궁'],
#  ['주방', '상도동', '빌라'],
#  ['상수', '대여', '주택', '파티', '홍대', '드라마', '영화', '공간', '대관'],
#  ['햇빛', '아파트', '아주', '고층', '새집'],
#  ['주차장',
#   '홍대입구역',
#   '상가',
#   '위치',
#   '주택',
#   '홍대',
#   '거리',
#   '주변',
#   '편의',
#   '특성',
#   '도보',
#   '바로',
#   '출구',
#   '이용'],
#  ['한남동', '아파트', '서민'],
#  ['아파트', '쾌적', '상암', '주차', '취사', '서울', '마포', '가능', '경기'],
#  ['공덕역',
#   '참고',
#   '사용',
#   '우드',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '화이트',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '건물',
#   '주차장',
#   '유료',
#   '최대',
#   '서울',
#   '오피스텔',
#   '이용',
#   '요금',
#   '조화로',
#   '지하',
#   '촬영',
#   '분위기',
#   '제공',
#   '스피커',
#   '이점',
#   '발생',
#   '주차',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['공덕역',
#   '참고',
#   '사용',
#   '마샬',
#   '원룸',
#   '파스텔',
#   '사전예약',
#   '인원',
#   '마포',
#   '화이트',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '서울',
#   '오피스텔',
#   '조화로',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['공덕역',
#   '참고',
#   '사용',
#   '우드',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '서울',
#   '오피스텔',
#   '그레이',
#   '조화로',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['공덕역',
#   '참고',
#   '사용',
#   '마샬',
#   '원룸',
#   '사전예약',
#   '인원',
#   '마포',
#   '세트',
#   '바로',
#   '소품',
#   '분리',
#   '최대',
#   '그린',
#   '서울',
#   '오피스텔',
#   '조화로',
#   '옐로우',
#   '촬영',
#   '분위기',
#   '스피커',
#   '이점',
#   '드롱기',
#   '조성',
#   '활용'],
#  ['카페', '작업실', '개인', '미디어', '작가', '분위기'],
#  ['빈티', '주택', '카페', '유럽', '가구', '모던', '서울'],
#  ['자취', '원룸', '회사원'],
#  ['촬영', '화이트', '투룸', '원목'],
#  ['강남구', '면적', '레스토랑', '평의', '모던', '서울', '소재', '논현동'],
#  ['렌탈', '엔틱', '홍대', '합정', '서울', '서교동', '자연', '티크', '샹들리'],
#  ['렌탈', '엔틱', '홍대', '합정', '서울', '서교동', '자연', '티크', '샹들리'],
#  ['렌탈', '화보', '테라스', '뮤비', '홍대', '합정', '촬영', '서교동', '프로필'],
#  ['렌탈', '존트', '홍대', '합정', '거실', '티크', '서교동', '호리'],
#  ['렌탈', '존트', '홍대', '합정', '거실', '티크', '서교동', '호리'],
#  ['렌탈', '촬영', '자연', '서울', '공간', '쇼핑몰', '채광'],
#  ['아파트', '언제', '촬영', '서울', '가능'],
#  ['아파트', '언제', '촬영', '서울', '가능'],
#  ['문제',
#   '위치',
#   '사용',
#   '집주인',
#   '옥집',
#   '실제',
#   '정원',
#   '모델링',
#   '용도',
#   '거실',
#   '서울역',
#   '개조',
#   '스타일',
#   '모던',
#   '촬영',
#   '거주',
#   '편이',
#   '실내',
#   '북촌',
#   '규모',
#   '근처'],
#  ['문제',
#   '위치',
#   '사용',
#   '집주인',
#   '옥집',
#   '실제',
#   '정원',
#   '모델링',
#   '용도',
#   '거실',
#   '서울역',
#   '개조',
#   '스타일',
#   '모던',
#   '촬영',
#   '거주',
#   '편이',
#   '실내',
#   '북촌',
#   '규모',
#   '근처'],
#  ['위치', '디자인', '평풍', '최근', '루프', '자락', '서울', '남산'],
#  ['파티', '합정역', '대관'],
#  ['초등학생', '아이'],
#  ['서점', '촬영', '독립', '인터뷰'],
#  ['모임', '촬영', '소규모', '공간'],
#  ['위치',
#   '톨게이트',
#   '가톨릭',
#   '변경',
#   '인근',
#   '시내',
#   '거리',
#   '강릉',
#   '관동',
#   '시간대',
#   '진입',
#   '가능',
#   '대학교',
#   '협의'],
#  ['잠깐',
#   '일반',
#   '자녀',
#   '남편',
#   '이용',
#   '삼일',
#   '가정',
#   '이구',
#   '휴가',
#   '휴식',
#   '보시',
#   '공간',
#   '외국'],
#  ['바디', '성북구', '헬스장', '프로필', '피티', '운동', '공간', '요가'],
#  ['렌탈', '주방', '거실', '자연', '서울', '성수동', '뚝섬역', '쇼핑몰'],
#  ['신촌', '살롱', '채광'],
#  ['용공', '영상', '화보', '세미나', '촬영', '강의', '성수동', '공간'],
#  ['쇼핑몰', '성수동', '대관', '카페'],
#  ['촬영', '성수동', '채광', '소품', '컬러풀'],
#  ['내부', '작업', '인테리어', '사용', '공간', '분위기', '가능', '성신여대역', '스터디', '인터뷰'],
#  ['인천', '갈산역', '거리', '지하', '인용', '매장', '부평', '출구'],
#  ['모던', '계통', '아파트', '그레이'],
#  ['클래스', '미팅', '원데이', '모임', '회의'],
#  ['클래스', '원데이', '모임', '회의', '독서'],
#  ['클래스', '원데이', '모임', '회의', '독서'],
#  ['임차',
#   '유럽',
#   '예술',
#   '공간',
#   '건물',
#   '광고',
#   '카페',
#   '자리',
#   '현재',
#   '학암',
#   '스파크',
#   '거리',
#   '이천',
#   '촬영',
#   '전체',
#   '부분',
#   '주택',
#   '세비',
#   '활용',
#   '비어',
#   '잡고',
#   '상가',
#   '동이'],
#  ['느낌', '휴대폰', '매장', '번잡', '개인', '판매점', '사무실'],
#  ['세종시', '스타일', '마메', '아파트', '그릇', '집안', '분위기', '화이트', '전체'],
#  ['빈티', '하우스', '타이'],
#  ['대여', '강북', '노래', '녹음실', '보컬', '서울', '셀프', '연습실', '미아'],
#  ['대여', '그램', '장소', '촬영', '셀프', '홈스', '대관'],
#  ['영화', '드라마', '소개팅', '분위기'],
#  ['영화', '드라마', '소개팅', '분위기'],
#  ['카페', '촬영', '커피숍'],
#  ['클래스', '플랜', '쿠킹', '테리어', '커피'],
#  ['극장', '유튜브', '악기', '일산', '복합', '공연장', '콘서트', '공간'],
#  ['위치',
#   '개입',
#   '대여',
#   '사이드',
#   '미래',
#   '일요일',
#   '평일',
#   '송도신도시',
#   '심야시간',
#   '도시',
#   '심야',
#   '테이블',
#   '오전',
#   '고요'],
#  ['위치',
#   '하우스',
#   '테라스',
#   '케이블카',
#   '한눈',
#   '해변',
#   '제일',
#   '바다',
#   '부산',
#   '보이',
#   '송도해수욕장',
#   '평이',
#   '점망'],
#  ['송산', '진입', '정원', '시티', '그린'],
#  ['유투브', '제품', '촬영', '자연', '쇼핑몰'],
#  ['카페', '촬영', '쇼핑몰'],
#  ['렌탈', '대여', '마켓', '블로그', '촬영', '모임', '쇼핑몰', '공간', '장소'],
#  ['아파트', '야경', '촬영', '쇼핑몰', '장소'],
#  ['렌탈', '감성', '홍대', '공간'],
#  ['렌탈', '감성', '홍대', '공간'],
#  ['위치', '공덕역', '남산타워', '애오개역', '가정', '서울역', '발코니'],
#  ['모던', '예약', '인테리어', '심플'],
#  ['렌탈', '제품', '가장', '촬영', '호리', '수유'],
#  ['렌탈', '제품', '가장', '촬영', '호리', '수유'],
#  ['수원', '캠퍼스', '경희대', '썸띵', '언제', '영업', '국제', '문의', '이외', '영통', '시간', '대관'],
#  ['아파트', '그림', '숲뷰', '아트', '신축', '콘도', '미니'],
#  ['라이프', '아파트', '미니'],
#  ['차창', '일품', '채광', '거실', '촬영', '가정', '배치', '글쓰기', '숲뷰', '책장', '공간', '테이블'],
#  ['사당역', '아파트', '전주', '전집', '남현동', '관악산', '관음사', '숲속', '고양이'],
#  ['거실', '벚꽃', '숲속'],
#  ['다락방', '하우스', '테라스', '쉐어', '나무', '거울', '복층', '계단'],
#  ['스냅', '촬영', '인물', '사진'],
#  ['웨딩', '연인', '단지', '북한', '야생화'],
#  ['음악회', '웨딩', '동백', '스몰', '촬영', '영화', '동산', '장소'],
#  ['아파트',
#   '인테리어',
#   '오후',
#   '느낌',
#   '오전',
#   '심플',
#   '요일',
#   '평형',
#   '사우동',
#   '소재',
#   '화이트',
#   '시간',
#   '김포',
#   '경기',
#   '선호'],
#  ['해돋이', '요즈음', '소개', '거실', '아침', '요새'],
#  ['한양대', '왕십리', '스터디', '카페'],
#  ...]

# %%
print(len(CoreTagDate1),len(CoreTagDate2))
# Out:
# 1852 1852

# %% [markdown]
# ## wordcloud
#     단어간 유사도

# %% [markdown]
# ### CoreTag로 유사 키워드 추출

# %%
import gensim 
from gensim.models import word2vec

# %%
num_features = 100    # Word vector dimensionality                      
min_word_count = 3   # Minimum word count                        
num_workers = 2     # Number of threads to run in parallel
context = 4          # Context window size                                                                                    
downsampling = 1e-3  # Downsample setting for frequent words

model1 = gensim.models.Word2Vec(CoreTagDate1, workers=num_workers, 
                          size=num_features, min_count = min_word_count,
                          window = context, sample = downsampling)

model2 = gensim.models.Word2Vec(CoreTagDate2, workers=num_workers, 
                          size=num_features, min_count = min_word_count,
                          window = context, sample = downsampling)

model_name = "TagSimilarity1"
model1.save(model_name)

model_name = "TagSimilarity2"
model2.save(model_name)

# %%
# model.wv.vocab
test_keyword=["가정","사진","촬영","원목","아파트","루프","자연","채광","스튜디오","광고","거실","주택","파티","빌라","카페",
              "빈티","플라워","홍대","공간","화이트","느낌","분위기","원룸",
              "사무실","서울","마당","정원","모던","인테리어","오피스"]

testkeywordDict1={}
for keyword in test_keyword:
    testkeywordDict1.update({keyword:model1.wv.most_similar(keyword,topn=5)})
testkeywordDict1
# Out:
# {'가정': [('거실', 0.999882161617279),
#   ('서울', 0.9998787641525269),
#   ('카페', 0.9998739957809448),
#   ('하우스', 0.9998734593391418),
#   ('아파트', 0.9998722076416016)],
#  '사진': [('가구', 0.9999301433563232),
#   ('가지', 0.9999263286590576),
#   ('컨셉', 0.9999251365661621),
#   ('조명', 0.9999222755432129),
#   ('주차', 0.9999191164970398)],
#  '촬영': [('자연', 0.999890148639679),
#   ('분위기', 0.9998805522918701),
#   ('모임', 0.9998764991760254),
#   ('드라마', 0.9998758435249329),
#   ('개인', 0.9998742341995239)],
#  '원목': [('건물', 0.9999194741249084),
#   ('바로', 0.9999113082885742),
#   ('소품', 0.9999088048934937),
#   ('추가', 0.9999085664749146),
#   ('채광', 0.9999083280563354)],
#  '아파트': [('빌라', 0.9998910427093506),
#   ('원룸', 0.9998818635940552),
#   ('주방', 0.9998767971992493),
#   ('주말', 0.9998724460601807),
#   ('가정', 0.9998722076416016)],
#  '루프': [('샤워', 0.9999076128005981),
#   ('영화', 0.9999058246612549),
#   ('마당', 0.9998980164527893),
#   ('사용', 0.9998940229415894),
#   ('작업실', 0.9998926520347595)],
#  '자연': [('홍대', 0.9998906254768372),
#   ('촬영', 0.999890148639679),
#   ('드라마', 0.999886155128479),
#   ('야외', 0.9998823404312134),
#   ('모임', 0.9998817443847656)],
#  '채광': [('소품', 0.9999167919158936),
#   ('원목', 0.9999083280563354),
#   ('추가', 0.9999024868011475),
#   ('바로', 0.9999022483825684),
#   ('건물', 0.9998921155929565)],
#  '스튜디오': [('추가', 0.9999074339866638),
#   ('공간', 0.9999003410339355),
#   ('소품', 0.9998924136161804),
#   ('건물', 0.9998749494552612),
#   ('화이트', 0.9998742341995239)],
#  '광고': [('카페', 0.9999131560325623),
#   ('서울', 0.9998786449432373),
#   ('빈티', 0.9998781085014343),
#   ('직접', 0.9998761415481567),
#   ('원룸', 0.9998759031295776)],
#  '거실': [('서울', 0.9999072551727295),
#   ('화장실', 0.9999047517776489),
#   ('평일', 0.9999043345451355),
#   ('문의', 0.9999040365219116),
#   ('아이', 0.9998934268951416)],
#  '주택': [('전망', 0.9999158382415771),
#   ('마당', 0.9999153017997742),
#   ('테라스', 0.9999127984046936),
#   ('하우스', 0.9999058842658997),
#   ('잔디', 0.9999057054519653)],
#  '파티': [('샤워', 0.9998968839645386),
#   ('위치', 0.9998949766159058),
#   ('카페', 0.999890148639679),
#   ('루프', 0.9998820424079895),
#   ('제품', 0.9998807907104492)],
#  '빌라': [('위치', 0.9999086856842041),
#   ('정원', 0.9999018311500549),
#   ('직접', 0.9999009370803833),
#   ('카페', 0.9998998641967773),
#   ('원룸', 0.9998990893363953)],
#  '카페': [('직접', 0.9999241828918457),
#   ('광고', 0.9999130964279175),
#   ('또한', 0.9999117851257324),
#   ('마당', 0.9999104738235474),
#   ('빈티', 0.999908447265625)],
#  '빈티': [('카페', 0.9999085664749146),
#   ('나무', 0.9999008774757385),
#   ('영화', 0.9998930096626282),
#   ('모델링', 0.9998918771743774),
#   ('정원', 0.9998864531517029)],
#  '플라워': [('테라스', 0.9995659589767456),
#   ('전망', 0.9995650053024292),
#   ('클래스', 0.99956214427948),
#   ('레이스', 0.9995403289794922),
#   ('가족', 0.9995392560958862)],
#  '홍대': [('자연', 0.9998906254768372),
#   ('파티', 0.9998714923858643),
#   ('쇼핑몰', 0.9998654723167419),
#   ('대여', 0.9998633861541748),
#   ('셀프', 0.9998607635498047)],
#  '공간': [('추가', 0.999901533126831),
#   ('스튜디오', 0.9999003410339355),
#   ('소품', 0.9998571872711182),
#   ('화이트', 0.9998494386672974),
#   ('바로', 0.9998409748077393)],
#  '화이트': [('모두', 0.999905526638031),
#   ('사용', 0.9999035000801086),
#   ('정원', 0.9998977184295654),
#   ('채광', 0.9998863339424133),
#   ('추가', 0.9998846650123596)],
#  '느낌': [('준비', 0.9999098777770996),
#   ('야외', 0.9999092221260071),
#   ('장소', 0.9999035000801086),
#   ('거리', 0.9999011158943176),
#   ('감성', 0.9998985528945923)],
#  '분위기': [('시간', 0.9999178647994995),
#   ('다른', 0.9999135732650757),
#   ('모든', 0.9999129772186279),
#   ('개인', 0.9999129772186279),
#   ('예약', 0.9999123215675354)],
#  '원룸': [('복층', 0.999911904335022),
#   ('나무', 0.9999054670333862),
#   ('직접', 0.999902069568634),
#   ('카페', 0.9999008178710938),
#   ('빌라', 0.9998990297317505)],
#  '사무실': [('잔디', 0.9999208450317383),
#   ('제공', 0.9998963475227356),
#   ('디자인', 0.9998949766159058),
#   ('실내', 0.9998937845230103),
#   ('지하', 0.9998928308486938)],
#  '서울': [('감성', 0.9999325275421143),
#   ('문의', 0.9999317526817322),
#   ('또한', 0.9999246001243591),
#   ('구성', 0.9999234080314636),
#   ('마당', 0.9999226927757263)],
#  '마당': [('하우스', 0.9999380111694336),
#   ('잔디', 0.9999352693557739),
#   ('감성', 0.9999313354492188),
#   ('자리', 0.9999247789382935),
#   ('서울', 0.9999226927757263)],
#  '정원': [('사용', 0.9999159574508667),
#   ('건물', 0.9999143481254578),
#   ('모두', 0.9999104738235474),
#   ('바로', 0.9999073147773743),
#   ('나무', 0.9999067187309265)],
#  '모던': [('하우스', 0.999870777130127),
#   ('느낌', 0.9998655915260315),
#   ('마당', 0.9998589754104614),
#   ('안방', 0.9998573064804077),
#   ('침실', 0.999856173992157)],
#  '인테리어': [('원목', 0.9998905062675476),
#   ('주차장', 0.9998875856399536),
#   ('액자', 0.999884307384491),
#   ('건물', 0.9998842477798462),
#   ('소품', 0.9998784065246582)],
#  '오피스': [('영화', 0.9998819828033447),
#   ('루프', 0.9998751878738403),
#   ('작업실', 0.9998705387115479),
#   ('파티', 0.9998699426651001),
#   ('단독주택', 0.9998646378517151)]}

# %%
# "편안" 키워드 반영 X
test_keyword=["가정","사진","촬영","원목","아파트","루프","자연","채광","스튜디오","광고","거실","주택","파티","빌라","카페",
              "빈티","플라워","홍대","공간","화이트","느낌","분위기","원룸",
              "사무실","서울","마당","정원","모던","인테리어","오피스"]
testkeywordDict2={}
for keyword in test_keyword:
    testkeywordDict2.update({keyword:model2.wv.most_similar(keyword,topn=5)})
testkeywordDict2
# Out:
# {'가정': [('촬영', 0.9971935153007507),
#   ('공간', 0.9970043897628784),
#   ('주말', 0.9968531727790833),
#   ('거실', 0.9968520402908325),
#   ('느낌', 0.9965159296989441)],
#  '사진': [('느낌', 0.9967677593231201),
#   ('촬영', 0.9965486526489258),
#   ('주말', 0.9964958429336548),
#   ('공간', 0.9964368343353271),
#   ('평일', 0.9962464570999146)],
#  '촬영': [('주말', 0.9983217716217041),
#   ('공간', 0.9981911778450012),
#   ('정원', 0.9981109499931335),
#   ('아파트', 0.9979910850524902),
#   ('거실', 0.9979539513587952)],
#  '원목': [('가구', 0.9945619106292725),
#   ('정원', 0.9943369030952454),
#   ('거실', 0.9943026304244995),
#   ('모던', 0.994168221950531),
#   ('촬영', 0.994049072265625)],
#  '아파트': [('촬영', 0.9979909658432007),
#   ('느낌', 0.997343122959137),
#   ('주말', 0.9973375797271729),
#   ('사용', 0.9972960352897644),
#   ('인테리어', 0.9972710013389587)],
#  '루프': [('촬영', 0.996267557144165),
#   ('공간', 0.9961527585983276),
#   ('화이트', 0.9956377744674683),
#   ('가구', 0.9954395294189453),
#   ('주말', 0.9953470230102539)],
#  '자연': [('촬영', 0.9970767498016357),
#   ('아파트', 0.9966768622398376),
#   ('사용', 0.9966739416122437),
#   ('가구', 0.9966070652008057),
#   ('거실', 0.9963600039482117)],
#  '채광': [('촬영', 0.9950748085975647),
#   ('거실', 0.9947725534439087),
#   ('느낌', 0.9945723414421082),
#   ('테라스', 0.9945311546325684),
#   ('사용', 0.9944984912872314)],
#  '스튜디오': [('촬영', 0.9956350326538086),
#   ('시간', 0.995393693447113),
#   ('사용', 0.9953206181526184),
#   ('주차', 0.9951443672180176),
#   ('거실', 0.9950383901596069)],
#  '광고': [('촬영', 0.9968788623809814),
#   ('가정', 0.9964354038238525),
#   ('자연', 0.9962986707687378),
#   ('공간', 0.996094286441803),
#   ('주말', 0.9960088729858398)],
#  '거실': [('주말', 0.9981566667556763),
#   ('촬영', 0.9979539513587952),
#   ('시간', 0.9975883960723877),
#   ('공간', 0.9975831508636475),
#   ('느낌', 0.9975476861000061)],
#  '주택': [('촬영', 0.9973323941230774),
#   ('주말', 0.9966626167297363),
#   ('아파트', 0.9964842200279236),
#   ('사용', 0.9964233040809631),
#   ('인테리어', 0.9963514804840088)],
#  '파티': [('느낌', 0.9959044456481934),
#   ('거실', 0.995363175868988),
#   ('사진', 0.9950932860374451),
#   ('사용', 0.9950456023216248),
#   ('촬영', 0.9950417876243591)],
#  '빌라': [('촬영', 0.995506227016449),
#   ('평일', 0.9952607750892639),
#   ('주말', 0.9952223896980286),
#   ('사용', 0.9949873685836792),
#   ('거실', 0.9949538707733154)],
#  '카페': [('거실', 0.9953933954238892),
#   ('느낌', 0.994981586933136),
#   ('주말', 0.9949032068252563),
#   ('화장실', 0.9946058988571167),
#   ('시간', 0.9943259358406067)],
#  '빈티': [('촬영', 0.9959977865219116),
#   ('주말', 0.9957250952720642),
#   ('공간', 0.9956842064857483),
#   ('가정', 0.9954954385757446),
#   ('거실', 0.9953355193138123)],
#  '플라워': [('다른', 0.729195773601532),
#   ('클래스', 0.7288094758987427),
#   ('스냅', 0.7286806106567383),
#   ('날짜', 0.7284155488014221),
#   ('북한', 0.7284114360809326)],
#  '홍대': [('가구', 0.9959931373596191),
#   ('거실', 0.9957611560821533),
#   ('촬영', 0.9956060647964478),
#   ('공간', 0.9954380989074707),
#   ('시간', 0.9952781200408936)],
#  '공간': [('촬영', 0.9981911778450012),
#   ('주말', 0.9978474378585815),
#   ('느낌', 0.9976010322570801),
#   ('거실', 0.9975831508636475),
#   ('주차', 0.99735027551651)],
#  '화이트': [('촬영', 0.997402548789978),
#   ('공간', 0.9972466230392456),
#   ('사용', 0.9971872568130493),
#   ('가구', 0.9971423149108887),
#   ('정원', 0.9965616464614868)],
#  '느낌': [('공간', 0.9976010322570801),
#   ('거실', 0.9975477457046509),
#   ('촬영', 0.9974870085716248),
#   ('시간', 0.9974075555801392),
#   ('아파트', 0.9973433017730713)],
#  '분위기': [('촬영', 0.9974799156188965),
#   ('아파트', 0.9972283244132996),
#   ('거실', 0.9969673156738281),
#   ('평일', 0.9969388842582703),
#   ('주말', 0.9969353675842285)],
#  '원룸': [('거실', 0.9965972900390625),
#   ('공간', 0.9965066313743591),
#   ('느낌', 0.9963444471359253),
#   ('주차', 0.9960830211639404),
#   ('촬영', 0.9959187507629395)],
#  '사무실': [('거실', 0.9970613121986389),
#   ('주말', 0.9968332052230835),
#   ('인테리어', 0.9966156482696533),
#   ('평일', 0.9965547323226929),
#   ('화이트', 0.9964829683303833)],
#  '서울': [('거실', 0.9970710277557373),
#   ('촬영', 0.9969924688339233),
#   ('공간', 0.9966710805892944),
#   ('느낌', 0.9965513348579407),
#   ('아파트', 0.996430516242981)],
#  '마당': [('거실', 0.9961791634559631),
#   ('인테리어', 0.99614018201828),
#   ('촬영', 0.9959522485733032),
#   ('주말', 0.9955803155899048),
#   ('공간', 0.9954916834831238)],
#  '정원': [('촬영', 0.9981109499931335),
#   ('주말', 0.9971879720687866),
#   ('가구', 0.9969015717506409),
#   ('모던', 0.9968053102493286),
#   ('거실', 0.9967561960220337)],
#  '모던': [('촬영', 0.9975575804710388),
#   ('주말', 0.9970690608024597),
#   ('거실', 0.997006893157959),
#   ('사용', 0.9968955516815186),
#   ('정원', 0.9968053102493286)],
#  '인테리어': [('촬영', 0.9977402091026306),
#   ('아파트', 0.9972710013389587),
#   ('공간', 0.9971193671226501),
#   ('평일', 0.9970890879631042),
#   ('주말', 0.9970155954360962)],
#  '오피스': [('한강', 0.9472134113311768),
#   ('파티', 0.9462238550186157),
#   ('화이트', 0.9443095922470093),
#   ('광고', 0.9442697167396545),
#   ('하우스', 0.9436005353927612)]}

# %% [markdown]
# ## 각 모델 결과 태그를 새로운 태그 (extend_tag1,extend_tag) 컬럼으로 저장

# %%
extendTagList=[]
vocab=model1.wv.vocab
tagList1=[]
for i in range(len(CoreTagDate1)):
    extendTag=[]
    tag1=[]
    try:
        for j in range (len(CoreTagDate1[i])):
            if(CoreTagDate1[i][j] in vocab.keys()):
#                 print(CoreTagDate1[i][j])
#                 extendSet=model1.wv.most_similar(CoreTagDate1[i][j],topn=2)
                tag1.append(CoreTagDate1[i][j])
#                 for extend in extendSet:
#                     extendTag.append(extend)
#                 extendTagList.append(list(set(extendTag[0])))
            else:
                continue
        tagList1.append(tag1)
    except KeyError:
        continue

# %%
dataset["new_tag1"]=tagList1

# %%
# extendTagList=[]
vocab=model2.wv.vocab
tagList2=[]
for i in range(len(CoreTagDate2)):
    extendTag=[]
    tag2=[]
    try:
        for j in range (len(CoreTagDate2[i])):
            if(CoreTagDate2[i][j] in vocab.keys()):
#                 print(CoreTagDate2[i][j])
#                 extendSet=model2.wv.most_similar(CoreTagDate2[i][j],topn=2)
                tag2.append(CoreTagDate2[i][j])
#                 for extend in extendSet:
#                     extendTag.append(extend)
#                 extendTagList.append(list(set(extendTag[0])))
            else:
                continue
        tagList2.append(tag2)
    except KeyError:
        continue

# %%
dataset["new_tag2"]=tagList2

# %%
dataset.to_csv('C:/바탕 화면/playdata/ice/eclipse/Devils_Project/dataWork/controller/total_dataset_trim_newTag.csv',
                 sep=',',na_rep='NaN',index =True,encoding='utf-8-sig')

# %% [markdown]
# ## 데이터 전처리

# %%
import matplotlib
import matplotlib.pyplot as plt
dataset = pd.read_csv("total_dataset_trim_newTag_scale.csv",encoding='utf-8')

# %%
## price 컬럼 숫자형으로 변형
dataset["price"].astype("float32")
## floor 컬럼 문자열 숫자로 바꾸기 (지금은 데이터에서 직접 다 바꿈... 나중에 코드 입력하기)
# dataset[dataset["floor"]=='B']["floor"].replace("B",-,inplace=True)
# dataset[dataset["floor"]=='지하']["floor"].replace("지하",-,inplace=True)
# dataset[dataset["floor"]=='-']["floor"].replace("-",-1,inplace=True)
# Out:
# 0       50000.0
# 1       38000.0
# 2       38000.0
# 3       50000.0
# 4       62000.0
#          ...
# 1847    50000.0
# 1848    40000.0
# 1849    45000.0
# 1850    41000.0
# 1851    87000.0
# Name: price, Length: 1852, dtype: float32

# %%
# dataset["default_person"].plot()
# df.boxplot(dataset["floor"])
# Out:
# <AxesSubplot:>

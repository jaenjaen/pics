# %%
# 외부 모듈
import pandas as pd
# 사용자 모듈 불러오기
import sys
sys.path.append('..')
from dao import tag_dao
from npl_model import 
from word2vec_model import get_desc_tags
from count_tag_model import extend_tag

# %%
def tagData():
    # DB 데이터
    df = tag_dao.getTagData()
    return df
# Out:
#      stu_id          com_id  category_id                                name  \
# 0        10   11@sample.com            1                            엔코아스튜디오1
# 1        10   11@sample.com            1                            엔코아스튜디오1
# 2        10   11@sample.com            1                            엔코아스튜디오1
# 3        10   11@sample.com            1                            엔코아스튜디오1
# 4        11  1234@admin.com            2                                카페로제
# ..      ...             ...          ...                                 ...
# 243    1172  1234@admin.com            1            후오비_블록체인_커피하우스(달콤커피_논현점)
# 244    1173  1234@admin.com            1                                나무주택
# 245    1174  1234@admin.com            1                   강남_소규모_사무실_대관합니다.
# 246    1175  1234@admin.com            1  간단조명_촬영(양방향_자연채광)_양평동4가_성원APT(33평)
# 247    1176  1234@admin.com            1                                None
#
# ...

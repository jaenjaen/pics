# %%
import pymysql
import pandas as pd

# %%
#DB 접근
def get_cfsource() :
    db= pymysql.connect(host='pics.crvbvpzlygpt.ap-northeast-2.rds.amazonaws.com',
                         port=3306,
                         user='pics',
                         passwd='picspics!1',
                         db='pics',
                         charset='utf8',
                       cursorclass=pymysql.cursors.DictCursor)
    cursor= db.cursor()
    sql = "SELECT cust_id, stu_id, score "
    sql += "FROM review"

    cursor.execute(sql)
    db.commit()

    result = cursor.fetchall()
    db.close()
    df = pd.DataFrame(result)
    return df

# %%
# data = pd.read_excel('review.xlsx', enconding='utf-8')
# data.rename({'studio_name':'stu_id'}, axis='columns', inplace=True)
# data[data.duplicated(['stu_id','cust_id'])]
# data.drop_duplicates(['stu_id','cust_id'], inplace=True)
# data.score = round(data.score,0)
# ratings = data.pivot_table(index='cust_id', columns='stu_id', values='score')
# ratings_d = data.pivot_table(index='cust_id', columns='stu_id', values='score')
# index_list = [i+1 for i in range(len(ratings.index))]
# ratings.index = np.arange(22, 42, 1)
# ratings.columns = np.arange(1156, 1176, 1)
# ratings.index.name = 'cust_id'
# ratings.columns.name = 'stu_id'
# ratings
# Out:
# stu_id   1156  1157  1158  1159  1160  1161  1162  1163  1164  1165  1166  \
# cust_id
# 22        NaN   4.0   NaN   NaN   NaN   NaN   NaN   2.0   NaN   NaN   4.0
# 23        NaN   NaN   NaN   1.0   NaN   2.0   NaN   NaN   NaN   4.0   4.0
# 24        NaN   NaN   NaN   4.0   1.0   NaN   NaN   4.0   NaN   NaN   5.0
# 25        2.0   NaN   3.0   NaN   4.0   NaN   2.0   NaN   3.0   4.0   2.0
# 26        NaN   NaN   NaN   3.0   5.0   NaN   2.0   NaN   NaN   NaN   NaN
# 27        1.0   NaN   NaN   NaN   NaN   NaN   NaN   4.0   4.0   1.0   4.0
# 28        NaN   2.0   NaN   NaN   4.0   4.0   NaN   NaN   2.0   NaN   4.0
# 29        2.0   NaN   NaN   5.0   4.0   NaN   2.0   NaN   NaN   NaN   NaN
# 30        NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   4.0   NaN   NaN
# 31        4.0   NaN   NaN   NaN   4.0   NaN   NaN   2.0   NaN   NaN   4.0
# 32        NaN   1.0   2.0   NaN   2.0   NaN   2.0   1.0   2.0   3.0   4.0
# 33        NaN   NaN   NaN   NaN   NaN   2.0   4.0   NaN   2.0   NaN   3.0
# 34        NaN   NaN   2.0   NaN   NaN   2.0   NaN   NaN   2.0   NaN   NaN
# 35        4.0   NaN   NaN   2.0   2.0   4.0   4.0   NaN   3.0   NaN   5.0
# 36        NaN   NaN   2.0   4.0   5.0   2.0   NaN   2.0   NaN   NaN   NaN
# 37        NaN   NaN   4.0   3.0   NaN   2.0   4.0   NaN   NaN   2.0   2.0
# 38        NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   3.0
# 39        4.0   NaN   2.0   NaN   NaN   NaN   5.0   5.0   2.0   4.0   4.0
# 40        2.0   NaN   NaN   NaN   4.0   3.0   NaN   NaN   NaN   NaN   4.0
# 41        NaN   NaN   NaN   4.0   NaN   NaN   NaN   5.0   NaN   NaN   2.0
#
# stu_id   1167  1168  1169  1170  1171  1172  1173  1174  1175
# cust_id
# 22        NaN   NaN   2.0   NaN   2.0   NaN   NaN   NaN   NaN
# 23        NaN   NaN   NaN   NaN   2.0   NaN   NaN   NaN   NaN
# 24        NaN   NaN   NaN   NaN   NaN   NaN   4.0   3.0   NaN
# 25        NaN   NaN   4.0   NaN   4.0   NaN   NaN   NaN   1.0
# 26        3.0   4.0   4.0   NaN   NaN   4.0   1.0   NaN   NaN
# 27        1.0   1.0   NaN   4.0   4.0   NaN   NaN   5.0   NaN
# 28        3.0   NaN   NaN   NaN   NaN   NaN   NaN   1.0   4.0
# 29        4.0   4.0   NaN   NaN   2.0   4.0   2.0   NaN   NaN
# 30        NaN   NaN   2.0   2.0   NaN   3.0   NaN   NaN   NaN
# 31        NaN   4.0   NaN   2.0   5.0   NaN   NaN   NaN   NaN
# 32        NaN   4.0   NaN   3.0   4.0   NaN   2.0   2.0   4.0
# 33        NaN   NaN   NaN   NaN   2.0   3.0   NaN   2.0   2.0
# 34        1.0   2.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 35        NaN   NaN   NaN   NaN   NaN   1.0   NaN   3.0   NaN
# 36        1.0   NaN   NaN   2.0   NaN   NaN   NaN   NaN   NaN
# 37        NaN   NaN   4.0   2.0   NaN   NaN   NaN   NaN   NaN
# 38        4.0   4.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 39        NaN   4.0   NaN   NaN   2.0   NaN   NaN   2.0   NaN
# 40        4.0   NaN   5.0   NaN   1.0   1.0   4.0   4.0   4.0
# 41        NaN   NaN   3.0   NaN   2.0   2.0   2.0   2.0   NaN

# %%
# from itertools import product
# id_combo=list(product(ratings.index, ratings.columns))
# res_id = 62
# for cust_id, stu_id in id_combo:
#     db= pymysql.connect(host='pics.crvbvpzlygpt.ap-northeast-2.rds.amazonaws.com',
#                      port=3306,
#                      user='pics',
#                      passwd='picspics!1',
#                      db='pics',
#                      charset='utf8',
#                    cursorclass=pymysql.cursors.DictCursor)
#     cursor= db.cursor()
#     sql = "INSERT INTO reservation(cust_id,stu_id,start_date,end_date,total_price,res_date,total_people) "
#     sql += "VALUES("
#     sql += str(cust_id)+", "
#     sql += str(stu_id)+", "
#     sql += "'2020-09-14', '2020-09-15', 100000, '2020-09-01', 10);"


#     cursor.execute(sql)
#     db.commit()
#     db.close()

# %%
# from itertools import product
# id_combo=list(product(ratings.index, ratings.columns))
# res_id = 2485
# for cust_id, stu_id in id_combo:
#     score = ratings.loc[cust_id,stu_id]
#     if score > -1 :
#         db= pymysql.connect(host='pics.crvbvpzlygpt.ap-northeast-2.rds.amazonaws.com',
#                          port=3306,
#                          user='pics',
#                          passwd='picspics!1',
#                          db='pics',
#                          charset='utf8',
#                        cursorclass=pymysql.cursors.DictCursor)
#         cursor= db.cursor()
#         sql = "INSERT INTO review(cust_id, stu_id, res_id, score) "
#         sql += "VALUES( "
#         sql += str(cust_id)+", "
#         sql += str(stu_id)+", "
#         sql += str(res_id)+", "
#         sql += str(score) +"); "
#     else : 
#         continue

#     print(sql)
#     cursor.execute(sql)
#     db.commit()
#     db.close()
#     res_id += 1
# Out:
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 22, 1157, 2485, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 22, 1163, 2486, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 22, 1166, 2487, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 22, 1169, 2488, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 22, 1171, 2489, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 23, 1159, 2490, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 23, 1161, 2491, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 23, 1165, 2492, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 23, 1166, 2493, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 23, 1171, 2494, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1159, 2495, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1160, 2496, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1163, 2497, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1166, 2498, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1173, 2499, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 24, 1174, 2500, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1156, 2501, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1158, 2502, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1160, 2503, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1162, 2504, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1164, 2505, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1165, 2506, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1166, 2507, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1169, 2508, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1171, 2509, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 25, 1175, 2510, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1159, 2511, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1160, 2512, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1162, 2513, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1167, 2514, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1168, 2515, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1169, 2516, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1172, 2517, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 26, 1173, 2518, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1156, 2519, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1163, 2520, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1164, 2521, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1165, 2522, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1166, 2523, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1167, 2524, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1168, 2525, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1170, 2526, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1171, 2527, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 27, 1174, 2528, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1157, 2529, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1160, 2530, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1161, 2531, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1164, 2532, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1166, 2533, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1167, 2534, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1174, 2535, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 28, 1175, 2536, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1156, 2537, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1159, 2538, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1160, 2539, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1162, 2540, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1167, 2541, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1168, 2542, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1171, 2543, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1172, 2544, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 29, 1173, 2545, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 30, 1162, 2546, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 30, 1164, 2547, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 30, 1169, 2548, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 30, 1170, 2549, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 30, 1172, 2550, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1156, 2551, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1160, 2552, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1163, 2553, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1166, 2554, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1168, 2555, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1170, 2556, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 31, 1171, 2557, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1157, 2558, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1158, 2559, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1160, 2560, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1162, 2561, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1163, 2562, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1164, 2563, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1165, 2564, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1166, 2565, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1168, 2566, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1170, 2567, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1171, 2568, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1173, 2569, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1174, 2570, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 32, 1175, 2571, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1161, 2572, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1162, 2573, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1164, 2574, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1166, 2575, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1171, 2576, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1172, 2577, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1174, 2578, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 33, 1175, 2579, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1158, 2580, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1161, 2581, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1164, 2582, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1167, 2583, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1168, 2584, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 34, 1169, 2585, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1156, 2586, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1159, 2587, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1160, 2588, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1161, 2589, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1162, 2590, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1164, 2591, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1166, 2592, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1172, 2593, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 35, 1174, 2594, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1158, 2595, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1159, 2596, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1160, 2597, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1161, 2598, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1163, 2599, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1167, 2600, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 36, 1170, 2601, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1158, 2602, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1159, 2603, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1161, 2604, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1162, 2605, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1165, 2606, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1166, 2607, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1169, 2608, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 37, 1170, 2609, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 38, 1159, 2610, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 38, 1166, 2611, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 38, 1167, 2612, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 38, 1168, 2613, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 38, 1169, 2614, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1156, 2615, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1158, 2616, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1162, 2617, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1163, 2618, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1164, 2619, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1165, 2620, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1166, 2621, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1168, 2622, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1171, 2623, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 39, 1174, 2624, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1156, 2625, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1160, 2626, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1161, 2627, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1166, 2628, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1167, 2629, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1169, 2630, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1171, 2631, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1172, 2632, 1.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1173, 2633, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1174, 2634, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 40, 1175, 2635, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1159, 2636, 4.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1163, 2637, 5.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1166, 2638, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1169, 2639, 3.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1171, 2640, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1172, 2641, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1173, 2642, 2.0);
# INSERT INTO review(cust_id, stu_id, res_id, score) VALUES( 41, 1174, 2643, 2.0);

# %%
# !jupyter nbconvert --to script reco_dao.ipynb
# Out:
# [NbConvertApp] Converting notebook reco_dao.ipynb to script
# [NbConvertApp] Writing 1163 bytes to reco_dao.py
